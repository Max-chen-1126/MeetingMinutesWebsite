# %%
import os

from google.api_core.client_options import ClientOptions
from google.cloud.speech_v2 import SpeechClient
from google.cloud.speech_v2.types import cloud_speech

MAX_AUDIO_LENGTH_SECS = 8 * 60 * 60


def run_batch_recognize():
  # Instantiates a client.
  client = SpeechClient(
      client_options=ClientOptions(
          api_endpoint="us-central1-speech.googleapis.com",
      ),
  )

  # The output path of the transcription result.
  gcs_output_folder = "gs://test_stt_mp4_to_text/transcripts"

  # The name of the audio file to transcribe:
  audio_gcs_uri = "gs://test_stt_mp4_to_text/test_audio1.mp3"

  config = cloud_speech.RecognitionConfig(
      auto_decoding_config={},
      features=cloud_speech.RecognitionFeatures(
          enable_automatic_punctuation=True,
        ),
      model="chirp_2",
      language_codes=["en-US"],
  )

  output_config = cloud_speech.RecognitionOutputConfig(
      gcs_output_config=cloud_speech.GcsOutputConfig(uri=gcs_output_folder),
  )

  files = [cloud_speech.BatchRecognizeFileMetadata(uri=audio_gcs_uri)]

  request = cloud_speech.BatchRecognizeRequest(
      recognizer="projects/tw-maxchens-sandbox/locations/us-central1/recognizers/_",
      config=config,
      files=files,
      recognition_output_config=output_config,
  )
  operation = client.batch_recognize(request=request)

  print("Waiting for operation to complete...")
  response = operation.result(timeout=3 * MAX_AUDIO_LENGTH_SECS)
  print(response)
  
run_batch_recognize()
# Out:
# Waiting for operation to complete...
# ---------------------------------------------------------------------------
# RetryError                                Traceback (most recent call last)
# File ~/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages/google/api_core/future/polling.py:137, in PollingFuture._blocking_poll(self, timeout, retry, polling)
#     136 try:
# --> 137     polling(self._done_or_raise)(retry=retry)
#     138 except exceptions.RetryError:
#
# File ~/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#
# File ~/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#
# File ~/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     143 try:
# --> 144     result = target()
#     145     if inspect.isawaitable(result):
#
# File ~/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages/google/api_core/future/polling.py:119, in PollingFuture._done_or_raise(self, retry)
#     118 """Check if the future is done and raise if it's not."""
# --> 119 if not self.done(retry=retry):
#     120     raise _OperationNotComplete()
#
# File ~/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages/google/api_core/operation.py:174, in Operation.done(self, retry)
#     166 """Checks to see if the operation is complete.
#     167
#     168 Args:
#    (...)
#     172     bool: True if the operation is complete, False otherwise.
#     173 """
# --> 174 self._refresh_and_update(retry)
#     175 return self._operation.done
#
# File ~/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages/google/api_core/operation.py:162, in Operation._refresh_and_update(self, retry)
#     161 if not self._operation.done:
# --> 162     self._operation = self._refresh(retry=retry) if retry else self._refresh()
#     163     self._set_result_from_operation()
#
# File ~/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages/google/api_core/operations_v1/operations_client.py:159, in OperationsClient.get_operation(self, name, retry, timeout, compression, metadata)
#     157 metadata.append(gapic_v1.routing_header.to_grpc_metadata({"name": name}))
# --> 159 return self._get_operation(
#     160     request,
#     161     retry=retry,
#     162     timeout=timeout,
#     163     compression=compression,
#     164     metadata=metadata,
#     165 )
#
# File ~/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#
# File ~/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py:221, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     216     final_exc, source_exc = exc_factory_fn(
#     217         error_list,
#     218         RetryFailureReason.TIMEOUT,
#     219         original_timeout,
#     220     )
# --> 221     raise final_exc from source_exc
#     222 _LOGGER.debug(
#     223     "Retrying due to {}, sleeping {:.1f}s ...".format(error_list[-1], next_sleep)
#     224 )
#
# RetryError: Timeout of 600.0s exceeded, last exception: 504 Deadline Exceeded
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# Cell In[1], line 51
#      48   response = operation.result(timeout=3 * MAX_AUDIO_LENGTH_SECS)
#      49   print(response)
# ---> 51 run_batch_recognize()
#
# Cell In[1], line 48, in run_batch_recognize()
#      45 operation = client.batch_recognize(request=request)
#      47 print("Waiting for operation to complete...")
# ---> 48 response = operation.result(timeout=3 * MAX_AUDIO_LENGTH_SECS)
#      49 print(response)
#
# File ~/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages/google/api_core/future/polling.py:256, in PollingFuture.result(self, timeout, retry, polling)
#     144 def result(self, timeout=_DEFAULT_VALUE, retry=None, polling=None):
#     145     """Get the result of the operation.
#     146
#     147     This method will poll for operation status periodically, blocking if
#    (...)
#     253             the timeout is reached before the operation completes.
#     254     """
# --> 256     self._blocking_poll(timeout=timeout, retry=retry, polling=polling)
#     258     if self._exception is not None:
#     259         # pylint: disable=raising-bad-type
#     260         # Pylint doesn't recognize that this is valid in this case.
#     261         raise self._exception
#
# File ~/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages/google/api_core/future/polling.py:139, in PollingFuture._blocking_poll(self, timeout, retry, polling)
#     137     polling(self._done_or_raise)(retry=retry)
#     138 except exceptions.RetryError:
# --> 139     raise concurrent.futures.TimeoutError(
#     140         f"Operation did not complete within the designated timeout of "
#     141         f"{polling.timeout} seconds."
#     142     )
#
# TimeoutError: Operation did not complete within the designated timeout of 86400 seconds.

# %%
! pip install --upgrade google-cloud-aiplatform
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (1.49.0)
# Collecting google-cloud-aiplatform
#   Downloading google_cloud_aiplatform-1.62.0-py2.py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.17.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.29.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-cloud-aiplatform) (4.25.3)
# Requirement already satisfied: packaging>=14.3 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-cloud-aiplatform) (23.2)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.16.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.23.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.12.3)
# Requirement already satisfied: shapely<3.0.0dev in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.0.4)
# Requirement already satisfied: pydantic<3 in /Users/mai/.local/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.7.4)
# Requirement already satisfied: docstring-parser<1 in /Users/mai/.local/lib/python3.10/site-packages (from google-cloud-aiplatform) (0.16)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.63.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.32.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.64.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.62.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.7.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.9.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.13.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.5.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/mai/.local/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /Users/mai/.local/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform) (4.12.0)
# Requirement already satisfied: numpy<3,>=1.14 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from shapely<3.0.0dev->google-cloud-aiplatform) (1.26.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (0.6.0)
# Requirement already satisfied: six>=1.5 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mai/miniforge3/envs/GooglePoCEnv/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2024.2.2)
# Downloading google_cloud_aiplatform-1.62.0-py2.py3-none-any.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 7.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: google-cloud-aiplatform
#   Attempting uninstall: google-cloud-aiplatform
#     Found existing installation: google-cloud-aiplatform 1.49.0
#     Uninstalling google-cloud-aiplatform-1.49.0:
#       Successfully uninstalled google-cloud-aiplatform-1.49.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# vertexai 1.49.0 requires google-cloud-aiplatform[all]==1.49.0, but you have google-cloud-aiplatform 1.62.0 which is incompatible.
# Successfully installed google-cloud-aiplatform-1.62.0

# %% [markdown]
# ### 實際完成整個 Meeting Minutes 的生成流程流程
#
# 1. 取得語音檔案：將任意檔案轉成".wav" 並且是 16000hz 的檔案
# 2. 調用本地端的 whisper 模型進行語音轉文字
# 3. 設計 Prompt 並呼叫 Gemini 模型進行會議紀錄生成

# %%
# 取得語音檔案本地路徑，並解析格式轉換乘 16000hz 的 ".wav" 新檔案，並記錄路徑
import os
from pydub import AudioSegment

def convert_audio_to_wav(input_file_path):
    # 獲取輸入文件的目錄和文件名（不含擴展名）
    input_dir, input_filename = os.path.split(input_file_path)
    input_name, _ = os.path.splitext(input_filename)
    
    # 創建輸出文件路徑
    output_file_path = os.path.join(input_dir, f"{input_name}_16000hz.wav")
    
    # 讀取輸入音頻文件
    audio = AudioSegment.from_file(input_file_path)
    
    # 轉換為單聲道（如果是立體聲）
    audio = audio.set_channels(1)
    
    # 設置採樣率為 16000Hz
    audio = audio.set_frame_rate(16000)
    
    # 導出為 WAV 格式
    audio.export(output_file_path, format="wav")
    
    return output_file_path

# 使用示例
input_audio_path = "/Users/mai/Downloads/0704錄音1.mp3"  # 請替換為實際的輸入音頻文件路徑 
output_wav_path = convert_audio_to_wav(input_audio_path)
print(f"轉換後的 WAV 文件路徑：{output_wav_path}")
# Out:
# 轉換後的 WAV 文件路徑：/Users/mai/Downloads/0704錄音1_16000hz.wav

# %%
'''使用 Command 調用 Whisper.cpp 的模型，進行語音轉文字
Whisper.cpp 的調用方法 : 
使用步驟：
1. 先激活環境：mamba activate py310-whisper
2. 目前只接受 16000hz 的 wav : ffmpeg -i "./tests/20240402-Eupfin Bi-Weekly會議.m4a" -vn -ar 16000 -ac 1 -b:a 243k -f wav "./tests/20240402-Eupfin Bi-Weekly會議.wav" -y #如果已轉可以跳過
3. ./main -m models/ggml-large-v2.bin -l zh -otxt -f "file_path.wav" -of "file_path"'''

import subprocess
import os

# Whisper.cpp 的路徑（請根據實際情況修改）
whisper_cpp_path = "/Users/mai/Desktop/GitHub-Repos/whisper.cpp"
model_path = os.path.join(whisper_cpp_path, "models/ggml-large-v2.bin")
main_executable = os.path.join(whisper_cpp_path, "main")

# 設置輸出文件的路徑和名稱（不包括副檔名）
output_base_path = os.path.splitext(output_wav_path)[0]

# 構建 Whisper.cpp 命令
whisper_command = f"{main_executable} -m {model_path} -l zh -otxt -f {output_wav_path} -of {output_base_path}"

# 使用 conda run 來執行命令
full_command = f"conda run -n py310-whisper {whisper_command}"

try:
    # 執行命令
    result = subprocess.run(full_command, shell=True, check=True, capture_output=True, text=True)
    
    print("語音轉文字成功完成！")
    print(f"輸出文件: {output_base_path}.txt")
    
    # 如果需要，你可以讀取並打印轉錄的文本
    with open(f"{output_base_path}.txt", "r", encoding="utf-8") as f:
        transcribed_text = f.read()
        print("\n轉錄文本:")
        print(transcribed_text)

except subprocess.CalledProcessError as e:
    print(f"執行過程中發生錯誤: {e}")
    print(f"錯誤輸出: {e.stderr}")
# Out:
# 語音轉文字成功完成！
# 輸出文件: /Users/mai/Downloads/0704錄音1_16000hz.txt
#
# 轉錄文本:
# 高中 嘉義中學
# 沒有啦 他是學長
# 學長 有一個留紙一下
# 小中是大一屆
# 大一屆 46年
# 他都叫他學長
# 那不是同學了嗎
# 小中就是這個都沒做
# 連這個你都知道
# 他們同年為什麼是學長
# 太不謙虛了
# 那他跟那個林董是同年
# 同年嘛 跟那個
# 蘇秀賢啊
# 對 所以林董也是叫那個
# 小中阿伯也是叫學長
# 叫學長 嘉義中學
# 是喔
# 好吧 我們就先開始
# 林董在那個地下室準備上來了
# 你怎麼知道
# 同仁有回報
# 那是要先開始嗎
# 你馬上準備上來 我在等那一張
# 那個沈記長 陳惠敏
# 也是嘉義中學的
# 他也是嘉義中學
# 嘉義 我不知道嘉義中學
# 我認識他 我不知道嘉義
# 他們都叫他
# 陳惠敏比較大
# 他是44年
# 他的那個氣質跟祐賢有點像
# 他是44年是不是
# 44年大兩屆
# 是不是嘉義中學的
# 嘉義 他是不是嘉義中學
# 好像是喔
# 如果不是嘉義中學
# 那附近有的會去台南
# 不然就要跑到彰化 台松
# 我確定他是嘉義
# 嘉義
# 應該也是嘉義中學
# 季老頭的腳
# 我那天突然發現
# 我們那個文化局局長
# 他讀的國小
# 跟我讀的同一個國小
# 高雄
# 我很少碰到國小的學妹
# 很少很少
# 哪一屆 你說誰
# 文化局局長
# 張嘉義
# 市長叫我去那個
# 華誼的那個
# 在那個中環的那個
# 叫我上去
# 他們還會見會 聊天
# 高雄市還是高雄縣
# 高雄市
# 來了
# 不好意思喔 來太慢了
# 沒有
# 還沒處理媒體事件
# 還沒處理好
# 就趕快跑來
# 對 最近最辛苦了
# 還沒處理好
# 那個酒店花生那個是
# 他也是安可經理
# 他媽媽不知道受到什麼刺激
# 不是那個 是另外一個
# 另外一個
# 那個是學校
# 學校端的
# 看他能不能辦理
# 好 我們如果過半了
# 我們就開始
# 新北市住宅及都市分析中心
# 第二屆第四次董監事會
# 依據本中心設置之條例
# 第十二條及董事會議一事規則
# 第四條第一項規定
# 本中心董事會
# 應經董事人士過半數次出席時的開會
# 本中心董事11人 監事3人
# 本次出席董事9人 監事2人
# 以符合開會人數
# 依主席才是予以開會
# 請主席致詞
# 我稍微更正一下
# 我們剛剛報告的這個
# 得開會的或者是有效會議的
# 你們有講到說我們的監察人要出席
# 他沒出席的話
# 我們都要舉牌無效會議
# 跟另外一邊一樣
# 所以我們要謝謝
# 我首先就是要跟大家抱歉
# 因為我們按照這個時程的話
# 我們是每兩個月一次
# 今年我們就是偶數月
# 所以應該是在6月底之前
# 但是議會的關係
# 我們原來是排在上上禮拜
# 那勉強有過半數
# 但是臨時剛好
# 市長又有請那個國風局長
# 跟他一起去一個行程
# 所以我們那天就變成
# 會員人數就不足了
# 雖然是說有這個建國兄
# 但是還是沒辦法
# 所以我們就改到現在
# 那理論上這個
# 我們也有研判過
# 因為我們上次的監事也有律師
# 所以這個大概不是我們區域排
# 這樣也沒有差太遠
# 所以是合乎規定的
# 所以我們就在今天
# 謝謝大家會出席
# 我們是不是就按照議程來開始
# 接下來進行本次的報告案
# 本次報告案重有四件
# 報告案一
# 上次會議決議執行時提說明
# 請各位董監事參閱議程資料的第二頁
# 到第十三頁
# 及簡報資料的第五頁
# 本報告案由
# 行政部行政管理組組長曾秀鳳報告
# 跟各位董監事報告
# 在上一次的會議裡面
# 我們並沒有任何的討論案
# 相關的報告事項都依照時程在辦理當中
# 另外在本屆第二次的董監事會議裡面的討論案二
# 有關於新北市板橋區永安段14D2等
# 94筆土地的主辦機關公開評選實施整案
# 這個案件我們在上一次的會議
# 已經報告中心依照程序還報市府
# 市府也在今年的4月30號
# 以核定本中心所提的投資計畫
# 並同意由本中心主導推動以上
# 這個報告案大概就是把它的進度
# 因為上次只是說我們報告了市府
# 然後這次市府已經有同意我們主導這個案子
# 所以不知道我們各位董監事
# 對於這個報告有沒有什麼其他意見
# 如果沒有我們就加息
# 報告案一 上次會議決議請提說明
# 決議洽息
# 接下來進行報告案二
# 本中心113年5到6月重要業務報告
# 請各位董監事參閱一層資料的第14頁到第30頁
# 及簡報的第8頁到37頁
# 本報告案由各組的組長報告
# 現在先請資產管理部組長羅進玖報告
# 各位董監事午安
# 首先看到簡報第8頁的部分
# 113年度第一波辦理5+2處設宅的招租作業
# 這次收件跟審件的結果
# 總收件數是8006件
# 審查合格件數是6914件
# 其中如果扣除陽北跟國光這兩個
# 第五名單申請的件數
# 如果是以新設宅的審查來說的話
# 它合格件數是6368件
# 那我們再進一步去統計說
# 那申請設宅的人次
# 就是說它的總人數來說
# 它是2462人
# 那也就是說平均每人大概是申請2點多處的設宅
# 那目前接下來的進度是在6月26號的時候
# 已經完成了抽籤公告
# 那我們在7月份的時候就進行設宅的看選務務
# 那接下來請看到簡報第9頁的部分
# 那後續由於設宅陸續的點交
# 那我們也開始規劃六處設宅的招租作業
# 那第二波的設宅招租活動總共有六處設宅
# 那總戶數是894戶
# 那其中有公辦設宅兩處
# 包括中和安邦的632戶
# 還有行電民航的194戶
# 那另外還有龍江設宅總共有四處
# 那包括明德三號等等的四處
# 那我們預計會在8月份的時候進行公告招租
# 好 那接下來請看到簡報第10頁
# 那在設宅營運管理入住率的部分
# 那在第10頁的相次1到9的部分的設宅
# 然後還有第11頁的部分
# 10到14相次的設宅
# 那我們整體的入住率來說
# 是在93%到100%之間
# 那在相次15到18的新的設宅
# 那這個這幾處就是配合我們目前的招租活動
# 那正在進行看選屋中
# 那接下來看到簡報的第12頁
# 那在相次19跟20
# 這邊是財政局委託本中心營運的板橋
# 民權的社會住宅跟出租住宅
# 那這邊要說明的是
# 板橋民權社會住宅在今年3月份的時候
# 進行財政局委託給我們第二批的設宅的看選屋作業
# 那3月那時候開始看選屋
# 那但是在0403的地震的時候
# 那時候社區他就有發生這個三台電梯
# 其中有兩台他的鋼纜就是斷裂的這個事件
# 那後來他是到6月3號的時候才修繕完成
# 那所以入住率這邊我們就從6月份開始
# 那我們後續就是再做一個加緊辦理看選屋
# 然後預計在7月份的時候會再把這個入住率拉起來
# 那接近到9成
# 那接下來看到簡報第13頁的部分
# 那這段期間我們也是持續進行
# 農獎設宅的業務跟點交作業
# 那包括土城明德3號的11戶
# 那五湖方舟的23戶
# 泰山信華1號的14戶
# 還有新店實行3號的20戶
# 那這個部分在6月底的時候
# 我們都已經完成這幾戶的業務跟點交作業
# 那接下來看到簡報第14頁的部分
# 那在設宅營運管理的方面
# 那我們這邊也是持續精進
# 那頒定了新北設宅營運管理的SOP手冊
# 那目的就是為了要推動設宅執行人員作業標準的一致性
# 那本部門這邊後續也會將這個手冊提供給
# 委託的物管公司作為作業遵循的依據
# 而且定期辦理教育訓練跟稽核督導
# 以確保廠商他的管理執行的作業品質
# 那接下來看到簡報第15頁的部分
# 那在設宅的夜食區的相關措施的部分
# 那我們這邊進行的是設宅設置洗衣精智慧補充站
# 那本部門跟台塑生醫環保認證洗衣精的智慧補充站有洽談合作
# 那優先在大型的設宅做設置
# 那本方案可以提供給民眾便利而且便宜添購洗衣精的選擇
# 那如果說他是用這個空瓶去裝
# 在這個機器去裝洗衣精的話
# 那這個費用只要買一個新的洗衣精的三分之一
# 那另外這也配合本公信夜市區減塑的環保目標
# 那響應綠色的經濟
# 以上報告
# 好謝謝
# 接下來由中和業務一部專案組組長葉陽報告
# 各位同學大家好
# 那接下來由公辦案件來做報告
# 那首先在簡報第16頁的部分
# 那我們大城住點公共站持續的服務大城這邊的社區的住戶
# 那我們近期服務的重點是
# 大城單元三搬遷點交的補償費、住金補貼
# 以及相關所得稅所遇到的問題的一些協助
# 那另外因為現場已經架設了圍籬以及信箱
# 那我們住點的同仁又協助住戶這邊在做信件的領取以及通知
# 那另外在大城單元一的部分
# 那原本有繳交使用補償之音的住戶
# 那經過我們輔導之後
# 他們都是已經符合未來可以申購土地的一個資格
# 那後續我們會協助他們來辦理購地的一個程序
# 那另外在個案的住戶的一些資訊以及重要的資訊的說明的話
# 他們也不定時的會提供一些服務
# 那在簡報第17頁的部分
# 大城單元三在今年的4月30號
# 已經完成了252戶的全數點交之後
# 那目前現況是由拆除公司目前正在做廢棄物的清運
# 那預計在7月12號的時候
# 我們會舉辦一個拆除的動工的典禮
# 然後邀請市長一起來參與
# 那後續在正式拆除動工之後
# 我們也會用影像的紀錄的方式來紀錄整個拆除的過程
# 作為未來的一個行銷宣傳的使用
# 那在簡報第18頁的部分
# 大城單元一跟四在今年三月底公告招商之後
# 那除了住戶持續的關心進度之外
# 那在簡報之後的一些相關工作我們也有做提前的準備
# 那兩個案子分別是在6月26號以及7月11號會做結標
# 那單元四的部分已經在6月27號的時候已經完成了資格的審查
# 那在簡報的第19頁的部分
# 那樞林行政園區案
# 那目前我們會持續的配合內政部這邊的審議的進度來辦理
# 那另外有關回饋的方案的話
# 未來我們也會參考其他行政園區的一個審議的情況之後
# 再來做個案的一個處理
# 那在簡報第20頁新店中華段的部分的話
# 那原本是針對國有土地分回規劃作為社宅使用
# 那在112年的時候市府也已經向國產署申請了無償國用社宅
# 並且我們也在說明會的時候跟住戶告知說
# 未來會有社宅的一個使用的規劃
# 那現在國產署表示說要做優先評估中央辦公廳社的一個使用
# 跟委員來推動的方向有不太一致也不太符合
# 所以在今年的3月29號市府也會請中心站推動這個案子
# 那後續我們會看國產署他們這邊內部的評論結果之後
# 我們再來研擬這個推動的方向
# 那在簡報第21頁金山市場的部分
# 那我們依照預約的一個工作
# 我們在5月21號的時候已經完成了花瓶更新地區的一個核定
# 那並且我們配合市場處的一個需求
# 在6月6號的時候召開了招商的說明會
# 當天有9家廠商來到場與會
# 那我們是預計在這個月的時候會依照市場處的指示來辦理公告招商
# 那在簡報第22頁文山溪農案的部分
# 那目前正在做招商前的一個前置的作業
# 那在整合的部分的話
# 那我們土地所有權利跟違章佔用的部分都已經全數取得他們的意願的參與了
# 那另外在其中有事故的違章跟佔用的話
# 那我們也持續在跟他們做協議的溝通當中
# 那是預計在8月的時候會來做招商
# 那在簡報第23頁的部分
# 永和鼎溪案
# 目前我們先期規劃持續進行當中
# 那在整合的部分的話
# 我們在6月1號的時候有開了一個全區的大型的說明會
# 那接下來我們會持續的整合
# 整個住戶的一個意願
# 以及召開小型的座談會
# 來徵詢住戶的參與的意願
# 那預計是在年底的時候會來做公告招商
# 那在簡報第24頁板橋福州案的部分的話
# 那目前我們已經啟動了先期規劃
# 那接下來我們就會針對社區的一個住戶
# 來凝聚他們的參與意願
# 那另外我們也會定期的追蹤內政部
# 就是審核主要計畫的一個進度
# 那在簡報第25頁的部分的話
# 文山木柵案
# 那屬於是新北市有89%的土地
# 在台北市的一個境內的一個案件
# 那未來我們也是朝向以公辦都更的方式來做執行
# 然後今天的話
# 我們稍後也會在討論案的時候
# 針對這個案子來做討論
# 接下來由綜合業務二部企劃宣導組代理組長林佳良報告
# 各位董事好
# 接下來由綜合業務二部這邊報告
# 首先參與簡報第25頁
# 那首先是先針對我們偵測協助案
# 新店大溪地案的部分
# 那本案中心持續輔導社區自主更新
# 提供更新會推動方向以及法律的諮詢
# 那本案已經召開第六次專案小組審查
# 那會議結論為修正後辦理聽證
# 更新會已經在5月25號召開會員大會
# 決議排除144之1地號
# 私有公共設施用地以及選配原則等議題
# 並在6月4號申請補證展延
# 那後續中心這邊會持續追蹤補證進度
# 以及提供相關的協助
# 接下來請參院簡報第27頁
# 那同為政策協助案580危險建築物專案計畫
# 那本專案公告實施以來
# 已經辦理近70場的一個580專案計畫說明會
# 那截至6月底已經有20案申請了本專案
# 那其中包含0403鄭水蒙黃單社區總共有10案
# 將會優先協助處理
# 那另外首案新店案的這些新案社區
# 第二階段統一比例已經符合規定
# 達8成
# 那其中公辦都跟著招商作業
# 那第二案新莊民安花園廣場
# 因統一比例未達標
# 已含複申請了不續行本專案
# 但後續仍會依社區的意願
# 持續協助不老社區
# 那其餘案件的辦理進度請參院簡報第28頁
# 那接下來針對民辦已簽約案的一個案件進度報告
# 那目前請參院簡報第29頁的部分
# 首先先針對板橋文化路油庫口岸的部分
# 那本案中心協助成立更新會並擔任全案管理
# 那因為鄰近的漢堡建設整合文化路的基地
# 那該公司在4月底前已經完成林地意願調查
# 那目前只有取得少數的同意
# 所以更新會將會以原本的範圍來繼續執行
# 那更新會在5月底也完成租戶的自主更新意願調查
# 那調查的結果其實還不是很明確
# 那有部分租戶表示傾向與建設公司合建
# 而且不願意執行出資
# 所以理監事會也在商討轉公開評選持續者的可行性
# 並同步徵詢會員的一個意願
# 接下來請參院簡報第30頁
# 那新莊專訪落案的部分
# 那本中心擔任專案顧問提供法律的諮詢
# 那5到6月我們持續追蹤本案的整合進度
# 那目前同意比例還是未達法定的門檻
# 那另外因為合約已經屆滿
# 那雙方同意再續約一年
# 那接下來我們參院簡報第31頁
# 羅東長安街193巷案的部分
# 那本案中心擔任全案管理顧問
# 參與事權計畫的擬定
# 那本案已經在4月23到5月22辦理公展
# 5月7號辦理公辦公聽會
# 那預計是在7月9號會召開專案小組審查
# 接下來請參院簡報32頁
# 羅東長安街46巷案的部分
# 那本案中心協助成立更新會後
# 其實持續推動全案管理的部分
# 那以及說明帶電原則
# 但是因為更新會未能符合中心的帶電原則相關規範
# 所以更新會在5月25號
# 那更新會的會員大會決議
# 同意由中壢都更作為帶電
# 以及全案管理的廠商
# 中心擔任本案的專案顧問
# 一同協助社區完整都市更新
# 接下來請參院簡報33頁
# 新店區秀水斷案的部分
# 那本案為都市更新可行性評估案
# 那本案全區範圍都屬於三坡地
# 那已經初步的一個坡度檢討分析以及檢討作業
# 那因為全案上有需要突破的地方
# 所以經呼籲監設決議
# 那決定在委託專業的水保技師
# 進行完善的三坡地的檢討
# 那目前客棧辦理坡度檢討的一個作業
# 接下來請參院簡報34頁
# 新莊中港路中美社區案的部分
# 那本案中心擔任專案顧問
# 提供法律的諮詢
# 那本案已經在4月3號到5月2號辦理工展
# 4月11號召開公辦公聽會
# 6月20號召開第一次專案小組
# 那針對建築 骨架 還有縣有鄉道的改廢
# 以及圍管等疑慮
# 那釜鎮釐清之後 以及釜鎮之後
# 那會去排第二次專案小組審查
# 那接下來簡報第35頁的部分
# 那針對法律宣導說明會辦的情形說明
# 那截至6月29日
# 針對都更三建 蘇仁連署 海砂屋社區
# 還有里長說明會等等
# 總共辦理166場說明會
# 那約有2萬4千人參與
# 那以上是綜合業務的部分報告
# 接下來由行政部 行政管理組組長生修奉報告
# 請各位董監事參院簡報第36頁
# 在36頁可以看出來
# 我們中心為了招募人才
# 我們在4月份的時候擬定了招募的一個經濟計畫
# 除了在104的人力領航持續的將缺額來做公告以外
# 我們也化被動的主動
# 直接尋找適合的大專院校及相關的就業輔導博覽會
# 那除了4月30日到文化大學的都計學院課程上面
# 辦理招募的說明會以外
# 我們也安排了台北大學跟智里科技大學等學生來中心參訪
# 並且主動跟他們說明招募的內容
# 另外我們也參加了104的人力銀行舉辦的招募博覽會進行招募
# 然後也同步拍攝了中心的招募影片
# 在社群網站上播放
# 在簡報的第37頁可以看出來
# 我們在5到6月辦理了多場的教育訓練
# 包括了資安的課程
# 跟消防安全等相關的課程以上
# 好 那各位總監對於剛剛我們的業務報告
# 不知道有沒有什麼指教
# 不好意思 我只有一個小事
# 對業務的部分沒有意見
# 但有一個17月的部分
# 17月的部分
# 我們大成山的部分7月12號將那個拆除拍購
# 那當天的部分原則上是希望
# 因為這個是一個非常難的案子
# 也非常謝謝中心的同仁
# 那包括一個市場的拆除等等這些
# 過程都非常的辛苦
# 那在府裡面疫情會議討論的時候
# 曾經有詢問說這個案子
# 因為其實這是一個很代表性的案子
# 那我現在只想確認一件事情
# 就是目前得到的訊息不一樣
# 因為市長可能會出席那天的拆除的開工典禮
# 但是目前為止我們得到的訊息是
# 因為市長出席一定會有記者隨行
# 那有記者隨行就不可能低調
# 但是我所知道的是中心的業務單位
# 好像希望低調 擔心會有狀況發生
# 但是又問的結果是好像是說
# 因為沒有說要低調
# 那這個部分會牽扯到市長到底要不要出席
# 所以我想中心這邊會比較了解
# 如果可能會有狀況
# 那當然我們就會考慮市長的行程
# 原因就是說
# 因為我們也不知道那個狀況到底是怎麼樣
# 所以這個部分可不可以中心這邊
# 可以讓我們了解一下
# 那個實際的情況會有多好
# 各位董監事早
# 下午好
# 基本上大城山的這個拆除動工的儀式
# 我們基本上我們沒有要低調
# 中心沒有要低調
# 那目前先講這個行銷媒體的部分
# 目前也感謝警察局跟更新處這邊
# 還有我們中心自己的管道
# 目前已經有7家的這個電視台會來做採訪
# 那採通的部分
# 我們包含房產線還有市府線的部分
# 我們會全部都發
# 除此之外我們還有這個住戶的部分
# 我們也希望整個場子是比較熱鬧的
# 所以我們也在我的LINE的群組部分
# 也跟各位住戶也吸引他們
# 有發一些小禮物
# 請他們來參與這樣的一個盛會
# 那我們目前明天我們還會到現場去做
# 跟黃局長去做現場的動作
# 跟秘書長報告
# 非常謝謝那個中心的同仁辛苦了
# 因為這個訊息的部分
# 因為確實也有這樣子的一個訊息
# 是中心的同仁這邊做反應
# 我們只是要確認這個情況
# 如果因為這個案子其實是個代表性的案子
# 市長能出席
# 其實因為他一直都很關心這個案子的拆除的動作
# 好不好
# 那如果沒有其他可能狀況的話
# 原則上我們還是會建議市長
# 還是要出席那天的會議好不好
# 那只是訊息上因為當時有一點點的落差
# 所以我想說這個時間確認一下
# 因為現在現場都已經辦妻完成
# 也沒有任何的所謂的
# 會有民眾來陳情等等這些資訊
# 我們現在應該都沒有
# 所以我早上也是跟他們ReRe一下
# 這整個過程
# 然後我知道國光也會到現場去看
# 然後典禮的前一天也會才來
# 國光他們也會去
# 那唯一比較我們覺得比較艱鉅的就是交通
# 因為現在都圍起來
# 要進出到那個已經拆掉的那個市場那裡
# 所以我們也是希望是說當地的派出所
# 能夠請他們來協助
# 對交通的這個管制
# 要請他們來幫忙
# 那那個黃翔他們
# 我看他們也是投入相當多的精力
# 要來辦這個事情
# 好不知道還有沒有哪一位
# 董事來請
# 這邊有一個
# 這位PD的公認請你稍微說明一下
# 就是新店中華按鈕
# 後拆署是三位就已經含金標準要贊成辦理
# 那目前有沒有比較新的狀況
# 到底我們目前中心這邊準備怎麼做
# 因為114年現在我們把這個案子還是讓進來
# 所以到底他會不會再往返
# 這個不用解說
# 謝謝
# 關於這個案子
# 我們其實在更新處這邊
# 有跟國南署我們開一個
# 還有城鄉局這邊開一個會
# 針對他未來要做的這個辦公需求
# 是不是要續辦
# 不是更新這個案子做一個討論
# 那他們目前正在調查
# 各個機關的需求
# 預計他們時間共就是要四個月的時間
# 三到四個月的時間
# 那我們目前掌握到是我們每一段時間
# 大概是每半個月
# 我們都會跟他們的同仁去做詢問
# 看有沒有最新的一個進度
# 那如果說他們將來還是要做辦公的部分
# 可能我們這邊要跟城鄉局這邊討論
# 看看是不是要再續行這個案子
# 目前還未定
# 我想最有可能會是
# 分配的內容會改變
# 以前我們是希望設宅
# 設宅他土地的話就是無償撥用
# 我們幫忙他做這個
# 因為老百姓那個地主
# 我們都已經去整合
# 大家都已經期待
# 如果變成辦公大樓
# 那是不是變成一棟辦公大樓
# 或一棟那個住宅
# 那這個怎麼樣分配
# 那也可能會是朝這樣
# 但是他們的需求
# 等於是現在還沒有確定
# 之所以會有這樣的變化
# 我們也不方便去深入說
# 為什麼會是這樣
# 原來都講的都沒有問題
# 所以我們才說
# 這個如果是這樣的話
# 我們來做社會住宅
# 那這個土地就無償撥用
# 大概是這樣
# 所以短時間內可能
# 我看一兩個月之內
# 可能還不會說最後確認
# 不過都有在進行這個事情
# 如果做辦公大樓
# 一樣我們中心還是單位使用
# 他們一定會委託我們來辦
# 他們有地
# 但是不然的話委託
# 這個是國家住宅中心
# 不願意幫他們辦
# 找我們
# 當初是這樣子
# 這個是我們內部在這邊講
# 所以不方便講
# 現在不知道
# 突然他的用途改變了
# 才會有發生這個趨勢
# 不知道還有沒有
# 來 請
# 第36頁這裡
# 能力招募的部分
# 上次我們有討論過
# 這個薪資的調整之後
# 那目前這樣的能力招募的情形
# 有沒有因為這樣而得到改善
# 我先瞭解一下
# 還有你們多元的招募的方式
# 有沒有發現哪個方式是最有利
# 因為我對人力這個部分
# 會比較敏感一點
# 我自己都找不到
# 跟董事長
# 董事長一次報告
# 經過我們上一次的這個薪資調整
# 那另外還有一個
# 我們招聘人員的這個方式的改變
# 目前我們原本的原額是75幾年度
# 那我們後來做了一個
# 這樣的一個改變之後
# 的確有增加了一些
# 但是那個數量其實並沒有很多
# 那我們來的這個管道的部分
# 也有從台北駐都這邊過來
# 這個的確就是
# 我們當初在做挑薪的時候的預測
# 就是當兩邊的
# 這個中心的薪資結構一樣的時候
# 這些員工他們就會去做一些選擇
# 的確是有從台北市過來的
# 除此之外
# 我們有到一些這個
# 大型的博覽會去參加
# 我們也有一些員工
# 是從那邊得到我們中心的消息
# 的這個招聘的訊息
# 也有經過這樣的他們來投入這個履歷
# 那也順利的也有招到幾個
# 是從那個博覽會這邊過來的
# 那另外一個改變就是
# 因為以前的104的這種招聘的方式
# 因為我們不像公務機關
# 我們會有在有一個網站
# 我們必須透過這個民間廠商
# 一樣都是透過104
# 那104它是有一段時間
# 就是時間到我們就會下架
# 那我們這次嘗試就是一直掛在那個上面
# 就是有這個民眾
# 或是有這個人要上去看的時候
# 他可以一直看到我們有這樣的一個職缺
# 那所以我們經過這樣的一個調整之後
# 是有比較好到升到人口
# 但是跟我們目前的
# 剛剛看到我們員工
# 目前還是只有56位
# 跟我們的這個
# 中間的這個差距還是蠻大的
# 以上
# 好 不知道還有沒有哪位 來 請
# 那這個會議資料裡面
# 第18頁
# 那也有提到
# 因為上次市長在這個市政會議有提到
# 就是希望大省如果有104人
# 這個重大採購
# 未來能夠成立採購廉政平台
# 那這個部分呢
# 因為董事長也特別交代
# 我也跟執行長也聯絡過
# 所以我們就把它成立一個採購廉政平台
# 那網頁已經正式運作了
# 我覺得這個未來
# 如果有需要的議題的時候
# 再來召開這個會議
# 那原則上就落實市長的政策
# 那以上
# 對 好 謝謝
# 這個 沒問題
# 好 不知道還有沒有哪一位
# 好 如果沒有的話
# 我們這個就是報告
# 我們是不是就洽詢
# 報告二
# 本中心113年5到6月重要業務報告
# 決議洽詢
# 接下來進行報告案三
# 本中心113年1到4月
# 預算執行進行報告
# 請各位董監事參閱議程資料的
# 第31頁到第40頁
# 及簡報的第40頁到44頁
# 本報告案由行政部財務組組長吳廟芬報告
# 各位董監事大家好
# 請參閱簡報第40頁
# 本中心113年1到4月的預算執行情形
# 1到4月的收入執行率是99%
# 執行數是1億1600萬1000元
# 成本及費用執行率的部分是71%
# 執行數是4460萬5000元
# 剩餘數是7139萬6000元
# 再簡報第40頁的部分
# 是業務收入執行率的部分
# 業務收入執行率是98%
# 主要是社宅租金及權利金收入的部分
# 這邊特別說明有關貸款財政局
# 社宅及出租宅的執行率的部分是41%
# 1到4月貸款社宅
# 是用收貸戶的原則去列帳
# 因此沒有認列社會住宅收入的部分
# 因此產生了預決算的差異數
# 我們在跟會計師討論了之後
# 就是在5月份開始
# 我們會依照預算編列的原則
# 調整為收支並列的方式去做表達
# 因此未來在報表的呈現上面
# 收入跟支出的金額都會做一個呈現
# 1到4月的業務收入如果增列
# 就是民權社宅的收入的部分
# 在住宅收入的部分會有556萬2千元
# 另外停車位的部分也會有27萬4千元
# 那增列了這兩個數額之後
# 整個執行率會能夠提高到103%
# 目前就是表列的數字會增加5%
# 在簡報第42頁的部分
# 有關公辦社宅住宅收入的整體執行率是105%
# 那目前既有社宅就是相次1到7的部分
# 執行率是都在95%以上
# 那新接管的社宅是在相次第8到12的部分
# 預計在8月份開始會陸續點交招租
# 所以1到4月也沒有預算的分配數
# 在簡報第43頁的部分
# 有關榮獎社會住宅租金的部分
# 1到4月的執行率是67%
# 那接下來就是就執行率比較有落差的部分
# 做一個簡要的說明
# 相次1的部分是三峽北大社宅的部分
# 執行率是79%
# 那主要是因為有部分的房舍有漏水修繕
# 那在修繕的過程當中
# 這些社宅是沒有租金收入
# 因此會有執行率的落差
# 那相次2的部分是永和國光社宅
# 那永和國光社宅我們在2月份的時候
# 已經就是點回給社會局去做管理
# 那預算的部分也是只有1月到2月
# 那執行率是53%
# 在相次9的部分是五股城州
# 1號社宅執行率是0
# 那因為配合前面業務報告所說明的
# 就是招租作業的期程
# 預計在8月份開始可以招租入住
# 那在相次10到14的部分
# 是今年新接管的社宅
# 那因為目前1到4月
# 4月底的時候仍在業務點交跟裝修的作業當中
# 因此執行率是0
# 那後續也會配合就是招租業期程開始進行招租入住
# 那如果說我們排除掉第10到14相次
# 就是受建商延遲點交的影響的話
# 去計算執行率可以回到執行率99%
# 在簡報室事業的部分
# 成本及費用的執行
# 1到4月的執行率是71%
# 那實際執行數是4461萬
# 交易算分配數6256萬元
# 減少大概1796萬元
# 那主要大概會有三個主要的落差的原因
# 首先就是整體用人費用的部分
# 不管是在出入資產成本
# 業務費用跟管理總部費用
# 三個項目之下的用人費用
# 整體來說的執行率是76%
# 預算的分配數1到4月減少大概779萬元
# 那4月份的禁用員額是55億
# 跟我們預算原來編列的75億有所落差
# 因此就是執行率受到一些影響
# 那目前也急在進行人員的招募當中
# 第二個主要原因是出入資產成本
# 服務費用的部分執行率是74%
# 那比預算的分配數減少大概620萬元
# 主要是因為社宅物管費用的核銷有一些延遲
# 不過這個部分我們也已經在積極的辦理核銷當中
# 那最後一個原因是在業務費用的服務費裡面
# 就是跟預算分配數減少大概257萬
# 那就項目來說的話
# 主要是在於都更一些委外案件的支出
# 跟行銷宣傳費的部分跟預期有一些落差
# 那應該會在下半年的部分會去做執行
# 那6月份開始中興這邊會
# 就是按月針對全年度的執行率去做預估跟檢視
# 然後去針對各個項目必要的支出做盤點
# 希望能夠掌握就是全年度的一個決算的情形
# 以上是4月的預算執行情形說明
# 那最後那句話就是說
# 現在已經下半年開始
# 我們每個月的決算
# 他會把實際的情形以及預估未來剩下的時間
# 還可能會收入或支出
# 然後看到年底的時候可能會是正負
# 那意思就是這樣
# 從7月開始就要控制
# 這樣才不會說到了10月、11月你再來想辦法
# 要那個的話就稍微有點慢
# 好 這個我們的這個預算執行情形報告
# 不知道我們你們董監有沒有什麼指教
# 在你們會議資料裡面我詢問一下
# 第三是6月表期的部分
# 因為執行的這個期間是1到2月
# 那其他都是1到4月
# 那這個是因為談判錯誤呢
# 還是說這個表期資料是舊的
# 那製作者有分歧
# 我們財務報告的話就是會lag兩個月
# 等於是我們現在報告的都是4月
# 所以他1到4月
# 那他資料是物質
# 對啊 那資料物質
# 好 來 請
# 我確認一下就是41頁的部分
# 剛剛特別有提到
# 那個執行率41%那個部分
# 剛剛有解釋了
# 就是當時的民權社宅是用
# 執行的時候是用代收代付這樣子
# 所以沒有收入
# 那我確認一下這個114年度
# 你們的做法是怎麼樣
# 因為決算總是要跟著這個預算跑
# 114年度是怎麼樣
# 114年預算
# 明年 明年 對
# 是用代收代付的方式
# 所以明年的話
# 所以就不會編了就對了
# OK 那這樣的話就一致了
# 那就跟會議室的期待就是符合的
# 好 了解
# 好 謝謝
# 那 來 請
# 謝謝理事長
# 那個因為剛剛有一個案子
# 我們在5、6月份的中央業務報告
# 有提到板橋民權
# 是因為電梯電纜斷裂的時候產生的故障
# 所以讓我們一起到原本要入住的時間往後遞
# 所以看起來或許在5、6月或是往後
# 可能會產生這個收入會有影響
# 那我們現在回到這個1到4月的執行情況
# 剛好會遇到那個0406地震的那個界點
# 那就會 我想知道就是
# 因為這樣子現在到現在大概6月了
# 那距離地震大概兩個月過去了
# 所以像比方講我自己的社區
# 我們修了電梯就遞延了兩個月之後
# 就出現了一個十幾萬的一個費用
# 那我就不知道0406這個影響
# 有沒有原本沒有預期到的cost
# 將來可能會在5、6月或是之後
# 的支出上會出現
# 可以說明一下
# 那我這邊說明一下
# 因為我們這個板橋民權社宅
# 它是一個一般的社區大樓
# 就裡面除了我們財政局它擁有的235戶
# 它還有一般出售給一般區權人
# 大概130多戶這樣子
# 所以變成說今天裡面相關費用的執行
# 都是由這全部的區權人去做決議
# 那並不單單是由我們中心這邊去做一個
# 一個代為負擔這樣子
# 對 那基本上以電梯修復這件事情來說
# 因為目前還在保固期
# 所以這個是建商他去負責做一個修繕的
# 以上報告
# 好 那個今天我們有那個監事
# 採購處的處長他也出面的意見
# 是不是我們也可以
# 我朗讀一下
# 有關報告三的部分
# 監事這邊意見是
# 精簡式預算執行落後項目
# 表9至表11之
# 用人費用之支出執行率60%到74%
# 顯示各單位人員
# 淨用人未如期預期
# 另表9出資資產成本
# 服務費用之出資
# 會執行處達600餘萬元
# 表示業務費用
# 服務費用之出資執行率僅17%
# 除健行加速和銷作業外
# 並建議自行盤點服務費所對應之
# 委外服務費服務契約是否有延期履約情形
# 加強履約管理
# 以上
# 這個是那個業務單位還是那個
# 基本上我們跟這些物管公司的勤款
# 主要是我們的落差是在物管公司
# 他來跟我們勤款的這個時間
# 有一個落差
# 那這部分我們會請這個資產管理部將來
# 針對合約的這個勤款的時程
# 跟撥款的時程可能要密切的配合
# 這部分我們會去做加強的管理
# 那至於剛剛講人員的這個招聘跟支出的部分
# 我們也這個我想可能是大環境的問題
# 因為現在人都找不到
# 所以我們這個這筆錢
# 我也沒辦法把它花費掉
# 大概我大概是對的說
# 那個月管的那個
# 除了就是說他們申請的時間
# 還有我們審核的流程要精簡
# 以前我們做這個公共建設
# 承包商也是每月估驗
# 他估驗原則上
# 因為承包商他一定是說
# 他這家公司要開支票
# 哪一天要付錢
# 他大部分都會固定
# 所以你不能耽誤到他太多的時間
# 所以譬如說我們審核到付錢
# 大概一個禮拜
# 五個工作天到十個工作天是合適的
# 所以這個我們自己內部
# 因為你估驗的那些項目
# 基本上大概都已經固定
# 那你只要確認說他做的量
# 是不是有按照合約的規定來那個
# 那我們每一個設宅
# 我們都有一個督導的同仁
# 所以他對這些應該是很熟
# 他不要到說一定要這個月滿
# 他下個月中才跟人家開會才確認
# 他可能在第三個禮拜
# 他就可以開始去確認前三個禮拜
# 沒有問題
# 等到這個下個月初
# 他們報上來的話
# 再做最後一個禮拜的確認加強
# 這樣我們就會很快
# 按照這個公款支付的原則
# 是說不能超過五天
# 但是各個機關大概沒有辦法那麼快
# 剩五天到十天就已經是非常好了
# 我們這個應該金額也不是太大
# 因為他們每個月屋苑的話金額不是太大
# 如果公共工程
# 每個月幾千萬到上億都有
# 那項目其實項目都是固定的
# 現在他們應該也都是電腦作業
# 平常的紀錄是最重要的
# 我有跟那個他們職場管理部
# 跟他們溝通過
# 經理回來的時候
# 你們在內部討論一下
# 看這個流程應該怎麼樣
# 再來說吧
# 好 不知道還有沒有其他的資料
# 如果沒有
# 我們是不是就這個部分也洽息
# 那接下去
# 報告案三
# 本中心一百一十三年一到四月預算
# 執行情形報告決議洽息
# 接下來進行報告案四
# 本中心內部稽核業務報告
# 請各位董監事參閱一成資料的
# 第四十一頁到四十三頁
# 及簡報的第四七頁
# 本報告案由基盟專員郭麗清報告
# 四月到五月的時候
# 委託國庫號法廉會計師事務所
# 查核租金及勞務收入循環
# 那抽查色彩輸出的部分
# 都有依照規定公告還有審核
# 還有公文文件
# 那抽查的過程中
# 全程公開並且有公告
# 那租賃契約的部分也有經過公正
# 那抽查那個顛覆出入的部分
# 也有依規定公告
# 那租金抵價的訂定
# 也是有按物價指示的報告
# 還有前置標案金額許高為抵價
# 招標開標及絕標的程序也有符合規定
# 那租賃契約也有經過公正
# 那應收帳款作業的部分
# 抽查就是會計單位也有按月編制
# 應收帳款帳明分析表
# 然後也會辦業務單位
# 然後針對催收款的部分
# 那預期帳款作業的部分
# 就是屆期滿兩個月之後
# 是會催收款
# 那這個部分業務也有積極去協商
# 然後如果無法協商的話
# 也會辦那個法務單位採取一些法律措施
# 發票開立的部分
# 也有在社宅還有店鋪出租收入的話
# 也有依規定開立還有作為發票
# 然後並按期去申報營業稅
# 那銷售退回及折讓的部分
# 如果社宅還有店鋪有提前退租的部分
# 也有依規定提出申請
# 那退租的程序都有確實去點交
# 還有契約終止協議都有簽訂
# 那經抽查的作業
# 向我們發現重大異常
# 那下個月六到七月的話
# 預計要查核新工學化
# 以上報告
# 好 那對這個部分不知道我們
# 這個董經燕
# 有沒有什麼資料
# 有沒有查核報告
# 在我們那個疫情資料裡面有附
# 我再請教一下
# 這個書面資料的四十三頁
# 這裡面就是我們看他的這個
# 內部稽核報告
# 那稽核項目裡一到六項
# 我要詢問的就是說
# 我們的抽查比例
# 有沒有訂定一定的抽查比例
# 因為每一項的抽查比例都不一樣
# 那像這個第一項的社會住宅
# 抽查比例百分之二十九
# 第二項百分之五十
# 第三項百分之十三
# 第四項百分之二十五
# 第五項百分之四十七
# 第六項百分之二十七
# 那看起來這個抽查比例都沒有
# 有沒有限定最低的標準
# 他是按照什麼
# 信賴區捷運九十五的比例
# 還有說可容忍的比例去算
# 那他一定是只按照這樣的模式
# 然後可能按照圈數
# 大概說整個樣本有多少
# 就是在這個期間有多少的量
# 然後去推算出來
# 這樣看起來比例差距很大
# 像這個件數少的兩件
# 抽一件就百分之五十
# 那多的這個有沒有
# 他的公式是固定的
# 但是樣本空間不一樣
# 所以出來的結果
# 那個就會
# 就是說兩件的話抽一件
# 就是百分之五十
# 一百件抽五件
# 就是百分之五十
# 所以公式是一樣
# 就是樣本空間
# 會影響到他抽的這個比例
# 那個應該是抽查的
# 有那個抽查的那個算法
# 這個是我們新進的這個稽核
# 我們等一下會追認
# 因為那是屬於
# 等於是他的抽查結果
# 都要經過我們董事會來認定
# 所以每一次董事會我們都會報
# 大致上是
# 就是剛剛他所說明的是這樣子
# 就像我們稽查
# 可能有人會有一個最低的
# 上面的話
# 譬如說你例行的抽查
# 跟專案抽查
# 也不一定會一樣
# 專案的話就是有特殊的那個
# 在專案簽
# 那如果是例行的話
# 大概是一個最低值
# 那因為人力的關係
# 他也不可能
# 每次都超過百分之五十
# 百分之五十兩件就要看一件
# 那人力也是太那個
# 所以現在我們剛剛講說
# 有按照什麼樣的那個
# 這個信賴的這個
# 百分之九十五嘛
# 是不是
# 那基本上我這邊的話
# 或許我可能會去看一些
# 風險可能比較大的
# 或者是說力量
# 風險比較少的話
# 我可能就有可能會考慮全場
# 或抽兩件再打
# 對啦
# 因為兩件而已
# 你抽一件就五件
# 那比例是很高
# 但是事實上只有兩件
# 五十幾件抽了
# 可能抽二十件
# 當然每一件的案件的複雜性不一樣
# 好
# 不知道還有沒有其他的比較
# 如果沒有
# 我們這個部分是不是也洽息
# 報告案是
# 本中心內部機核業務報告決議洽息
# 接下來進行本次的討論案
# 本次總共有四件討論案
# 討論案一
# 本中心內部機核人員聘任追認
# 請各位董監事參閱一層資料的第四十四頁
# 及簡報資料的第五十一頁
# 本報告案由前一綱代理執行長報告
# 是不是請我們各位小姐
# 要先迴避一下
# 請他迴避啦
# 請他迴避啦
# 討論案迴避
# 我們不用看管啦
# 迴避就好
# 那等一下再請他進來
# 好不好
# 那個行長
# 這個郭小姐是我們從伊底士利一號這邊招聘來的
# 那我們去年度整年都在找這個機核業務
# 因為我們行政法人要找一個機核
# 其實不容易啦
# 因為一般來講
# 機核比較通常會是在金融機構
# 或是在一般上市櫃的公司
# 有這樣的一個職缺
# 那我們行政法人目前
# 去年度招聘了一整年都沒有
# 很高興能夠招聘到這個郭小姐
# 那她的經歷也正如這個簡報上面可以看得出來
# 她在這個生物科技公司這邊也待了十二年
# 這樣的一個資歷的部分
# 那剛剛也有在我們這個前面的
# 我們過去一年
# 內部機核都是委託國父會計師事務所這邊來幫我們查核
# 那他本身也是會計師
# 會計系畢業的
# 所以我想在未來的這個機核的工作項目部分
# 我想他應該是可以升任的
# 以上
# 那選議學經歷
# 在這邊知道
# 各位董事對於這個案子
# 不知道有沒有其他指教
# 如果沒有
# 我們是不是就通過追認
# 是哪些同仁去請他
# 討論案一
# 本中心內部機核人員聘任追認
# 決議
# 本討論案討論前
# 機核人員郭立清與
# 你還有自己的文稿
# 本討論案
# 經全體董監事一致同意通過追認
# 經全體出席董監事
# 好不好
# 這樣會比較
# 接下來進行討論案二
# 本中心110年度業務及營運計畫
# 請各位董監事參閱議程資料的第45頁
# 複冊及簡報資料的第54頁到69頁
# 本討論案由前議綱代理執行長報告
# 各位董監事下午好
# 針對本中心114年度的業務及營運計畫
# 由我來跟各位做個說明
# 本中心的發展總目標主要有兩個
# 就是自立與社會住宅的政策的落實
# 我們希望透過行政法人企業化的經營
# 來提升市有財產的經營效率
# 除此之外
# 我們會積極來推動都市更新的政策
# 建立公民營的推動都市更新的程序跟方法
# 來做為未來招商的一個示範
# 除此之外
# 我們能夠強化跟民間業者跟所有群人之間的
# 這樣的一個互信基礎的橋梁
# 在發展的四目標目標部分
# 在我們簡報裡面可以看到
# 我們第一個是實踐社會住宅的政策
# 我們會專責在社宅的招租營運的履約管理
# 保障這個市民有多元的居住的選擇
# 另外是兼顧社會住宅的品質
# 跟它的量的提升
# 來維護整個居住品質
# 來落實居住的正義
# 另外是在經營社會住宅跟都市更新的不動產部分
# 我們會持續的經營管理市府
# 所受委託給我們的社會住宅
# 另外來接受榮獎回饋
# 都市更新的不動產的經營管理
# 來活化資產的效益
# 我們預計在114年度
# 會接管的社宅達到37處
# 總共超過了近5000戶的這樣的一個水準
# 另外我們會加速來辦理主導公辦
# 來協助民辦來推動都市更新
# 以中心的角色公平公開公正的方式來推動
# 以專業的第三部門的角度
# 來擴大辦理都市更新
# 推動這樣的一個能量
# 另外我們中心很重要的一個宗旨
# 就是要推展不動產的資訊的研究跟交流
# 來提供政策上的建議
# 對於社宅的部分
# 我們會有一些資料的收集 統計 分析
# 也作為未來在興建社宅上面的一個參考
# 另外對於都市更新的資料
# 還有可行性評估的工作業
# 我們也會陪著協助市府的角色來辦理
# 積極來辦理這樣的一個智庫的角色
# 促進產官學的一個交流
# 提供研究發展的能量
# 那在業務計畫 社宅的受作管理部分
# 在我們資產管理部
# 我們對於民眾的承租
# 我們希望來考量市場的行情
# 提供只租不受的社宅
# 我們明年度會達到37處
# 那維持113年度30處以上
# 這個90%以上的這個入住率
# 另外我們在114年度
# 我們會有接管7處社宅的入住
# 跟他的這個社宅的地主簽約的相關的事宜
# 那在店鋪經營的部分
# 我們明年度會健全社會的
# 社區的生活機能
# 來提供33處的這樣的一個管理
# 那我們也希望能夠在入住率達到80%以上
# 另外我們也對於明年度新接管的這個大型社宅
# 包含國光二期
# 還有泰山中山等16戶的店鋪招租的作業
# 我們會積極的來辦
# 另外在社宅裡面還有這個公益空間
# 那我們明年度呢
# 我們會來提升社宅的服務的效能
# 達到26間
# 那配合市府各局處辦理公益空間的這個地約
# 我們希望能夠在使用率達到80%以上
# 那我們也會來積極協助各局處
# 公益空間跟承租廠商
# 還有公益藝術團體來辦理社區的互動的活動
# 來增加社宅民眾的凝聚力
# 另外在管理營運部分
# 我們希望能夠提供高效能的管理營運
# 針對這5500戶
# 那我們會導入我們在紀念度所
# 8月份7月底預計來公布的
# SOP的這樣的一個營運管理的手冊
# 來針對物管公司來做加強的教育訓練
# 跟加強的督導
# 另外我們會導入智慧化跟電子化相關的設備
# 來降低社宅的營運成本
# 另外也讓我們會做社宅民眾的家戶的
# 這個訪視的紀錄
# 針對一些特殊的觀望戶來持續的追蹤
# 那我們明年度
# 我們可以從表格上面
# 可以從59頁的這個簡報裡面
# 從110年度我們接管了9處1565戶
# 到明年度110年度的7處
# 總共有37處達到50500戶
# 那在明年度接管的社宅裡面
# 主要比較大型的社宅有三峽過光二級
# 有達到921戶
# 這是僅次於我們目前
# 相邊央北社宅的一個規模
# 這個是一個比較大的這個公辦社宅
# 除此之外還有5處的榮獎
# 榮獎的這個社宅
# 那在社宅以外的這個業務計畫
# 我們還要再做的是
# 加速推動公辦的都市更新
# 那綜合業務一部主要執行的案件有大城三
# 大城三拆除完成之後
# 記錄到實際的施工階段
# 我們會結合我們PCM廠商
# 來嚴格管理施工的品質跟進度
# 那對於大城一跟四的話
# 我們會辦理選配跟都市更新計畫的報合
# 以及在樹林案的部分
# 會持續追蹤整個都市計畫的變更的審議進度
# 來辦理後續的公開招商
# 另外在新店中華段
# 我們會等待國產署這邊完成需求評估之後
# 我們來看最後的結果
# 再來做後續的一個處理
# 另外在台北市的文山西農案的部分
# 我們會在今年度辦理公告招商之後
# 明年度來辦理選配
# 跟都市更新事業計畫全面的一個報合
# 另外在永和頂溪案
# 我們會辦理公開評選實施者跟簽約
# 來做這個履約管理
# 以及在板橋福州案
# 我們也會來辦理公告的一個招商跟履約管理
# 另外在台北市的木柵案
# 文山木柵案的話
# 我們會辦理先期的規劃作業
# 跟劃定更新地區跟招商的前置作業的相關計畫
# 那在民辦的部分的綜合二部的業務計畫裡面
# 我們執行主要執行案件有三個
# 第一個是在新莊公園一路案的合聯案
# 那目前我們是擔任專案管理的顧問
# 那工程在適逢中
# 預計在115年能夠完成
# 那達到這個實照
# 所以我們中心會擔任專案管理的顧問
# 繼續協助廠商來辦理
# 另外在蘆洲長安街
# 長安街193項案裡面
# 我們擔任全案的這個管理顧問
# 當然會來協助事權的審議跟報合的動作
# 那另外是在油庫口案子
# 目前我們是擔任全案的管理顧問
# 那我們來協來針對住戶的協調整合
# 那還有後續的專業團隊的一個遴選
# 那另外還有在新莊中港路的軍風案裡面
# 我們擔任專業的顧問
# 來提供法律的諮詢
# 來協助實施者跟未同一戶之間的溝通協調
# 做一個平台
# 另外還有在長安街46項
# 這個更新會的部分
# 我們也是擔任法律諮詢
# 那也是協助實施者跟未同一戶來做一個溝通
# 另外在思源路案的部分
# 我們也是擔任顧問案的角色
# 來做事業跟權變的這個審議跟合理的一個動作
# 另外我們在協助市府的580專案的部分
# 我們會持續來推動
# 來加速進行580專案的一個協助
# 那我們也會中心自己部分
# 也會新增受託民間推動度勢科技案
# 一到三處這樣的一個案源
# 那另外在行政部的業務計畫
# 我們對於人員的招募的部分
# 我們對於各部門的人員的需求
# 我們會做滾動式的修正調整
# 另外來辦理至少三場的內部的教育訓練
# 還有針對兩次的績效考核
# 檢視同仁的專業跟工作態度來做一個調整
# 那對於我們的財務規劃的部分
# 我們會依照我們業務的範疇來規劃營運的資金
# 那做預決算的一個編列跟執行控管
# 跟財務管理的一些相關動作
# 那定期來檢討租金的收買進度
# 那降低這個待帳的風險
# 以及在定期檢討這業務的發展
# 我們隨時都會做四年度的財務的預測
# 另外在資訊管理的部分
# 我們也會落實管理作業跟應用系統的流程
# 相關的權限 備份等相關的行政事務
# 那辦理這個資通安全的西級應該辦理的一個事項
# 那我們對於網路的部分
# 我們會透過相關的資訊來提升我們的作業的效率
# 所以在組織建構的部分
# 我們明年度還是編列75個
# 那因為因應到整個市場環境
# 人員招募不順利
# 所以我們明年度還是維持今年度的這樣的一個員額
# 就是75個這樣的一個員額
# 那各個部署的這個部署的部分
# 我們並沒有做一些調整或是增加
# 那對於住宅及都市更新的知識研究發展部分
# 在資管部的專業的知識部分
# 我們會辦理相關的物業管理的教育訓練
# 來提升同仁跟我們外站的物業管理的專業的職能
# 另外我們也會跟國內外的這個社宅相關的研究
# 來提出這個分析來做研究報告
# 另外綜合一部的部分
# 我們對於都市更新的教育訓練
# 我們會跟學界還有跟業界相關的實務經驗來做一個整合
# 那加強我們對於社區協助
# 諮詢都市更新相關的一些駐點的整合的效果
# 另外是對於國內外的都市更新的作業的一個研究規劃
# 還有資料的收集的政策建議
# 我們也都會主動的來做一個收集
# 來提供給業界來做一個分享
# 那綜合業務二部的部分
# 我們會來持續辦理都市更新法令的說明會
# 讓我們都市更新的知識能夠普及到這個市民的身上
# 那我們114年度我們希望能夠辦理
# 不能低於今年度的這樣的目標
# 至少辦理200場為這樣的一個目標
# 那對於國內外的這個都市更新的研究規劃
# 一樣我們會來持續收集相關的政策
# 來提供給都市更新處這邊來做政策上的一個修正
# 修改或是參考訂定的一個依據
# 另外在行政部裡面來講
# 是對於同仁的都市更新的專業知識的教育
# 我們會再做一個調整跟一個加強
# 另外會辦理這一場的都市更新相關的教育系列
# 來增加同仁的都市更新的知識
# 另外在國內外的研究的部分
# 我們至少會提供一次的國內外的住宅
# 以及都市更新的訊息給同仁知道
# 那每一週我們也會提供新北市政府相關的法令的修正
# 還有這個餘勤的部分來提供資訊給同仁來諮詢
# 那再來是114年度的經費的收支的狀況
# 我們在明年度的這個收支的總額是6億4千3百48萬
# 那只是比今年度來成長32%
# 另外在成本及費用的總額部分是3億8千5百5萬
# 那成長比今年度成長24%
# 那結繳支出的支出總額的部分可以達到2億5千8百42萬
# 那比今年度還要再成長46%
# 以上是針對110年度的營運計畫
# 跟各位董先生做個報告
# 好 謝謝
# 那個不知道對於這個我們的業務及營運計畫
# 不知道有沒有什麼指教
# 非常謝謝執行長剛剛對於營運計畫的說明
# 我想我們這裡還有一本完整的114年度營運計畫的報告
# 這裡面對於報告的內容
# 我個人沒有意見
# 但是有幾個問題必須要提醒
# 因為出租中心成立到現在
# 跟營運基礎之間的一個互動的關係裡面
# 包括我們當時的條例在制定過程
# 其實大家可以看得出來
# 我們自治條例的部分中心大概就是以營運等等為主
# 但興建的部分其實在議會當時是被否決的
# 但是在我們的營運計畫裡面
# 是希望將來可以執行興建等等這些
# 那到底興建等等這些事情
# 如果要爭取將來中心的話
# 那很可能自治條例的修正的部分
# 就必須要跟營運處這邊討論
# 我需不需要在議會裡面再去爭取所謂的興建的這個部分
# 讓興建跟營運可以一起
# 在這個地方一起去做處理
# 這是第一個
# 第二個早期我們在做社會住宅的定義的時候
# 其實因為我們是比較多移民的那個城市
# 因為差不多的年輕人都到這邊工作
# 所以我們把定位為青年社會住宅
# 但實際上我們現在的社會住宅不是只有青年
# 我們包括中低收入等等我們都有
# 所以在我們的營運計畫裡面
# 在114年希望將來能夠增加
# 增加接管青年社會住宅
# 這個定義的部分
# 可能在營運計畫裡面
# 我們也可能必須要定義得更加清楚
# 這是第二個建議
# 第三個建議的部分一樣
# 大概我們不管綜合業務的一部跟二部的同仁都非常辛苦
# 那因為我們現在薪資調整之後
# 我們希望營運的招募能夠更加的順利
# 那當時薪資調整的部分
# 讓人員可以招募更順利的原因
# 是因為我們的業務希望能夠擴展
# 但是還沒有到位的時候
# 當然同仁都很辛苦
# 所以在人員不斷的增加的情況底下
# 我們一部跟二部的業務的部分
# 我剛剛特別看了一下
# 114年的部分
# 還是以我們現在在執行的案件為主
# 那至於新的案件的開拓
# 跟新的案件的開發等等這一些
# 在人員逐漸的補齊的情況
# 我們希望人員可以逐漸補齊
# 因為這樣子的話人力上面比較能夠負荷
# 在逐漸補齊的部分
# 那將來的營運計畫的部分
# 實際上這邊可以更加的前瞻性的去提出來
# 我們將來不一定在114年
# 未來的幾年的部分可能有更前瞻性的做法
# 或是一些地區的開發
# 可能我們可以在這個地方可以提出來
# 那這樣子的話
# 就不會說業務上面有幾個案子
# 我們大概過去一直在執行
# 那這些案子其實不容易
# 持續的還是要把它完成
# 那新的地區的開闢的部分
# 也是希望將來我們能夠有新的案件
# 能夠逐漸的在這個地方可以擴展出來
# 所以提供這幾個給中天這邊做個參考
# 我們外面的據點
# 我們現在有那個大城山那邊有
# 那我們現在在三重
# 有一個新的據點
# 他們沒有跟我們報告
# 那邊已經開始使用
# 那主要要讓大家知道就是說
# 其實其他的局處
# 如果在那附近業務上有需要
# 也可以借用那個原來也是四五的財產
# 我們把它又重新整理又加固
# 所以花了差不多半年的時間
# 我們現在已經開始使用
# 這個可以請執行長順便也說明一下
# 回應一下剛剛秘書長的這個指教
# 我先回應一下秘書長的這個指教
# 關於第一點中興要去興建社宅的部分
# 我想目前度就算是明年度
# 我們應該也還沒有這樣的一個能量
# 除了能量應該是說人力之外的這個費用的部分
# 蓋房子的這個部分
# 因為我們中興的這個財務的制度
# 就是我們到了年底
# 我們全部都要上繳回入門基金的部分
# 所以我們並沒有年度的這個營運
# 所以如果要做自行的興建到營運的話
# 那我必須在整個制度面的一個大調整
# 除了剛剛講的法律面的修正之外
# 我可能在財務面跟這個相關的預算的編列部分
# 我都要做一個大幅度的調整
# 目前度我們應該還是比較著重在營運管理
# 如何改善這個目前營運管理的這個績效
# 那另外是在青年社宅的部分
# 那這部分跟秘書長說個抱歉
# 因為其實我自己看的時候
# 我也有發現我們同仁並沒有
# 並沒有很精準用到這個字眼
# 因為我們社宅的提供的對象不是只有青年
# 雖然這都是外來的移民
# 還有這個來台北這個就學的
# 其實我們還有一些弱勢戶跟一些高齡長者的部分
# 所以我們應該還是很歸到社會主宰
# 並沒有強烈的就是針對某一個族群去提供這樣的一個數量
# 這部分我們會去在營運計畫做一個調整
# 另外是在綜合醫療部
# 其實我們還蠻多的這種想要做的東西
# 但是真的是因為受限於能量
# 因為我們新北駐都跟國駐都還有北駐都
# 比較不一樣的是在於我們有去做民辦的部分
# 那我們民辦我們並沒有要去育民增利
# 我們主要是協助自力更新的部分
# 那自力更新當然不限於是自主更新會
# 或是說像一般的這種幫他去做顧問的角色
# 但我們是希望能夠跟更新處來做一些配合
# 就是深入到社區裡面針對這些比較危險
# 或是這些海砂屋的部分
# 我們能夠把自主更新的這個能量再放大
# 那目前我們的自主更新的這個同仁
# 因為受限我們的能力的部分
# 我們還沒有辦法到全部的整個生命週期的服務
# 只能幫他做初步的這個意見的法律的諮詢跟宣導
# 那甚至一些重點的
# 這個譬如說0403這樣的一個地震的
# 地震的這些社區
# 受損的社區
# 大概就是比較重點式的服務
# 但我們是希望說
# 能夠結合更新處的政策的指導之下
# 我們中心能夠進去到社區裡面
# 對於前面的讓他們社區有一個勞動
# 讓他們了解到怎麼來辦理更新
# 這部分我們是比較多的
# 想要在這地方做一個協助
# 那至於這個綜合一部的這個公辦的部分
# 我們其實也有一些想像是除了市府的土地之外
# 我們也想要去開拓一些
# 將來開拓一些案源
# 包含就像那個國家住宿中心
# 國產署是把他的土地交給
# 我國住都來做一個處理
# 那我們也想去找一些國公營事業
# 包含的這個一些郵政機機也好
# 或是說像這種台電公司
# 說中油他們的這些土地
# 我們可不可以來委託我們郵政中心
# 來幫他來做這個招商
# 這部分我想應該都是
# 未來我們可以去做的一個業務
# 業務方向
# 那另外回到剛剛董事長提的部分
# 我們在6月27號
# 我們在我們一大漢就是西北西南
# 因為市府這邊有分西北西南
# 那西南的業務大部分
# 我們都還是透過我們新店這邊行政園區
# 這一個主要的辦公室為來服務社區民眾
# 那未來在西北的部分
# 我們在三重原本是一個派出所的一個使用
# 那因為後來交回去給財源局
# 那我們這邊很順利跟財源局這邊爭取到了
# 那我們也做好了裝修
# 我們在6月27號已經開始正式營運
# 那我們目前有同仁已經在那邊做服務
# 那將來我們目前已經跟建築師公會
# 這邊有做一個配合
# 就是未來在每一個月
# 我們會有做法例的一些宣導
# 那提供民眾可以來詢問
# 那關於這個都市更新的相關的業務
# 那除此之外
# 我們未來在社宅的收件的部分
# 也會在西北辦公室那邊
# 來接受民眾的這個收件跟遞補件
# 那我們也會再跟我們的都跟大聯盟的各個工學會
# 來做一個合作
# 未來讓我們的西北辦公室的能量能夠放大
# 以上
# 稍微講一下那邊的空間怎麼樣
# 那我們就是局處長
# 稍微知道一下
# 如果有什麼樣的
# 他們那邊剛好有些需要
# 可以借用
# 目前我們那一個的空間
# 大概可以辦一個小型的說明會
# 那說明會的部分
# 大概就是20個人左右的這樣的一個說明會
# 那也有一些會議空間
# 那另外的話
# 我們大概是三層樓的一個建築
# 如果說未來的使用效能擴大
# 我們才會用到四樓
# 四樓的這樣的一個空間
# 我們目前大概就是主要是用在一樓跟二樓
# 那三樓的話
# 目前是做我們自己治療的一個方式
# 謝謝
# 不知道還有沒有其他的指教
# 不好意思 我再補充一下
# 那個
# 因為我們這個是114年度的業務跟營運計畫的報告
# 是因為剛剛
# 剛剛你的報告裡面有特別提到
# 積極的興建
# 興建跟營運社會住宅
# 我那時候聽到有點嚇到
# 就是說興建的部分
# 他是用來嚇我們
# 是已經開始要去爭取興建
# 因為這畢竟是114年業務報告
# 我想目前為止我們大概確實是有困難
# 但是其實這是個未來的事
# 以後到底中興要不要走到那個程度
# 我覺得這個是以後是可以討論的
# 那當然如果走到那個
# 所有的財務等等機制跟制度裡面
# 必須要做一個翻新
# 那包括對銀行的貸款等等
# 融資等等這些
# 基本上大概就不會以現在的預算去做執行
# 所以我剛特別仔細的聆聽一下
# 因為114年的報告裡面
# 我突然聽到興建的時候
# 所以我想這邊確認一下
# 那第二個部分是在資訊的應用上面
# 我們現在目前
# 最近非常夯的AI的部分
# 因為我們非常多的說明會
# 大概都靠同仁到現場去做很多的說明
# 可是AI的應用某種程度上面
# 在這個資訊的應用上面
# 它其實可以協助我們
# 做很多類似這樣的工作
# 可以減輕同仁的困難
# 那我們將來在這方面資訊業務的推展上面
# 我覺得可以嘗試看看
# 能夠有一些新的這樣子的一個做法
# 因為畢竟AI在應用上面
# 確實有它的一定的一個趨勢
# 所以提供給中興這邊做個參考
# 我們已經有在規劃
# 這個部分很感謝秘書長的意見
# 我們預計在今年底
# 今年底我已經找AI的廠商
# 來討論一下我們中興有哪一些的業務方向
# 可以走AI的協助
# 讓我們的同仁可以降低一些工作的壓力
# 包含了因為民眾常常都會打電話來問
# 一些社會住宅的資訊
# 還有都市更新的一些資訊
# 我們希望能夠透過AI的一個角色來扮演
# 這部分我們預計在今年底會推出一個東西
# 我們再來跟董介石做個報告
# 我們昨天的青森會
# 吃了公家的食物
# 我們也有請我們受訓的同仁來講受訓的內容
# 因為有兩個是報AI的
# 所以這個確實是同仁也有意識到說
# 現在的時代已經進入到這個
# 我們有重複性的這些知識的傳播的話
# 靠這個AI確實是可以節省很多的能力
# 那那個孫教授是不是有要想要指導的
# 我現在沒有舉手
# 沒有舉手啊
# 那你的頭一直
# 就是剛聽各位這個董介石在吹熊的時候
# 我就不斷的在思考
# 想釐清
# 後來我們看資產負債表
# 所以我一直很想知道我們到底有多少資產
# 後來發現我們只能放這裡面
# 我們只有那個什麼包彩圖
# 那後來猛一看好像有三台車
# 所以我們資產負債表裡面
# 看了一下每年只有大概22萬的交通運輸設備
# 只是剛一直翻
# 因為沒有看到真正的資產負債表
# 所以就沒有看到我們到底有多少的資產
# 只看得到就是一年
# 我們114年度可能就是會
# 折舊團體22萬的交通運輸設備
# 所以我在猜應該就是這三部車的折舊
# 那可能回去我再看一下以前的會議資料
# 因為在目前今天的資料裡面
# 沒有看到我們資產負債表
# 我剛剛是在思考就是說
# 我們中心如果沒有固定資產這麼多的話
# 我覺得是好事
# 因為一個地震來我們所有的資產都變
# 那是很可怕的話
# 就是房子如果都倒了
# 那很顯然就是看起來
# 我們有點像是買工賣工
# 就是管理啦
# 財經局講說我們是空殼公司
# 那如果是這樣子的話
# 我們整個就是看cash flow
# 就是我們的現金流
# 就是收入跟支出出去
# 那我們中間有一些資產可以管理
# 所以可以維持收入金
# 然後我們的預算的支出出去
# 但倘若什麼樣的原因
# 比方講有一個地震
# 然後我們所有的可以管理的資產
# 突然被鎖住了
# 但我們支出還是得給
# 就是我們所有人的支出還是給
# 就不知道那個buffer
# 到底是
# 這個可能可以想一想
# 可能跟今天討論無關
# 比方講突然一個地震來
# 然後我們10%或20%的那個
# 要管理的資產突然不能動
# 雖然我們沒有
# 不是我們的資產
# 所以我們沒有折損的問題
# 那可是很顯然的
# 我們的整個量能
# 收入的量能就會
# 突然會減少30%
# 可是我們支出還是會
# 還是必須有
# 那那個缺口就我們中心來講
# 我們到底要怎麼設計
# 或者是到時候就基金再撥補給我們
# 如果整個機制是這樣子的話
# 那應該還算ok
# 就是說我剛剛是不斷在
# 在思考這個問題
# 這個問題我們大概幾年前就開始思考
# 那我們發現就是說
# 我們可能要先從
# 這個life cycle裡面
# 社宅維修的
# 因為隨著時間的話
# 它會有
# 會出現一些時間
# 它需要比較大的資金來修
# 譬如說電梯
# 譬如說開始外面的那個
# 要拉皮等等這些
# 這個制度要怎麼樣
# 我們是把這個每年的盈餘
# 是不是放一些板筆
# 在我們成立一個基金
# 就像你講的基金
# 萬一碰到什麼樣的時候
# 這個可以拿來周轉
# 應付那個狀況
# 到底會需要怎麼大的規模
# 我們現在是先開始從這個
# 這個life cycle裡面的修復
# 你這個修復的錢
# 如果說你沒有平常
# 這個把它儲備起來
# 到時候我們
# 第一個你要預估說
# 今年是要邊修什麼東西
# 很難抓
# 你突然要用的時候
# 那你預算沒有
# 那就等於要跟明年
# 或者是我們也沒有
# 預備金的這個概念
# 所以現在有請
# 那個政大的教授
# 也來幫忙我們
# 我們是台科大
# 台科大教授抱歉抱歉
# 我是台科大的
# 有請他們幫我們
# 建立一些模式
# 那從這個我們再來看看說
# 以我們現在知識條例
# 跟現在運作
# 我們怎麼樣跟主計處也好
# 或者是我們的財政局也好
# 怎麼樣來建立
# 一樣這樣的這個系統
# 萬一碰到像地震的這個時候
# 我們可能需要
# 有一個足夠的這個周轉金
# 來做
# 那現在目前是這個
# 這個構想我們要量
# 因為剛剛那個
# 行政長官有報告說
# 我們都會做四年的
# 財務的這個預測
# 那現在怎麼樣
# 說收入跟支出
# 因為隨著這個社會住宅
# 接管的這個增加
# 所以我們收入也會增加
# 像明年我們收入
# 會增加百分之三十二
# 百分之三十二我們支出
# 只增加百分之二十幾
# 但是我們回繳的話
# 會比這個增加百分之三十二
# 還要多
# 所以說像這樣有餘裕的時候
# 是要全部都先回繳
# 然後到時候需要的時候
# 再來申請還是再怎麼樣
# 還是我們有一些百分比
# 先再這個由我們來管理
# 成立一個基金
# 這個也可以說
# 從我們董監事裡面
# 再選這個基金管理的委員
# 這也是一個
# 也可以做完
# 照人家那個公司一樣
# 上市公司一樣也有
# 這個是我們已經想了很久
# 但還沒有定案的事情
# 報告董事長
# 我剛剛在想的是
# 因為沒有資產就沒有風險
# 對
# 所以我本來是在想
# 如果我們這房子是背在我身上
# 那我們應該是要去保險
# 因為有資產就有風險
# 目前看起來除了車子跟那些設備之外
# 我們是沒有資產的
# 所以那就是房東的事
# 就是新北市政府的事
# 所以其實我在思考的是
# 如果by contract
# 我們有點像包租代管的公司
# 如果包租的是這十年
# 那十年裡面的修繕費
# 是要我自己付
# 那我們可能就要編在裡面
# 看看要累在哪裡
# 因為我們不能有盈餘
# 可是它一定要parking在某個地方
# 另外一個是
# 如果我們的合約跟市政府合約是
# 我們這部分我們就包租代管
# 舉凡什麼東西壞了
# 我就找房東
# 那就是市政府
# 就是資產所有人一定要出來買
# 包租代管好像比較簡單
# 對
# 那這樣子就要跟市政府講
# 設宅的時候
# 以後什麼東西壞了
# 一定是你修
# 我們住宿中心我們只保
# 就是只做包租代管
# 可是這兩件事一定要先確認是哪一個
# 如果是資產是在房東身上
# 就是新北市政府
# 那我們只做包租代管
# 那我們這個過程中
# 就是cash flow in跟out
# 我們就balance就可以了
# 可是如果我by contract
# 是15年或20年
# 可是這中間過程某些東西壞了
# 歸我管
# 歸我修
# 那這個部分可能就跟通商長一樣
# 我們就必須把這個錢parking在某個地方
# 可是又不能算是盈餘
# 變成是未來要付的一個
# 未來應付帳款的一個暫存區
# 那這個就必須設計
# 那如果現在跟房東還沒有講清楚
# 那可能就是要思考什麼時候把它講清楚
# 否則一旦東西要修了
# 那就他會說我們住宿中心要修
# 可是我們會說你是房東
# 新北市政府也要修
# 那到底是誰編這個錢來修這樣
# 我發那時候房東還是我們建國修
# 現在這個
# 其實教授剛剛講的蠻遠的
# 其實現在這個房東是誰
# 這個房東是我們那個城鄉局
# 對 就是市政府
# 你看那個
# 你就看這張表
# 收入跟成本
# 後面有一個那個結繳
# 對結繳
# 結繳
# 其實結繳那部分的話
# 你去看這本書的話
# 其實它寫的不太一樣
# 但事實上
# 事實上
# 內容是一樣的
# 那因為結繳那部分其實也是放在成本與費用裡面
# 所以你看那個
# 21頁有沒有
# 我們這本21頁
# 你看那個成本與費用
# 這邊跟這邊的成本與費用
# 差了兩億多嘛對不對
# 那個兩億多那部分
# 事實上就是我們結繳
# 城鄉基金兩億五千多萬
# 大概就是那個數字
# 那剛剛教授提到說
# 未來房東到底要不要繳
# 事實上如果是說
# 今天
# 當然今天還沒有跟房東談好
# 就是說未來如果是說
# 真的這個東西談好的話
# 是由房東來負責的話
# 那這邊的那個數字就會動了
# 你那個結繳那部分的話
# 可能會少一點
# 這邊的成本與費用的話
# 那邊可能會多一點
# 那這個就是
# 大家如果談好的一個結果
# 是這樣一個概念
# 不過現階段我就覺得這個問題還不會發生
# 為什麼
# 因為你這個支出有沒有
# 那個結繳的房東
# 城鄉基金那個部分的話
# 有兩億五千多萬
# 所以這個數字的話
# 還不會說到達那種已經
# 已經很危險很風險
# 很高價的一個地步
# 但是那個教授這麼一個長遠的
# 我滿佩服的
# 這個一個概念非常非常好
# 那個讓我們
# 這個讓房東也知道
# 他未來
# 城鄉局可能
# 城鄉基金這部分
# 是不是未來要
# 這大家可以再坐下來
# 做一個討論 做一個思考
# 對啊 我們就想要怎麼樣來啟動這個
# 這個大家來談這個事情
# 總是說要比較清楚
# 跟各位董監事報告
# 其實在第一屆董事會的
# 第一次的會議上面
# 我印象很深刻
# 就董監事有提到說
# 在我們的這個機制裡面
# 並沒有針對
# 社宅的設備去做這個
# 做準備
# 因為一個社宅裡面有
# 我們直接講電梯好了
# 電梯可能十年
# 二十年之後一定要開換
# 那一台電梯都是一百萬左右
# 那有這麼多的社宅的時候
# 那個中心依照我們的機制
# 我們全部都要上繳
# 那我們是不是應該要
# 提前做分年的這個提列到
# 一個剛剛董事長講
# 也許是一個基金
# 或是一個準備金的部分
# 那講完那一次之後
# 其實我們一直都放在心上
# 那我們終於在去年的時候
# 我們有委託台科大跟
# 這個成大的建築系的這個教授
# 針對我們目前手上的
# 大中小的這種
# 三種類型的社宅
# 去做長期修繕計畫
# 把當初
# 強取在做社宅發包施工的
# 這個費用的部分
# 每一項的資產去做一個盤點
# 在什麼時候會壞掉
# 大概什麼時候會發生
# 大量的這個預算
# 可能要做編列的時候
# 做一個model
# 那我們在目前已經算出來了
# 我們大概每五年
# 可能要去做一次
# 這個費用的一個提列
# 做一個準備
# 應該說一個準備
# 那我們預計大概就是
# 我們希望能夠在明年之後
# 開始去做這筆經費的一個提撥
# 因為我們開始針對
# 社宅的這個營運
# 大家都知道已經上軌道
# 我們知道什麼時候
# 應該會發生什麼樣的一個費用
# 那剛剛主席處長這邊有提到
# 就是說我們目前上繳的部分
# 還算是可以支應
# 未來我們突然發生的一些
# 這個東西的一個損壞
# 或是必須要做重置
# 那至於說
# 那個資產的這個
# 這個登記的部分
# 的確我們只有三台車
# 但是相關的這些登記的部分
# 都還是由我們的房東
# 就是江局這邊來管
# 我們只是代管
# 但是將來我們修繕完成之後
# 那就變成是我們的資產
# 那另外保險的話
# 我剛才詢問同仁
# 保險的部分
# 目前都我們有在做保險
# 我們有做保險
# 好 不知道還有沒有幾項
# 來 康康剛剛講
# 剛剛因應這個我們孫教授提的
# 我想請教一下
# 就是說這些社宅
# 目前到底是登記在城鄉局
# 是歸城鄉局的資產
# 還是歸在都更基金的資產
# 因為如果是在都更基金的資產的話
# 它就會有所謂的
# 折舊的一些編列
# 所以這些以後的最後修繕
# 應該是在他的基金裡面會修繕
# 來 第二個 城鄉局
# 知道嗎
# 包租貸款的所有所謂的一併是
# 應該是就是
# 因為我本來就是要看
# 我們的這個舊房子到底能賺多少
# 可是資產不在我身上
# 城鄉局報告
# 目前社宅是登記在市府
# 但是管理機關是中興
# 所以中興是管理人
# 但是我們就是無償提供給中興
# 去做收益
# 對啊 因為它是包租貸款
# 所有權益一定是承擔
# 跟各位董事電視報告
# 就是我們在那個財產跟市府
# 就是城鄉局會計師這邊的配合
# 就是我們每個月會把
# 就是財產攤平折舊的數字
# 結算出來之後
# 提供給會計師
# 你們去做市府折舊數的認別
# 所以整個市府是有財產的
# 那個折舊師在市府那邊去做攤平
# 所以他會算到基金那邊去
# 所以他所有權益是他
# 所以他那邊也會有折舊的
# 折舊就是有一個
# 重置成本的一個概念
# 所以基本上的話
# 他是市府
# 是房東社會來負責的
# 那另外一種方式
# 如果房東重置成本
# 他不處理的話
# 那就是由你們那邊去調整
# 腳步數在那邊調整
# 然後這邊再來處理
# 這也是第二種方式
# 不過看樣子的話
# 剛剛是所有權那邊來負責
# 那個比較貪心就是說
# 你確實是需要用
# 你就把它用
# 用完了以後
# 看還應該回繳那個剩餘
# 譬如說這是兩億五
# 因為什麼理由
# 我們多花了一億
# 只能夠繳一億五回去
# 那你就說明理由
# 為什麼今年只能繳一億五回去了
# 大概是這個概念
# 所以我們的金國兄
# 就叫我們現在不用太擔心
# 我這邊還有一個小問題
# 請我們中心這邊釐清一下
# 就是在我們114年的營運計畫
# 第18頁裡面
# 1580專案是目前有10案在申請
# 可是在我們的議程資料裡面
# 22頁聽到是目前已經有20案申請
# 所以到底是10案還是20案
# 這個封卡要怎麼寫
# 應該是20案
# 因為我們114年營運計畫是比較早編
# 那58年是最近一直陸陸續續都有進來
# 所以我們會選擇
# 所以這邊是20案
# 就是簡報的是20案
# 還有沒有
# 我是想說那個
# 剛剛提到那個社宅租金的部分
# 那因為我們今年新北市的社宅
# 開始有那個分級租金
# 那過去我們的社宅的租金的收入
# 其實比較好去估算
# 是因為社宅的一般戶優先戶
# 他的租金的折扣其實是
# 就是戶數跟那個租金其實會比較是固定的
# 那現在的話就會變成因為分級租金的關係
# 會等到入住之後
# 才會去呈現說我這一處的社宅
# 他的租金大約會落在多少的收入
# 那因為我們剛好就是這兩年
# 可能有一些戶數比較大的社區
# 所以我在想說他的那個租金收入的那個計算
# 會不會因為這樣子的調整
# 就是說我在今年在設定這個收入的話
# 會有一些差異
# 那這個差異也許可以有一點準備
# 就是說我們現在估的收入其實是還滿高的
# 可是確實不確定說
# 我們實際入住的那個住戶的那個收入
# 他的租金會落在哪一個層次上面這樣
# 所以這個部分
# 這個我們可以說明一下
# 我們現在是怎麼樣預估
# 這確實是一個很好的問題
# 那資產管理部這邊說明一下
# 就是當初局這邊在年底這個促進分級制的時候
# 那也有委託外部的顧問公司
# 那就目前社宅租戶的一個
# 實際上他們的收入的資料
# 那去做一個研擬說
# 那日後變成如果走租金分級制的時候
# 他對於這個租金收入的影響數會到多少這樣子
# 那我們在編列114年預算的時候
# 有去參照他這個研究的成果
# 那他初步抓的大概是在7%
# 會影響到7%
# 會短少7%這樣子
# 那我們在預算編列的時候
# 就把這個其他的數字就先把它考慮進去
# 那後續當然實際上上路的時候
# 這個一定還會有一個波動在
# 那我們也會把今年度
# 這個分級促進制他實際上上路了以後
# 那跟我們原本預期的一個落差的情況
# 再把它做一個明年度預算編列的一個參考
# 以上回覆
# 這個可能確認一下
# 但我依稀記得的是這樣子
# 就前幾天我們在北市住都的時候
# 開會的時候
# 好像是市政府針對租金差額的部分
# 他是編了一個預算當成補助款
# 然後百%進來
# 所以住都中心我們本身的成本
# 會影響
# 就是多少
# 所以我們這邊這樣是很清楚的
# 只是因為老闆嘛對不對
# 市政府或市長他想要給大家多少優惠
# 那你就市政府那邊要去編預算
# 那編預算之後樓好進來
# 我們這邊才會stable
# 就是說我們是在營運嘛
# 就是你不能你開著支票
# 然後我幫出代管
# 我來降租金
# 那這樣子帳會亂掉嘛
# 所以我記得會是這個樣子
# 就是北市府針對於租金降低的部分
# 他是提列一個預算補進
# 那我們這邊就是營運
# 那當然有多我還是繳回去嘛
# 那用這樣的方式看起來是比較清楚
# 那否則的話就是執政團隊會
# 就是很開心的開支票
# 可是我們這裡差額的部分
# 由我們這邊去調整
# 那永遠會算不清楚我們的成本
# 就是營運成本跟整體的收入支出的一個關係
# 反正我們這邊有多賺我們還是不會繳回去
# 所以就看用哪一個方式去做
# 請問一下你說的是哪個市政府
# 台北市政府
# 我們支持他
# 這個部分我再補充說明一下
# 台北市的那個市政府補貼的那個部分
# 只有台北市有一部分的一個低收入戶
# 然後他原來住的是平價住宅
# 平價住宅那一個部分
# 那那個部分他收的租金
# 他的繳的租金就非常的少
# 每一戶非常的少
# 那那個的
# 那可是住宅中心這邊要收的部分的租金
# 是一個額度
# 那這個部分由社會局整個補貼給
# 住宅中心
# 我是覺得我們
# 這個分級的這個還有一點
# 我是覺得我們的收入
# 平常都有結餘
# 所以我們自己能夠那個
# 而且事先編的時候就有考慮到那個
# 那個是7%
# 大概7%
# 差不多是這樣
# 我覺得我們新北市政府
# 就不需要額外再有本益算再編那個
# 因為這個倒回
# 用剩的還是要繳回去
# 盈餘的部分還要繳回去
# 只是說真的不足的時候
# 就是那個基本營收繳回款那個部分
# 再來跟那個我們的房東
# 再來跟他討論
# 今年度因為是怎麼樣
# 所以就會短少多少錢
# 當然這樣就比較好
# 這樣就可以了
# 因為我們的老人
# 不是老人啦
# 這個進勞卡的部分
# 昨天李副市長來我辦公室聊天
# 他講到說你都催他去領那個進勞卡
# 對啊他說
# 要把他用光光
# 我說我們編益算
# 其實也沒有編滿
# 還是很多人都
# 台北市也用
# 不可能編滿
# 因為很多人就是沒辦法用
# 都用三分之一
# 他有的缺陰我們一定要通知他
# 不然就會發生沒通知又來抱怨
# 他昨天就是去板橋市公所
# 辦這個然後到我辦公室來聊天
# 還有特別談到說
# 我們社會局
# 一直逼他進來
# 480點要用完
# 你知道多少錢嗎
# 如果編組的話
# 那不得了那是補貼
# 那不得了耶
# 這個我們參考
# 我們應該已經有在因應了
# 應該我們的現在收入
# 還沒達到的收入
# 如果真的是不行的話
# 我們等於是從基本營收那邊
# 來調解
# 包括我們所講LiveCycle
# 裡面的重大的秀
# 那個才是我們可以想看看
# 什麼時候啟動跟我們房東
# 跟我們財主單位可以來討論
# 至於說我們現在包租貸款
# 不過那個比較單純
# 反正財政局他是房東
# 所以他會負責
# 我們等於是說
# 供錢
# 跟他供錢
# 貸付給我們不會上
# 好 不知道還有沒有什麼
# 請大家指教
# 林監事這邊有書面意見
# 針對業務及營運計畫四
# 114年度工作計畫一
# 第六項的國內政策建議之內容
# 總統提及社宅管理流程項目
# 建議實際研究規劃時
# 能按所欲解決之管理問題
# 有採取執行力措施
# 具體提出研究細項
# 這個
# 那個
# 我們目前中心有針對
# 用戶評估還有
# 社宅這些住戶在使用上
# 有沒有什麼問題
# 其實我們每一年度都會做一個檢討
# 還有問卻的部分
# 我想這部分我們會跟
# 也有一些可能會跟
# 這些研究單位來做看怎麼樣去做配合
# 作為未來在政策在制定
# 還有在興建
# 社宅的時候的一個參考
# 那這部分我們會去做一個加強
# 我們已經差不多
# 今年第四年
# 大概會碰到什麼樣的問題
# 比較清楚的可以
# 初步的列出一些
# 這個研究
# 覺得說可能還可以更進一步
# 去精進
# 去了解那些研究案
# 那另外我們
# 收集的這些資料或是我們問卷的資料
# 等等是國家住宿中心跟
# 台北市的他們也是
# 因為現在住宅管理的單位
# 都有定時會有聯誼
# 他們也是蠻期待就是說
# 我們的這個資料可以
# 跟大家分享那我們也很願意
# 這個可以
# 三個中心
# 目前就新北市就是我們
# 我們管理的最多
# 因為國家只有林口而已
# 台北市只有逛市
# 才今年度開始
# 那目前是我們的經驗最豐富
# 那我們定期這三個中心
# 大概每半年會有一次
# 大型的這個研討會
# 會針對社宅管理上面
# 的一些問題做一些
# 交流
# 我們最近得了兩個獎
# 也順便跟我們
# 董監事報告一下
# 一個是社宅管理一個是那個
# 那個
# 雖然說獎牌是我們自己出錢去買的
# 出錢給他們
# 幫我們做的
# 那個叫什麼
# 國家卓越建設
# 國家卓越建設獎
# 那一個得
# 金獎就是我們央北社宅
# 一千多戶
# 那另外一個是
# 我們大城
# 更新單元三
# 是都市更新規劃類的
# 特別獎因為在
# 整合上面
# 目前公辦都更案並沒有像我們這個案子
# 有這樣的一個
# 做法
# 是不是也報告一下
# 上次會議有一個特殊的個案
# 後續處理
# 打官司的那個
# 那個有
# 說明一下
# 我們跟社會局跟我們合作
# 圓滿解決
# 那個
# 應該是剛剛那個
# 董監事問到的應該是
# 受攬社宅的那個無知一戶
# 的那個部分
# 後來我們的處理方式就是
# 我們跟社會局這邊
# 有達成一個協議
# 就是說他是用一個專案的方式
# 他等於說他不是
# 他現在不是我們社宅的一般的
# 主股那他是用一個
# 專案的方式做一個案子
# 因為他們家的這個
# 他的承租人就是母親的部分
# 他就是年事已高
# 而且他也沒有辦法做一個移動
# 所以我們接下來就是會用
# 一年一簽的方式然後去
# 去評估看他是不是
# 他的狀況是不是還是
# 繼續適用這樣的一個
# 專案的方式然後每年就再做
# 重新的訂約
# 這個評估的部分社會局會幫
# 原則上就是服務
# 那個年紀大的
# 也要讓他
# 身體或者因為
# 這個沒有住搬來搬去
# 他那個環境有改善嗎
# 安全有改善嗎
# 對他裡面的那個環境
# 我們還是要求
# 基本上這個租戶
# 他還是不希望我們進去做訪視
# 因為他還是
# 他本身態度上還是有一些
# 堅持對那這個部分我們也是
# 比較轉向說
# 有一個設公司他進去
# 跟他做一個訪視跟了解這樣子
# 然後再把裡面的狀況再跟我們做一個
# 一個交流
# 對所以
# 真的是各局處配合
# 是蠻重要的
# 所以人的部分是繼續安置在那裡
# 對
# 但是他的公安問題如果他還是
# 肯處理的話這個公安對這個
# 整個社宅來講還是一個
# 潛在的
# 特別提醒他
# 這個部分
# 因為我們還是有一個
# 訪視的機制在
# 變成說他們現在是
# 比較不同意讓我們
# 去做訪視
# 我們社工這邊比較可以
# 一個協助跟關懷的角度
# 進到他的屋內
# 那我們也會去了解說他目前是不是有一個
# 比較改善的一個狀況
# 跟他新的企業上面是有要求
# 合約上面是有訂定
# 如果有違反公安消防那些的話
# 就必須要
# 就是終止合約的這個部分
# 往以前來講我們住戶都是
# 三年以前
# 那現在住戶就是一年以前
# 那配合社工的這個機制定期的訪視
# 那社工也會回報給我們的
# 中心的同仁讓他知道說
# 現在裡面的這個狀況
# 那這個社工的時候進去之前
# 我們也會跟他做一個保持聯繫
# 這樣子來定期的訪視
# 所以這個訪視的一個
# 機制可能就是要請
# 社會局這邊的社工人員
# 譬如說去的時候
# 可能有一些拍照
# 或什麼你要傳給我們
# 跟中心這邊
# 他才能夠去掌握他到底會不會影響公安
# 那才能夠掌握到
# 要不然的話
# 處理上還是要有一些技巧
# 我想剛剛委員提的這個
# 當然我會交代我們同仁
# 不過至於拍照這個部分
# 我們要來處理
# 不見得一定要拍照
# 如果我們透過過程可以協助他
# 我覺得不應該一定要求要拍照
# 要達到效果就好
# 達到效果就好
# 基本上來講
# 他經過這一次事件之後
# 他的態度其實是有改變的
# 因為他認為
# 他如果到外面去住
# 他可能也住不到這麼便宜
# 那他可能因為媽媽也年事已高
# 身體有一些問題
# 所以他也覺得說
# 就稍微收斂一點
# 所以我們目前
# 跟物業管理他之前的態度比較差
# 那現在的態度是有些比較收斂
# OK 還有沒有其他的建議
# 如果沒有這個
# 就通過
# 財務
# 明年的
# 文字部分需要修改
# 再做最後的確認
# 討論案二
# 本中心114年度
# 營業物及營運計畫
# 經全體出席
# 皆是一致同意通過
# 並授權住都中心
# 依照會中建議文字修改
# 後續依
# 新北市住宅及都市更新中心
# 設置自治條例規定
# 報新北市政府備償
# 先下來進行討論案三
# 本中心114年度
# 預算案
# 請各位董監事參閱
# 依存資料的第46頁
# 複測及簡報資料的第72頁
# 到77頁
# 本討論案由行政部
# 財務組組長吳妙慧報告
# 各位董監事
# 大家午安
# 請參閱簡報第72頁的部分
# 下述你
# 本中心114年的預算案
# 本中心114年的
# 預算書呢
# 會依照新北市行政法人
# 預算編制注意事項規定
# 已經完成編報
# 有依存資料的複測
# 會前我們已經送請
# 城鄉局會計師以及主計處
# 預做審查
# 有關社會住宅當年度營業收入的部分
# 會依照新北市住宅
# 及都市更新中心
# 盈餘回繳
# 城鄉發展基金辦法
# 去計算營收繳回款
# 以及盈餘結繳基金的部分
# 我們的預算會以
# 收支平衡為原則來進行編列
# 那以下僅就
# 114年收支概況
# 再要進行報告
# 在簡報第73頁的部分
# 是114年
# 預算收入跟
# 成本費用編列的部分
# 那收入跟支出
# 的部分是統合
# 為六億四千三百四十八萬一千元
# 較上年度
# 四億八千六百七十四萬一千元
# 提升了百分之
# 三十二點二
# 在簡報第74頁
# 是有關於收入的部分
# 114年的預算總收入
# 比113年的
# 預算數增加了一億五千六百七十四萬元
# 那各項收入的部分
# 勞務收入
# 是一億兩千五百一十一萬六千元
# 比113年度
# 增加了兩千四百三十三萬元
# 六千元
# 成長了百分之二十四點一
# 那這個部分會依照
# 前面業務計畫的說明
# 各個都更案件以及受託
# 財政局委託就是
# 涉宅營運的服務收入的部分
# 依照就是
# 規劃的作業行程進行
# 那在租金離權
# 歷經收入的部分呢
# 金額是五億一千一百五十二萬兩千元
# 比113年度增加了
# 一億兩千七百五十六萬一千元
# 成長的比例是
# 百分之三十三點二二
# 那目前的話
# 我們的規劃是依照114年
# 受託的三十處的
# 一個受託管理的
# 社會住宅入住率都能夠維持
# 達到百分之九十以上
# 以及在114年
# 新接管的設宅
# 開始進行委託接管營運的部分
# 那其他業務
# 收入的部分呢 預算數是
# 三百八十四萬三千元
# 那去年度沒有編列預算
# 那這個部分是
# 我們針對目前就是
# 社會住宅一些行動電話機房的
# 使用收入
# 依照規劃進行編列
# 那在財務收入的部分呢
# 預算數是編列三百萬
# 是隨著
# 就是社會住宅營運的
# 那個戶數的增加
# 那我們針對設宅跟停車位
# 會收取押金這個部分呢
# 作為一個
# 就是一年期的定存
# 去做規劃 那這個部分呢
# 會有一些支息收入
# 整體評估下來會比113年的預算
# 會增加大概過近百萬
# 在
# 簡報第75頁的部分呢
# 針對支出的部分做說明
# 那支出呢我們會包含
# 有成本、費用以及
# 結繳數的部分
# 那就上面的四項
# 就是各項成本跟
# 費用的部分呢
# 因著
# 業務收入的增加會有一些增加
# 的比例
# 那就是
# 包含在公司資產成本、業務費用
# 以及管理及總務費用、財務費用等
# 合計的金額
# 大約是佔總支出的百分之六十
# 那剩餘的百分之四十
# 的部分呢就是
# 結交款的部分
# 那總額是包含基本營收小本款
# 跟營運結交的部分
# 總數是兩億五千八百四十二萬八千元
# 那這個部分呢
# 就是我們在
# 就是會議資料提供之後
# 有發現就是
# 數額有一些不值的部分
# 那依照
# 就是基本營
# 就是結繳犯法的計算
# 實際上應該是
# 基本營收小本款應該的數額是
# 兩億五千六百零八萬三千元
# 跟我們
# 所提供的會議資料
# 兩億五千五百九十二萬八千元
# 會增加了十五萬五千元
# 那同時呢
# 也會影響到就是
# 營餘結交的部分
# 因為我們整個收入支出的計算
# 是以平衡預算來編列
# 所以呢營餘的部分就會同步減少
# 十五萬五千元
# 那這個部分呢就是要請董監事同意
# 中心予以修正
# 那因著
# 租金及權利金收入的增加
# 一百一十四年的
# 基本營收小本款是
# 就是兩億五千六百零八萬三千元
# 那比
# 一百一十三年的增加數是
# 八千兩百五十三萬兩千
# 那成長的比例是
# 四十七點五
# 跟簡報的資料會有一些差異
# 那另外在
# 簡報第七十六頁的部分呢
# 是本中心
# 近五年來的收入跟支出的
# 一個執行
# 那從中心
# 一百一十年成立以來
# 經過五年的持續的成長
# 那一百一十四年的
# 預期的收入大概會是
# 比一百一十年的預算收入的
# 大概四點八倍
# 那收入的增加率是
# 指數也會持續的增加
# 在簡報第七十七頁的部分
# 有關固定資產
# 改良擴充的部分呢
# 一百一十四年的設備擴充
# 在上面的
# 動產廠房設備的部分呢
# 主要是
# 配合農甲分肥
# 設宅的一些
# 試裝工程
# 冷氣的設置跟熱水器的
# 安裝這個部分
# 還有就是採購會用的平板
# 等等的支出
# 那在無薪資產的部分呢
# 有兩百萬的部分
# 是針對官網的優化
# 去做一個規劃
# 那以上是我們一百一十年
# 預算摘要的一個報告
# 看看有沒有什麼
# 什麼指教
# 如果沒有的話我們是不是
# 可以
# 監事這邊有一個意見
# 勞動一下
# 一百一十四年預算需求
# 是否已充分對應
# 所提出一百一十四年業務
# 及營運計畫
# 以及各項收支用
# 預算需求必要性
# 與合理性等
# 提報前再自行檢視
# 並過去年度
# 收支執行實際數與
# 編列數有重大差異項目
# 提醒於一百一十四年編列
# 作業要充分考量
# 避免再發生
# 請執行長參考
# 有沒有什麼指教
# 對這個目前編列的
# 這個預算的部分
# 我們有意見
# 可是我有一個要強調
# 我們的這個資料裡面
# 從我們的
# 這個預算的資料裡面
# 二十六頁這邊
# 我們住宅租金收入的話
# 是四億多
# 那我們的這個
# 各處設宅物管的
# 費用的話
# 是兩億多
# 那是大概佔到百分之二十五
# 就是物管佔我們住宅收入的
# 這個部分
# 我猜清楚
# 就是說這樣子的
# 物管費
# 是合理
# 或者是
# 剛剛我們在那個
# 相關的這個
# 我們下年度的這些營運計畫裡面
# 有講說要導入智慧化
# 電子化設備
# 可以降低這設宅管理責任
# 那將來針對我們這些的
# 設宅漸漸的越來越多
# 達到一定規模以後
# 是不是達到規模
# 將近或怎麼樣可以降低
# 或者是這些的
# 電子化設備
# 降低的
# 這個費用
# 物業管理
# 現在佔百分之二十五是蠻高的
# 對
# 有哪一位要
# 跟總監事報告
# 就是
# 我們的向來就是物管費用
# 其實算是我們
# 為於設宅其實蠻大宗的
# 一個成本
# 那包含就是
# 現地的那個保全人員
# 跟物管箱的那個部分
# 那另外就是說目前我們
# 在就是
# 目前就是物管費用
# 這個部分我們有談過
# 就是針對機電的一些維修
# 保養的部分也都涵蓋在裡面
# 還有設宅的一些
# 植栽的部分
# 所以其實
# 例行性的維修的部分
# 現在目前就是放在物管費用
# 所以他的那個
# 加上這幾年就是針對人事成本的提高
# 所以目前我們在
# 物管費用的邊界上面
# 確實有比就是前兩年要增加一些
# 那其實也是反映到
# 人事成本的提高
# 目前的平均這個
# 旅賓的管理費大概是多少
# 我們有賣這個數據
# 管理費也是包括在這個裡面
# 管理費有包括在租金裡面
# 對 管理費是在租金裡面
# 對 差不多佔多少錢
# 這個部分我們可能
# 要再做一個細算
# 就把這個物管費用再攤算到
# 裡面去看這樣子
# 董事的意思是說我們現在佔四分之一
# 成本大概佔四分之一
# 就是物管費用
# 那好像是稍微高了一點
# 那如果說我們含
# 那些要算
# 就是比較的基礎要把它弄成一致的話
# 這樣才會比較那個
# 這個可能我們回去可以再
# 進一步把它分析
# 因為我們現在那麼多年
# 應該是可以更進一步的
# 那這個是後續
# 新的標案出來
# 或者是說續約的時候
# 這個都可以做為我們那個
# 招標的這個基礎
# 這是管理上是可以
# 就是說假設我們每一瓶
# 收一百塊
# 我多少錢我不知道
# 那如果我的物業管理的
# 支出是一百二十塊
# 對 那我們就虧本了
# 就虧本了
# 現在應該
# 因為還要付
# 我們的薪水等等
# 沒有那麼多
# 這部分我會後之後
# 我會跟資產管理部這邊來做一個分析
# 那基本上我們目前
# 社團並沒有收管理費
# 如果用管理費的角度
# 的確剛剛阿雪董事
# 提的這個想法
# 我覺得是可以去討論去分析的
# 就是我們目前
# 我們其實是租金
# 租金裡面
# 含管理費
# 租金的架構
# 有一定的算法
# 管理費也有一定的算法
# 所以這個我覺得我們經營的
# 越來越多的時候
# 那這個部分應該要
# 要好好複習
# 好
# 好 還有沒有
# 那請
# 這一點大概也是請教
# 就是跟會計商多嘗試怎麼做
# 比方講我們四十一頁的固定資產
# 擴充明細表這裡
# 我把建物改名拉了兩個
# 一個部分是這個管線包覆工程
# 這邊大概是
# 一千兩百萬左右
# 然後另外一塊是這個門窗
# 跟防水修繕
# 這邊是七百多萬
# 那就現金來講
# 我們就是付掉
# 只是你把它列為我們資產
# 然後再去折回來
# 可是基本上是
# 就是說主體不是我們
# 那修
# 可能你也搞不清楚修哪裡
# 所以你財產還真的不知道
# 貼哪裡對不對
# 所以就這個部分來講
# 就我們中心的管理
# 是要把它當成一次性支出
# 就支掉
# 還是必須掛一個帳
# 建物改良
# 不會再折舊了
# 這個應該是
# 那一直掛著也不是個事
# 因為
# 這看起來可能還是會折吧
# 你如果這樣的話
# 理論上是會折到
# 所以到底要不要掛帳
# 這是我一直在看這一頁的想法
# 就是說其實也不多啦
# 就兩千萬
# 那修完之後
# 有時候修修補補
# 你還真的不知道去補哪一行
# 所以它就會形成一個
# 對我來講是一個支出
# 那不知道會計上很習慣的是
# 會把它列到一個固定資產
# 然後就掛在那個帳上
# 因為畢竟那個房子不是我們的
# 那這是我的疑問
# 跟董事說明一下
# 就是針對建物改良這個部分
# 我們當初就是也
# 就是在客戶使用上
# 也跟會計師做了很多的討論
# 因為畢竟建物的主題不是中心的
# 可是它的金額又達到一定的規模
# 那在會計師的認定上
# 他也沒有辦法
# 就是同意我們在當年度
# 把所有的費用在年度裡面去做一個認列
# 所以針對這個部分
# 他其實給我們的金額
# 用一個建物改良的客戶
# 然後他實際上是
# 比照財產的方式
# 就是看體數
# 所以我們目前列了這兩項
# 第一項是針對就是融價
# 分回社宅的就是初期的一些建築的部分
# 那第二個項目是
# 我們就是
# 如同剛剛金導有提到
# 我們跟那個學界
# 那邊有討論過說
# 依照大中小的一個社宅的
# 皮膚起來我們大概在明年的時候
# 能夠規劃的一些
# 大型的修繕的一些
# 那整個就是估下來
# 我們現在立即要處理的
# 我們就先
# 就算編列的方式把它編入
# 未來的規劃
# 來一次我們就這樣的一個執行
# 所以他有他們
# 他們的辦法
# 這個會計師
# 好不知道還有沒有其他指教
# 這個是不是
# 這個部分
# 是不是應該
# 監察你們這邊應該可以協助一些
# 因為事實上這個
# 預算的費用只能編一個地方
# 那如果我們這邊編了
# 都更基金那邊應該就
# 沒有這一筆
# 所以這個部分
# 他只是結語的部分
# 講回去的話才有
# 但是他事實上要折舊的時候
# 他就有一些所謂的
# 所謂的維護成本的部分
# 所以這個部分應該是說從
# 我們的預算裡面
# 怎麼樣去區別
# 不然重複編列應該
# 到底是我們這邊來編還是
# 城鄉局的那邊
# 應該反正
# 往往出在養生上
# 你不夠的最後還是有基金那邊來支應
# 應該是說
# 在哪裡使用在哪裡編
# 只要有一致的做法就可以
# 就是要有一邊要處理
# 對啊一邊處理
# 了解一下看有用
# 我剛剛的意思是說
# 其實是一次新支出已經支出去了
# 對啊
# 然後你這邊
# 到底要貪二十年還是三十年
# 就是一個門窗防水工程
# 比方講他讓我們折
# 那就等於在
# 帳上還要再掛十年
# 但是這個cash flow已經付出去了
# 只是好像感覺
# 我們有一個固定資產
# 在那裡
# 那對我而言
# 還是
# 我們要真正
# 得到一個資產
# 跟會計師再討論一下的確
# 剛剛教授講得不錯
# 修完
# 不應該是不動產
# 會計師有
# 會計師一定有他的道理
# 他會有他的一個會計的原理原則
# 因為修上
# 在會計的角度裡面
# 他有分什麼
# 他有分大修跟小修
# 小修的話當費用
# 大修的話我們這邊有那個會計
# 大修的部分他可以延長
# 耐用連線的部分他把它當資本
# 那他這個金額
# 他來看的話他看出說他是不是可以延長
# 他的耐用連線
# 或者說他金額達到某一定的一個金額
# 的情況之下
# 那他就是他的固定成本
# 就不是上一次的費用
# 我想那個會計師他一定是有這樣的一個概念
# 他們有討論過嘛
# 會計師就是要這樣
# 金額大的要這樣
# 要這樣弄
# 五塊以後這個會裂一百
# 就是這種中間就會裂
# 項目
# 但是沒關係
# 他說會延長壽命的他會這樣
# 跟那個
# 虧損認列一樣
# 那我另外提一個
# 就是
# 一個是小問題
# 就是說我們現在按照我們的
# 行政法人法還有按照
# 中興的這個自治條例裡面
# 特別有規定說
# 什麼樣的條件之下
# 你就只要送市府就好了
# 不用再送議會審查
# 那是不是可以建議這邊標註一下
# 讓所有的董監事知道一下
# 114這個預算到底要不要送議會
# 在這邊
# 不然董監事可能不知道這個東西
# 到底要不要送
# 應該是不用嘛對不對
# 因為裡面有50%嘛對不對
# 所以找個地方標一下註明一下
# 其實我們這東西
# 你們放心
# 這個東西我們到時候不會送到議會去
# 送到去那邊被討論之類的
# 這個註明一下
# 你是要讓議員放心還是
# 讓我們放心
# 讓我們現在做的董監事稍微放心一下
# 這個部分我們114年
# 依照我們的設置自治條例
# 未定的
# 只有是送市府備查
# 不需送到議會
# 這個註明一下
# 就是後續我們在簡報的時候再提醒一下
# 對 以後就讓董監事知道一下
# 把他塗黑了
# 謝謝
# 好
# 如果沒有其他意見的話
# 我們還是決議
# 如果有錯誤的
# 剛剛有講的那個就是我們
# 其實是超過那個級距
# 他忘了說這個級距
# 要變成70
# 因為我們是累積的級距
# 那個級距的話
# 那部分的話就是要回繳的比例會增加
# 但是最後那個級距
# 他沒有把它分出來
# 所以少了15萬
# 這個城鄉局的那個幫我們看出來
# 所以我們就15萬
# 那個部分我們還是要再修訂一下
# 討論案生本中心114年度預算案
# 經全體出席董監事一致同意通過
# 後續爐溫涉及重大改變
# 而有誤寫物質
# 明顯錯誤或新北市政府建議修正者
# 授權本中心予以修正
# 並依新北市住宅及都市更新中心設置自治條例規定
# 報新北市政府備查
# 接下來進行討論
# 本中心擔任台北市文山區木柵段一小段912D號等24筆土地
# 公辦都市更新實施者案
# 請各位董監事參閱議程資料第47頁到48頁
# 複測及簡報資料第80頁到102頁
# 本討論案由綜合業務與部專案組主展業養報告
# 這個二樣的報告
# 各位董監事大家好
# 現在由綜合業務來報告一下
# 這次提報的公辦都市更新案
# 那今天簡報公安總共分為五個部分
# 首先在簡報第82頁的部分
# 那我們這個案子的基地是位在台北市文山區的九康街
# 以及秀明路一段的交叉口旁邊
# 那土地面積大約是1816平方公尺
# 那在簡報第83頁的部分
# 那我們基地內總共有24筆的土地
# 所有權的單位有22人
# 那產權的部分
# 公有土地佔了89%
# 私有的部分佔了11%
# 那在簡報第84頁
# 那我們基地內只有一筆合法的私有建築物
# 只是一個人持有
# 那在簡報第85頁的部分
# 那我們是依照文山區的一個都市計畫所載的一個內容
# 那我們全區都是第三種的住宅區
# 那在簡報第86頁
# 那基地現況的部分
# 目前的話多數都是以一層樓的一個老舊建築物為主
# 那大約有14戶
# 那合法建築物只有一戶
# 那增建的部分也有佔用到計畫道路上面
# 那接下來說明一下容積獎勵的部分
# 簡報第88頁
# 那目前我們依照整個基地的規模以及條件
# 那我們預計會去爭取整個容積獎勵到48.23%
# 那在我們容積獎勵評估過後
# 那我們在簡報的第90頁的部分
# 那我們參考了周邊的一個市場的行情
# 那我們在15年內的一個住宅的產品的部分
# 目前的銷售價格大約是61到67萬一平
# 那新成屋的部分大約是在65到75萬一平
# 那平均大約是70萬
# 那在簡報第91頁的部分
# 那我們剛剛講到依照基地的條件
# 算出了建築的量體
# 以及未來的銷售的一個面積
# 那目前我們大概預估是在
# 銷售面積大約是2840平左右
# 那在整個量體的部分
# 預計是規劃在地上15層
# 地下3層這樣子一個規劃
# 那在簡報第92頁的部分
# 那我們有初步以住宅產品來預估
# 未來更新後的一個價值
# 所以我們未來整個案子更新後
# 大約會創造大約21.36億的一個
# 一個更新後的總價值
# 那在簡報第93頁的部分
# 那共同負擔的部分的話
# 我們目前依照規定
# 計算大約是9.96億的一個成本
# 那所以我們目前依照這樣子的成本的話
# 共同負擔比例大約是46.63
# 那我們在依照了整個基地的一個條件
# 那我們有模擬了幾個
# 開發上面的一些課題
# 那第一個課題是
# 我們未來是需要經過台北市政府審查
# 選定我們整個基地為公辦都更的一個案子
# 所以那我們建議是後續我們會
# 依照台北市的一個公辦都更實施辦法
# 來辦理事宜性的評估
# 來選定我們整個基地為公辦都更案
# 那完成之後
# 我們後續還有發訂更新地區的一個作業
# 那這樣子作業完成之後
# 後續我們就可以來做招商
# 那在簡報第96頁
# 第二點的課題的部分
# 那我們後續會擬具
# 事宜性的評估來送審的時候
# 我們會了解更新單元
# 除了事宜性檢討之外
# 那周邊的林地的一個居民的意願的調查
# 我們也會去做一個調查
# 那避免是造成林地
# 他沒有辦法去做都更的一個情形
# 所以我們後續依照相關的規定
# 我們會去徵詢林地的相關授權
# 並且剛剛說明說
# 整個公辦都更的一個程序
# 以及推動的方式
# 那在簡報第97頁
# 第三個課題的部分
# 因為我們基地景林的987地號
# 在我們簡報上面的圖上的範圍三這個部分
# 它是面積只有67平方公尺
# 那依規定它是被認定為是基林地的部分
# 那後續我們建議說
# 我們去在整合的階段
# 我們去徵詢這塊基林地的所有權人
# 他的參與意願
# 那如果他沒有納入這次的更新單元的話
# 那我們後續會依照規定來做調除
# 那在簡報第98頁的部分
# 那第四點課題
# 本案基地景林988的地號
# 在簡報的上面
# 我們有標示範圍四的一個部分
# 那這個範圍是道路用地
# 那所有權人一樣是新北市政府的財政局
# 那因為遭到佔用
# 導致這個計畫道路沒有辦法去做完整的通行
# 那我們後續是會建議說
# 這個這一塊988的地號納入在我們更新單元之內
# 並且我們會跟佔用人來做協議
# 讓這個計畫道路能夠順利的來開發的通行
# 那在簡報第99頁第五點的課題的部分
# 那依據我們現場的勘查的結果
# 那其中有14筆的門牌
# 是有跟新北市政府財政局有租約
# 租占的一個關係
# 8筆有做一個租賃的契約
# 6筆有做一個繳交使用補償金的一個情況
# 那所以我們目前這個基地範圍內的租占的狀況
# 可能會影響到我們後續的一個案件的一個推動的期程
# 所以我們建議說在前期階段的時候
# 我們會去初步的去調查這個租戶的餐飲意願
# 那我們同步的會去檢核說
# 這些舊違章的建築物的一些資格
# 以及它的面積的測量
# 那我們在招商之前能夠順利的先跟這些數目達成協議
# 那後續的一個實施價位跟時程的話
# 那我們經過這次董事會通過之後
# 那我們會開始做一些林地調查的一個作業
# 後續就會提送到台北市做一個公辦都會事宜性的評估
# 劃定更新地區取得中興單位實施者的一個資格
# 那在程序完備之後
# 我們就會啟動整個先行規劃的一個作業
# 以及招商的一個程序
# 那我們是預計在115年底來做招商
# 那在簡報第102頁的部分
# 那在實施架構的部分
# 我們將後續中興取得了實施者的資格之後
# 那將由中興來擔任前期的一個規劃整合
# 以及拯救出資人 專案管理等等的這些工作
# 讓我們整個案件能夠順利的一個推動
# 以上為本次友善物價案的一個報告計畫
# 好 我們看我們董介師有沒有什麼要指教的
# 這個位置不錯啦
# 那個應該還會 這樣子還會再往上
# 好 來 請
# 我贊成這個案子
# 那這個案子其實基本上也算單純
# 所以那個我們是到115年12月才公告招商
# 我覺得這個期程也許可以檢討再往前移
# 好 謝謝
# 還有沒有答案 那離政大很近
# 其實這件事情我們新北住宿中心當實施者
# 我們想說更新完
# 因為我們想要看到的故事
# 完成交付之後怎麼處置或處分
# 其實是一個很大的重點
# 那我們新北住宿中心去當實施者
# 弄完之後當社宅 社宅住的是台北市的
# 那算你新北市的社宅
# 這個是財政局的
# 對不對
# 如果是財政局那他就是收益或是處分
# 對不對
# 那如果是這樣子的話
# 我在想說我們新北住宿在這個過程中到底
# 因為我們看收入
# 到底是哪一塊勞務收入
# 還是哪一部分的收入會挹注到我們
# 就是去run這個project
# 那當然是我們自己按照平台自己去做
# 所以如果我們不管交付之後的事
# 那就是我們新北住宿就是去跟財政局談一個deal
# 然後去變成我們的勞務收入
# 是這樣
# 那如果回到財政局
# 那他回給我們比較划算
# 還是回給其他單位可能會比較划算
# 這個就會是走到另外一項
# 那另外一點我在看那個部分條例第12條
# 他到底是在講該管政府直轄市或縣市政府
# 可以實施都市更新的方式
# 可是我們今天跨區了
# 所以是不是用這個12條
# 我剛剛也一直在思考
# 因為我從來沒有思考過這個問題
# 就是說他寫的是我直轄市
# 我新北市
# 然後我怎麼在我新北市裡面
# 有就是官方主導的都市更新
# 可是我們今天是新北市要划到台北市
# 因為那是我的地
# 去做這些事情
# 是不是適用12條
# 我可能這陣子我再思考一下
# 或許這是沒有問題是對的
# 所以OK
# 那我知道我們就是去跟財政局
# 然後去收勞務收入
# 然後就談一個deal
# 然後就放這個更新案
# 那最後就會看我們跟財政局收的這個錢
# 我們的cost的支出
# 會不會至少balance或是小賺一點
# 那如果是這樣的話
# 可能是大賺一點
# 跟教授說明一下
# 大概兩個事情
# 第一個是依照更新條例第12條
# 我們那個有一張表
# 第101頁
# 目前依照法律的規定
# 的確不是新北市政府同意
# 新北駐都中心擔任實施政策
# 台北市同意新北駐都中心擔任實施政策
# 所以這個法律上是沒有問題
# 然後第二點就是剛剛講的
# 我們中心擔任實施者
# 那我們獲取什麼樣的一個報酬
# 基本上就跟大城山一樣
# 我們沒有分房子
# 因為沒辦法擔任名義上的這個
# 實際上的實施者
# 出資換折抵這個樓地板面計畫
# 我們基本上來講
# 我們就是跟未來的投資人出現之後
# 我們收取權利金
# 就是工程管理費的一部分
# 作為我們的大半費用
# 這一年來的這個大半費用
# 我們已經有另外一個案子
# 也是在新榮路附近的
# 也是有台北市政府也同意我們擔任實施
# 至於說財政局違給他自己做
# 還是說他違給中心哪個比較好
# 其實基本上應該回到市府的政策
# 因為住都中心成立的宗旨就是
# 未來的話所有的公辦
# 應該都會回到我們住都中心那邊
# 來推這個公辦的主政這樣子
# 至於剛剛那個阿雪董事問的說
# 可不可以縮短時程
# 我們也希望
# 但是因為這案子就是考量到
# 因為在台北市
# 那必須依照台北市的這個
# 他的程序必須要做適應性的分析
# 那台北市是比較
# 我們沒辦法去做
# 但我還是會去跟他們做
# 保持這個聯繫跟溝通
# 希望能夠加速
# 同意我們擔任實施這樣的一個時程
# 因為這是我們的盈餘
# 我們也是會回繳到
# 回繳到我們的土耕基金
# 如果是委託外面的話
# 他就賺走了
# 所以我們是更新會的
# 原來這個案子
# 記者的條件不錯
# 我再補充說明幾點
# 因為剛剛我沒有發言的一部分
# 因為除了我是董事以外
# 我也是福利秘書長
# 所以剛剛孫老師
# 大家在討論那個攤體择就
# 等等相關的問題
# 到底是從房東還是從中心這裡
# 是從府的立場來講
# 對外來講
# 我們會有一個答案
# 一定會有答案
# 他不會重複去編列
# 但是這裡面也顯得到財政局
# 租屋中心 城鄉局
# 工作上的協調
# 我想那個董事長
# 那個陳副他也是福利的
# 我想最終一定會把這個部分
# 只是現在因為
# 畢竟租屋中心成立
# 現在的社宅的部分
# 還沒有到營運管理
# 營運的部分
# 或者是維護的部分
# 大量的相關的支出
# 但是這個問題
# 其實在裡面都會心裡有底
# 這個將來勢必會把它做一個
# 整個的釐清
# 我想這個絕對沒有問題
# 那至於這個案子的部分
# 原則上因為我們以前
# 興隆已經有個案例
# 是有一點那個財務分析上面
# 給中心做個參考
# 你們預估這裡
# 你們有看一下
# 實價登錄的時候
# 這是15年之內的房子
# 大概70萬
# 我想蘇老師跟阿許這邊
# 應該是很清楚
# 我至少到目前為止
# 附近新蓋的房子
# 我沒有聽到70萬的
# 但我聽到的三個新的案子
# 是三位數的
# 昨天的新聞
# 是三位數
# 所以我們估價的部分
# 跟那個恐怕
# 不要落差太大
# 不然當然對中心的信心會
# 那個實際上估價的部分
# 而且他那個也是預售的
# 就在對面
# 那也是預售的
# 所以這個其實就像
# 對 這個恐怕在估價的數字上面
# 可能要稍微分析
# 降鐵在那邊
# 哇 那一大片
# 他不知道要蓋什麼
# 降鐵那個是
# 是公司的社宅
# 然後公辦屏東
# 然後底下因為跟
# 也是公辦屏東
# 跟鐵路
# 跟鐵路混合在一起
# 所以
# 我們這個是實價登錄的資訊
# 聽說是要上百萬
# 現在幾乎都三位數
# 這部分我們跟品廠報告
# 還會再做招商前的那個
# 可能一切評估的時候
# 我們會重新的
# 針對這個資訊調查
# 對 純粹是我們內部的這個
# 對 針對我們做調整
# 好 不知道還有沒有什麼比較
# 好 如果沒有的話
# 林監事有一個建議
# 印象
# 就是本案推動五項課題
# 尤其私有土地
# 所有權人 住在居民
# 過期離地 所有權人等
# 協調事宜甚為關鍵
# 如已有錯誤接洽結果
# 請與會中補充說明
# 這個就是邊我們大臣
# 跟那個我們辦理的
# 都是同樣的單位
# 兩個月的那個業務報告
# 我們會針對個案的地方
# 都會重新做報告
# 好
# 那我們就
# 決議吧
# 討論案是
# 本中心擔任台北市
# 文山區木柵段一小段
# 9121號等
# 24筆土地公辦都市更新
# 實施者案決議
# 經全體出席
# 董監事一致同意通過
# 依新北市住宅及都市更新
# 中心設置之日條例
# 第五條規定報請新北市政府
# 核定
# 接下來進行臨時動議
# 不知道各位有沒有什麼
# 臨時動議
# 如果沒有我們今天會議到這邊
# 不好意思 差不多兩個小時
# 今天會議到此結束
# 謝謝董監事的參與
# 再見
# 謝謝大家 請請
# 這件事是極大難題啊

# %%
with open(f"/Users/mai/Downloads/0704錄音1_16000hz.txt", "r", encoding="utf-8") as f:
        transcribed_text = f.read()
        print("\n轉錄文本:")
        print(transcribed_text)
# Out:
# 轉錄文本:
# 高中 嘉義中學
# 沒有啦 他是學長
# 學長 有一個留紙一下
# 小中是大一屆
# 大一屆 46年
# 他都叫他學長
# 那不是同學了嗎
# 小中就是這個都沒做
# 連這個你都知道
# 他們同年為什麼是學長
# 太不謙虛了
# 那他跟那個林董是同年
# 同年嘛 跟那個
# 蘇秀賢啊
# 對 所以林董也是叫那個
# 小中阿伯也是叫學長
# 叫學長 嘉義中學
# 是喔
# 好吧 我們就先開始
# 林董在那個地下室準備上來了
# 你怎麼知道
# 同仁有回報
# 那是要先開始嗎
# 你馬上準備上來 我在等那一張
# 那個沈記長 陳惠敏
# 也是嘉義中學的
# 他也是嘉義中學
# 嘉義 我不知道嘉義中學
# 我認識他 我不知道嘉義
# 他們都叫他
# 陳惠敏比較大
# 他是44年
# 他的那個氣質跟祐賢有點像
# 他是44年是不是
# 44年大兩屆
# 是不是嘉義中學的
# 嘉義 他是不是嘉義中學
# 好像是喔
# 如果不是嘉義中學
# 那附近有的會去台南
# 不然就要跑到彰化 台松
# 我確定他是嘉義
# 嘉義
# 應該也是嘉義中學
# 季老頭的腳
# 我那天突然發現
# 我們那個文化局局長
# 他讀的國小
# 跟我讀的同一個國小
# 高雄
# 我很少碰到國小的學妹
# 很少很少
# 哪一屆 你說誰
# 文化局局長
# 張嘉義
# 市長叫我去那個
# 華誼的那個
# 在那個中環的那個
# 叫我上去
# 他們還會見會 聊天
# 高雄市還是高雄縣
# 高雄市
# 來了
# 不好意思喔 來太慢了
# 沒有
# 還沒處理媒體事件
# 還沒處理好
# 就趕快跑來
# 對 最近最辛苦了
# 還沒處理好
# 那個酒店花生那個是
# 他也是安可經理
# 他媽媽不知道受到什麼刺激
# 不是那個 是另外一個
# 另外一個
# 那個是學校
# 學校端的
# 看他能不能辦理
# 好 我們如果過半了
# 我們就開始
# 新北市住宅及都市分析中心
# 第二屆第四次董監事會
# 依據本中心設置之條例
# 第十二條及董事會議一事規則
# 第四條第一項規定
# 本中心董事會
# 應經董事人士過半數次出席時的開會
# 本中心董事11人 監事3人
# 本次出席董事9人 監事2人
# 以符合開會人數
# 依主席才是予以開會
# 請主席致詞
# 我稍微更正一下
# 我們剛剛報告的這個
# 得開會的或者是有效會議的
# 你們有講到說我們的監察人要出席
# 他沒出席的話
# 我們都要舉牌無效會議
# 跟另外一邊一樣
# 所以我們要謝謝
# 我首先就是要跟大家抱歉
# 因為我們按照這個時程的話
# 我們是每兩個月一次
# 今年我們就是偶數月
# 所以應該是在6月底之前
# 但是議會的關係
# 我們原來是排在上上禮拜
# 那勉強有過半數
# 但是臨時剛好
# 市長又有請那個國風局長
# 跟他一起去一個行程
# 所以我們那天就變成
# 會員人數就不足了
# 雖然是說有這個建國兄
# 但是還是沒辦法
# 所以我們就改到現在
# 那理論上這個
# 我們也有研判過
# 因為我們上次的監事也有律師
# 所以這個大概不是我們區域排
# 這樣也沒有差太遠
# 所以是合乎規定的
# 所以我們就在今天
# 謝謝大家會出席
# 我們是不是就按照議程來開始
# 接下來進行本次的報告案
# 本次報告案重有四件
# 報告案一
# 上次會議決議執行時提說明
# 請各位董監事參閱議程資料的第二頁
# 到第十三頁
# 及簡報資料的第五頁
# 本報告案由
# 行政部行政管理組組長曾秀鳳報告
# 跟各位董監事報告
# 在上一次的會議裡面
# 我們並沒有任何的討論案
# 相關的報告事項都依照時程在辦理當中
# 另外在本屆第二次的董監事會議裡面的討論案二
# 有關於新北市板橋區永安段14D2等
# 94筆土地的主辦機關公開評選實施整案
# 這個案件我們在上一次的會議
# 已經報告中心依照程序還報市府
# 市府也在今年的4月30號
# 以核定本中心所提的投資計畫
# 並同意由本中心主導推動以上
# 這個報告案大概就是把它的進度
# 因為上次只是說我們報告了市府
# 然後這次市府已經有同意我們主導這個案子
# 所以不知道我們各位董監事
# 對於這個報告有沒有什麼其他意見
# 如果沒有我們就加息
# 報告案一 上次會議決議請提說明
# 決議洽息
# 接下來進行報告案二
# 本中心113年5到6月重要業務報告
# 請各位董監事參閱一層資料的第14頁到第30頁
# 及簡報的第8頁到37頁
# 本報告案由各組的組長報告
# 現在先請資產管理部組長羅進玖報告
# 各位董監事午安
# 首先看到簡報第8頁的部分
# 113年度第一波辦理5+2處設宅的招租作業
# 這次收件跟審件的結果
# 總收件數是8006件
# 審查合格件數是6914件
# 其中如果扣除陽北跟國光這兩個
# 第五名單申請的件數
# 如果是以新設宅的審查來說的話
# 它合格件數是6368件
# 那我們再進一步去統計說
# 那申請設宅的人次
# 就是說它的總人數來說
# 它是2462人
# 那也就是說平均每人大概是申請2點多處的設宅
# 那目前接下來的進度是在6月26號的時候
# 已經完成了抽籤公告
# 那我們在7月份的時候就進行設宅的看選務務
# 那接下來請看到簡報第9頁的部分
# 那後續由於設宅陸續的點交
# 那我們也開始規劃六處設宅的招租作業
# 那第二波的設宅招租活動總共有六處設宅
# 那總戶數是894戶
# 那其中有公辦設宅兩處
# 包括中和安邦的632戶
# 還有行電民航的194戶
# 那另外還有龍江設宅總共有四處
# 那包括明德三號等等的四處
# 那我們預計會在8月份的時候進行公告招租
# 好 那接下來請看到簡報第10頁
# 那在設宅營運管理入住率的部分
# 那在第10頁的相次1到9的部分的設宅
# 然後還有第11頁的部分
# 10到14相次的設宅
# 那我們整體的入住率來說
# 是在93%到100%之間
# 那在相次15到18的新的設宅
# 那這個這幾處就是配合我們目前的招租活動
# 那正在進行看選屋中
# 那接下來看到簡報的第12頁
# 那在相次19跟20
# 這邊是財政局委託本中心營運的板橋
# 民權的社會住宅跟出租住宅
# 那這邊要說明的是
# 板橋民權社會住宅在今年3月份的時候
# 進行財政局委託給我們第二批的設宅的看選屋作業
# 那3月那時候開始看選屋
# 那但是在0403的地震的時候
# 那時候社區他就有發生這個三台電梯
# 其中有兩台他的鋼纜就是斷裂的這個事件
# 那後來他是到6月3號的時候才修繕完成
# 那所以入住率這邊我們就從6月份開始
# 那我們後續就是再做一個加緊辦理看選屋
# 然後預計在7月份的時候會再把這個入住率拉起來
# 那接近到9成
# 那接下來看到簡報第13頁的部分
# 那這段期間我們也是持續進行
# 農獎設宅的業務跟點交作業
# 那包括土城明德3號的11戶
# 那五湖方舟的23戶
# 泰山信華1號的14戶
# 還有新店實行3號的20戶
# 那這個部分在6月底的時候
# 我們都已經完成這幾戶的業務跟點交作業
# 那接下來看到簡報第14頁的部分
# 那在設宅營運管理的方面
# 那我們這邊也是持續精進
# 那頒定了新北設宅營運管理的SOP手冊
# 那目的就是為了要推動設宅執行人員作業標準的一致性
# 那本部門這邊後續也會將這個手冊提供給
# 委託的物管公司作為作業遵循的依據
# 而且定期辦理教育訓練跟稽核督導
# 以確保廠商他的管理執行的作業品質
# 那接下來看到簡報第15頁的部分
# 那在設宅的夜食區的相關措施的部分
# 那我們這邊進行的是設宅設置洗衣精智慧補充站
# 那本部門跟台塑生醫環保認證洗衣精的智慧補充站有洽談合作
# 那優先在大型的設宅做設置
# 那本方案可以提供給民眾便利而且便宜添購洗衣精的選擇
# 那如果說他是用這個空瓶去裝
# 在這個機器去裝洗衣精的話
# 那這個費用只要買一個新的洗衣精的三分之一
# 那另外這也配合本公信夜市區減塑的環保目標
# 那響應綠色的經濟
# 以上報告
# 好謝謝
# 接下來由中和業務一部專案組組長葉陽報告
# 各位同學大家好
# 那接下來由公辦案件來做報告
# 那首先在簡報第16頁的部分
# 那我們大城住點公共站持續的服務大城這邊的社區的住戶
# 那我們近期服務的重點是
# 大城單元三搬遷點交的補償費、住金補貼
# 以及相關所得稅所遇到的問題的一些協助
# 那另外因為現場已經架設了圍籬以及信箱
# 那我們住點的同仁又協助住戶這邊在做信件的領取以及通知
# 那另外在大城單元一的部分
# 那原本有繳交使用補償之音的住戶
# 那經過我們輔導之後
# 他們都是已經符合未來可以申購土地的一個資格
# 那後續我們會協助他們來辦理購地的一個程序
# 那另外在個案的住戶的一些資訊以及重要的資訊的說明的話
# 他們也不定時的會提供一些服務
# 那在簡報第17頁的部分
# 大城單元三在今年的4月30號
# 已經完成了252戶的全數點交之後
# 那目前現況是由拆除公司目前正在做廢棄物的清運
# 那預計在7月12號的時候
# 我們會舉辦一個拆除的動工的典禮
# 然後邀請市長一起來參與
# 那後續在正式拆除動工之後
# 我們也會用影像的紀錄的方式來紀錄整個拆除的過程
# 作為未來的一個行銷宣傳的使用
# 那在簡報第18頁的部分
# 大城單元一跟四在今年三月底公告招商之後
# 那除了住戶持續的關心進度之外
# 那在簡報之後的一些相關工作我們也有做提前的準備
# 那兩個案子分別是在6月26號以及7月11號會做結標
# 那單元四的部分已經在6月27號的時候已經完成了資格的審查
# 那在簡報的第19頁的部分
# 那樞林行政園區案
# 那目前我們會持續的配合內政部這邊的審議的進度來辦理
# 那另外有關回饋的方案的話
# 未來我們也會參考其他行政園區的一個審議的情況之後
# 再來做個案的一個處理
# 那在簡報第20頁新店中華段的部分的話
# 那原本是針對國有土地分回規劃作為社宅使用
# 那在112年的時候市府也已經向國產署申請了無償國用社宅
# 並且我們也在說明會的時候跟住戶告知說
# 未來會有社宅的一個使用的規劃
# 那現在國產署表示說要做優先評估中央辦公廳社的一個使用
# 跟委員來推動的方向有不太一致也不太符合
# 所以在今年的3月29號市府也會請中心站推動這個案子
# 那後續我們會看國產署他們這邊內部的評論結果之後
# 我們再來研擬這個推動的方向
# 那在簡報第21頁金山市場的部分
# 那我們依照預約的一個工作
# 我們在5月21號的時候已經完成了花瓶更新地區的一個核定
# 那並且我們配合市場處的一個需求
# 在6月6號的時候召開了招商的說明會
# 當天有9家廠商來到場與會
# 那我們是預計在這個月的時候會依照市場處的指示來辦理公告招商
# 那在簡報第22頁文山溪農案的部分
# 那目前正在做招商前的一個前置的作業
# 那在整合的部分的話
# 那我們土地所有權利跟違章佔用的部分都已經全數取得他們的意願的參與了
# 那另外在其中有事故的違章跟佔用的話
# 那我們也持續在跟他們做協議的溝通當中
# 那是預計在8月的時候會來做招商
# 那在簡報第23頁的部分
# 永和鼎溪案
# 目前我們先期規劃持續進行當中
# 那在整合的部分的話
# 我們在6月1號的時候有開了一個全區的大型的說明會
# 那接下來我們會持續的整合
# 整個住戶的一個意願
# 以及召開小型的座談會
# 來徵詢住戶的參與的意願
# 那預計是在年底的時候會來做公告招商
# 那在簡報第24頁板橋福州案的部分的話
# 那目前我們已經啟動了先期規劃
# 那接下來我們就會針對社區的一個住戶
# 來凝聚他們的參與意願
# 那另外我們也會定期的追蹤內政部
# 就是審核主要計畫的一個進度
# 那在簡報第25頁的部分的話
# 文山木柵案
# 那屬於是新北市有89%的土地
# 在台北市的一個境內的一個案件
# 那未來我們也是朝向以公辦都更的方式來做執行
# 然後今天的話
# 我們稍後也會在討論案的時候
# 針對這個案子來做討論
# 接下來由綜合業務二部企劃宣導組代理組長林佳良報告
# 各位董事好
# 接下來由綜合業務二部這邊報告
# 首先參與簡報第25頁
# 那首先是先針對我們偵測協助案
# 新店大溪地案的部分
# 那本案中心持續輔導社區自主更新
# 提供更新會推動方向以及法律的諮詢
# 那本案已經召開第六次專案小組審查
# 那會議結論為修正後辦理聽證
# 更新會已經在5月25號召開會員大會
# 決議排除144之1地號
# 私有公共設施用地以及選配原則等議題
# 並在6月4號申請補證展延
# 那後續中心這邊會持續追蹤補證進度
# 以及提供相關的協助
# 接下來請參院簡報第27頁
# 那同為政策協助案580危險建築物專案計畫
# 那本專案公告實施以來
# 已經辦理近70場的一個580專案計畫說明會
# 那截至6月底已經有20案申請了本專案
# 那其中包含0403鄭水蒙黃單社區總共有10案
# 將會優先協助處理
# 那另外首案新店案的這些新案社區
# 第二階段統一比例已經符合規定
# 達8成
# 那其中公辦都跟著招商作業
# 那第二案新莊民安花園廣場
# 因統一比例未達標
# 已含複申請了不續行本專案
# 但後續仍會依社區的意願
# 持續協助不老社區
# 那其餘案件的辦理進度請參院簡報第28頁
# 那接下來針對民辦已簽約案的一個案件進度報告
# 那目前請參院簡報第29頁的部分
# 首先先針對板橋文化路油庫口岸的部分
# 那本案中心協助成立更新會並擔任全案管理
# 那因為鄰近的漢堡建設整合文化路的基地
# 那該公司在4月底前已經完成林地意願調查
# 那目前只有取得少數的同意
# 所以更新會將會以原本的範圍來繼續執行
# 那更新會在5月底也完成租戶的自主更新意願調查
# 那調查的結果其實還不是很明確
# 那有部分租戶表示傾向與建設公司合建
# 而且不願意執行出資
# 所以理監事會也在商討轉公開評選持續者的可行性
# 並同步徵詢會員的一個意願
# 接下來請參院簡報第30頁
# 那新莊專訪落案的部分
# 那本中心擔任專案顧問提供法律的諮詢
# 那5到6月我們持續追蹤本案的整合進度
# 那目前同意比例還是未達法定的門檻
# 那另外因為合約已經屆滿
# 那雙方同意再續約一年
# 那接下來我們參院簡報第31頁
# 羅東長安街193巷案的部分
# 那本案中心擔任全案管理顧問
# 參與事權計畫的擬定
# 那本案已經在4月23到5月22辦理公展
# 5月7號辦理公辦公聽會
# 那預計是在7月9號會召開專案小組審查
# 接下來請參院簡報32頁
# 羅東長安街46巷案的部分
# 那本案中心協助成立更新會後
# 其實持續推動全案管理的部分
# 那以及說明帶電原則
# 但是因為更新會未能符合中心的帶電原則相關規範
# 所以更新會在5月25號
# 那更新會的會員大會決議
# 同意由中壢都更作為帶電
# 以及全案管理的廠商
# 中心擔任本案的專案顧問
# 一同協助社區完整都市更新
# 接下來請參院簡報33頁
# 新店區秀水斷案的部分
# 那本案為都市更新可行性評估案
# 那本案全區範圍都屬於三坡地
# 那已經初步的一個坡度檢討分析以及檢討作業
# 那因為全案上有需要突破的地方
# 所以經呼籲監設決議
# 那決定在委託專業的水保技師
# 進行完善的三坡地的檢討
# 那目前客棧辦理坡度檢討的一個作業
# 接下來請參院簡報34頁
# 新莊中港路中美社區案的部分
# 那本案中心擔任專案顧問
# 提供法律的諮詢
# 那本案已經在4月3號到5月2號辦理工展
# 4月11號召開公辦公聽會
# 6月20號召開第一次專案小組
# 那針對建築 骨架 還有縣有鄉道的改廢
# 以及圍管等疑慮
# 那釜鎮釐清之後 以及釜鎮之後
# 那會去排第二次專案小組審查
# 那接下來簡報第35頁的部分
# 那針對法律宣導說明會辦的情形說明
# 那截至6月29日
# 針對都更三建 蘇仁連署 海砂屋社區
# 還有里長說明會等等
# 總共辦理166場說明會
# 那約有2萬4千人參與
# 那以上是綜合業務的部分報告
# 接下來由行政部 行政管理組組長生修奉報告
# 請各位董監事參院簡報第36頁
# 在36頁可以看出來
# 我們中心為了招募人才
# 我們在4月份的時候擬定了招募的一個經濟計畫
# 除了在104的人力領航持續的將缺額來做公告以外
# 我們也化被動的主動
# 直接尋找適合的大專院校及相關的就業輔導博覽會
# 那除了4月30日到文化大學的都計學院課程上面
# 辦理招募的說明會以外
# 我們也安排了台北大學跟智里科技大學等學生來中心參訪
# 並且主動跟他們說明招募的內容
# 另外我們也參加了104的人力銀行舉辦的招募博覽會進行招募
# 然後也同步拍攝了中心的招募影片
# 在社群網站上播放
# 在簡報的第37頁可以看出來
# 我們在5到6月辦理了多場的教育訓練
# 包括了資安的課程
# 跟消防安全等相關的課程以上
# 好 那各位總監對於剛剛我們的業務報告
# 不知道有沒有什麼指教
# 不好意思 我只有一個小事
# 對業務的部分沒有意見
# 但有一個17月的部分
# 17月的部分
# 我們大成山的部分7月12號將那個拆除拍購
# 那當天的部分原則上是希望
# 因為這個是一個非常難的案子
# 也非常謝謝中心的同仁
# 那包括一個市場的拆除等等這些
# 過程都非常的辛苦
# 那在府裡面疫情會議討論的時候
# 曾經有詢問說這個案子
# 因為其實這是一個很代表性的案子
# 那我現在只想確認一件事情
# 就是目前得到的訊息不一樣
# 因為市長可能會出席那天的拆除的開工典禮
# 但是目前為止我們得到的訊息是
# 因為市長出席一定會有記者隨行
# 那有記者隨行就不可能低調
# 但是我所知道的是中心的業務單位
# 好像希望低調 擔心會有狀況發生
# 但是又問的結果是好像是說
# 因為沒有說要低調
# 那這個部分會牽扯到市長到底要不要出席
# 所以我想中心這邊會比較了解
# 如果可能會有狀況
# 那當然我們就會考慮市長的行程
# 原因就是說
# 因為我們也不知道那個狀況到底是怎麼樣
# 所以這個部分可不可以中心這邊
# 可以讓我們了解一下
# 那個實際的情況會有多好
# 各位董監事早
# 下午好
# 基本上大城山的這個拆除動工的儀式
# 我們基本上我們沒有要低調
# 中心沒有要低調
# 那目前先講這個行銷媒體的部分
# 目前也感謝警察局跟更新處這邊
# 還有我們中心自己的管道
# 目前已經有7家的這個電視台會來做採訪
# 那採通的部分
# 我們包含房產線還有市府線的部分
# 我們會全部都發
# 除此之外我們還有這個住戶的部分
# 我們也希望整個場子是比較熱鬧的
# 所以我們也在我的LINE的群組部分
# 也跟各位住戶也吸引他們
# 有發一些小禮物
# 請他們來參與這樣的一個盛會
# 那我們目前明天我們還會到現場去做
# 跟黃局長去做現場的動作
# 跟秘書長報告
# 非常謝謝那個中心的同仁辛苦了
# 因為這個訊息的部分
# 因為確實也有這樣子的一個訊息
# 是中心的同仁這邊做反應
# 我們只是要確認這個情況
# 如果因為這個案子其實是個代表性的案子
# 市長能出席
# 其實因為他一直都很關心這個案子的拆除的動作
# 好不好
# 那如果沒有其他可能狀況的話
# 原則上我們還是會建議市長
# 還是要出席那天的會議好不好
# 那只是訊息上因為當時有一點點的落差
# 所以我想說這個時間確認一下
# 因為現在現場都已經辦妻完成
# 也沒有任何的所謂的
# 會有民眾來陳情等等這些資訊
# 我們現在應該都沒有
# 所以我早上也是跟他們ReRe一下
# 這整個過程
# 然後我知道國光也會到現場去看
# 然後典禮的前一天也會才來
# 國光他們也會去
# 那唯一比較我們覺得比較艱鉅的就是交通
# 因為現在都圍起來
# 要進出到那個已經拆掉的那個市場那裡
# 所以我們也是希望是說當地的派出所
# 能夠請他們來協助
# 對交通的這個管制
# 要請他們來幫忙
# 那那個黃翔他們
# 我看他們也是投入相當多的精力
# 要來辦這個事情
# 好不知道還有沒有哪一位
# 董事來請
# 這邊有一個
# 這位PD的公認請你稍微說明一下
# 就是新店中華按鈕
# 後拆署是三位就已經含金標準要贊成辦理
# 那目前有沒有比較新的狀況
# 到底我們目前中心這邊準備怎麼做
# 因為114年現在我們把這個案子還是讓進來
# 所以到底他會不會再往返
# 這個不用解說
# 謝謝
# 關於這個案子
# 我們其實在更新處這邊
# 有跟國南署我們開一個
# 還有城鄉局這邊開一個會
# 針對他未來要做的這個辦公需求
# 是不是要續辦
# 不是更新這個案子做一個討論
# 那他們目前正在調查
# 各個機關的需求
# 預計他們時間共就是要四個月的時間
# 三到四個月的時間
# 那我們目前掌握到是我們每一段時間
# 大概是每半個月
# 我們都會跟他們的同仁去做詢問
# 看有沒有最新的一個進度
# 那如果說他們將來還是要做辦公的部分
# 可能我們這邊要跟城鄉局這邊討論
# 看看是不是要再續行這個案子
# 目前還未定
# 我想最有可能會是
# 分配的內容會改變
# 以前我們是希望設宅
# 設宅他土地的話就是無償撥用
# 我們幫忙他做這個
# 因為老百姓那個地主
# 我們都已經去整合
# 大家都已經期待
# 如果變成辦公大樓
# 那是不是變成一棟辦公大樓
# 或一棟那個住宅
# 那這個怎麼樣分配
# 那也可能會是朝這樣
# 但是他們的需求
# 等於是現在還沒有確定
# 之所以會有這樣的變化
# 我們也不方便去深入說
# 為什麼會是這樣
# 原來都講的都沒有問題
# 所以我們才說
# 這個如果是這樣的話
# 我們來做社會住宅
# 那這個土地就無償撥用
# 大概是這樣
# 所以短時間內可能
# 我看一兩個月之內
# 可能還不會說最後確認
# 不過都有在進行這個事情
# 如果做辦公大樓
# 一樣我們中心還是單位使用
# 他們一定會委託我們來辦
# 他們有地
# 但是不然的話委託
# 這個是國家住宅中心
# 不願意幫他們辦
# 找我們
# 當初是這樣子
# 這個是我們內部在這邊講
# 所以不方便講
# 現在不知道
# 突然他的用途改變了
# 才會有發生這個趨勢
# 不知道還有沒有
# 來 請
# 第36頁這裡
# 能力招募的部分
# 上次我們有討論過
# 這個薪資的調整之後
# 那目前這樣的能力招募的情形
# 有沒有因為這樣而得到改善
# 我先瞭解一下
# 還有你們多元的招募的方式
# 有沒有發現哪個方式是最有利
# 因為我對人力這個部分
# 會比較敏感一點
# 我自己都找不到
# 跟董事長
# 董事長一次報告
# 經過我們上一次的這個薪資調整
# 那另外還有一個
# 我們招聘人員的這個方式的改變
# 目前我們原本的原額是75幾年度
# 那我們後來做了一個
# 這樣的一個改變之後
# 的確有增加了一些
# 但是那個數量其實並沒有很多
# 那我們來的這個管道的部分
# 也有從台北駐都這邊過來
# 這個的確就是
# 我們當初在做挑薪的時候的預測
# 就是當兩邊的
# 這個中心的薪資結構一樣的時候
# 這些員工他們就會去做一些選擇
# 的確是有從台北市過來的
# 除此之外
# 我們有到一些這個
# 大型的博覽會去參加
# 我們也有一些員工
# 是從那邊得到我們中心的消息
# 的這個招聘的訊息
# 也有經過這樣的他們來投入這個履歷
# 那也順利的也有招到幾個
# 是從那個博覽會這邊過來的
# 那另外一個改變就是
# 因為以前的104的這種招聘的方式
# 因為我們不像公務機關
# 我們會有在有一個網站
# 我們必須透過這個民間廠商
# 一樣都是透過104
# 那104它是有一段時間
# 就是時間到我們就會下架
# 那我們這次嘗試就是一直掛在那個上面
# 就是有這個民眾
# 或是有這個人要上去看的時候
# 他可以一直看到我們有這樣的一個職缺
# 那所以我們經過這樣的一個調整之後
# 是有比較好到升到人口
# 但是跟我們目前的
# 剛剛看到我們員工
# 目前還是只有56位
# 跟我們的這個
# 中間的這個差距還是蠻大的
# 以上
# 好 不知道還有沒有哪位 來 請
# 那這個會議資料裡面
# 第18頁
# 那也有提到
# 因為上次市長在這個市政會議有提到
# 就是希望大省如果有104人
# 這個重大採購
# 未來能夠成立採購廉政平台
# 那這個部分呢
# 因為董事長也特別交代
# 我也跟執行長也聯絡過
# 所以我們就把它成立一個採購廉政平台
# 那網頁已經正式運作了
# 我覺得這個未來
# 如果有需要的議題的時候
# 再來召開這個會議
# 那原則上就落實市長的政策
# 那以上
# 對 好 謝謝
# 這個 沒問題
# 好 不知道還有沒有哪一位
# 好 如果沒有的話
# 我們這個就是報告
# 我們是不是就洽詢
# 報告二
# 本中心113年5到6月重要業務報告
# 決議洽詢
# 接下來進行報告案三
# 本中心113年1到4月
# 預算執行進行報告
# 請各位董監事參閱議程資料的
# 第31頁到第40頁
# 及簡報的第40頁到44頁
# 本報告案由行政部財務組組長吳廟芬報告
# 各位董監事大家好
# 請參閱簡報第40頁
# 本中心113年1到4月的預算執行情形
# 1到4月的收入執行率是99%
# 執行數是1億1600萬1000元
# 成本及費用執行率的部分是71%
# 執行數是4460萬5000元
# 剩餘數是7139萬6000元
# 再簡報第40頁的部分
# 是業務收入執行率的部分
# 業務收入執行率是98%
# 主要是社宅租金及權利金收入的部分
# 這邊特別說明有關貸款財政局
# 社宅及出租宅的執行率的部分是41%
# 1到4月貸款社宅
# 是用收貸戶的原則去列帳
# 因此沒有認列社會住宅收入的部分
# 因此產生了預決算的差異數
# 我們在跟會計師討論了之後
# 就是在5月份開始
# 我們會依照預算編列的原則
# 調整為收支並列的方式去做表達
# 因此未來在報表的呈現上面
# 收入跟支出的金額都會做一個呈現
# 1到4月的業務收入如果增列
# 就是民權社宅的收入的部分
# 在住宅收入的部分會有556萬2千元
# 另外停車位的部分也會有27萬4千元
# 那增列了這兩個數額之後
# 整個執行率會能夠提高到103%
# 目前就是表列的數字會增加5%
# 在簡報第42頁的部分
# 有關公辦社宅住宅收入的整體執行率是105%
# 那目前既有社宅就是相次1到7的部分
# 執行率是都在95%以上
# 那新接管的社宅是在相次第8到12的部分
# 預計在8月份開始會陸續點交招租
# 所以1到4月也沒有預算的分配數
# 在簡報第43頁的部分
# 有關榮獎社會住宅租金的部分
# 1到4月的執行率是67%
# 那接下來就是就執行率比較有落差的部分
# 做一個簡要的說明
# 相次1的部分是三峽北大社宅的部分
# 執行率是79%
# 那主要是因為有部分的房舍有漏水修繕
# 那在修繕的過程當中
# 這些社宅是沒有租金收入
# 因此會有執行率的落差
# 那相次2的部分是永和國光社宅
# 那永和國光社宅我們在2月份的時候
# 已經就是點回給社會局去做管理
# 那預算的部分也是只有1月到2月
# 那執行率是53%
# 在相次9的部分是五股城州
# 1號社宅執行率是0
# 那因為配合前面業務報告所說明的
# 就是招租作業的期程
# 預計在8月份開始可以招租入住
# 那在相次10到14的部分
# 是今年新接管的社宅
# 那因為目前1到4月
# 4月底的時候仍在業務點交跟裝修的作業當中
# 因此執行率是0
# 那後續也會配合就是招租業期程開始進行招租入住
# 那如果說我們排除掉第10到14相次
# 就是受建商延遲點交的影響的話
# 去計算執行率可以回到執行率99%
# 在簡報室事業的部分
# 成本及費用的執行
# 1到4月的執行率是71%
# 那實際執行數是4461萬
# 交易算分配數6256萬元
# 減少大概1796萬元
# 那主要大概會有三個主要的落差的原因
# 首先就是整體用人費用的部分
# 不管是在出入資產成本
# 業務費用跟管理總部費用
# 三個項目之下的用人費用
# 整體來說的執行率是76%
# 預算的分配數1到4月減少大概779萬元
# 那4月份的禁用員額是55億
# 跟我們預算原來編列的75億有所落差
# 因此就是執行率受到一些影響
# 那目前也急在進行人員的招募當中
# 第二個主要原因是出入資產成本
# 服務費用的部分執行率是74%
# 那比預算的分配數減少大概620萬元
# 主要是因為社宅物管費用的核銷有一些延遲
# 不過這個部分我們也已經在積極的辦理核銷當中
# 那最後一個原因是在業務費用的服務費裡面
# 就是跟預算分配數減少大概257萬
# 那就項目來說的話
# 主要是在於都更一些委外案件的支出
# 跟行銷宣傳費的部分跟預期有一些落差
# 那應該會在下半年的部分會去做執行
# 那6月份開始中興這邊會
# 就是按月針對全年度的執行率去做預估跟檢視
# 然後去針對各個項目必要的支出做盤點
# 希望能夠掌握就是全年度的一個決算的情形
# 以上是4月的預算執行情形說明
# 那最後那句話就是說
# 現在已經下半年開始
# 我們每個月的決算
# 他會把實際的情形以及預估未來剩下的時間
# 還可能會收入或支出
# 然後看到年底的時候可能會是正負
# 那意思就是這樣
# 從7月開始就要控制
# 這樣才不會說到了10月、11月你再來想辦法
# 要那個的話就稍微有點慢
# 好 這個我們的這個預算執行情形報告
# 不知道我們你們董監有沒有什麼指教
# 在你們會議資料裡面我詢問一下
# 第三是6月表期的部分
# 因為執行的這個期間是1到2月
# 那其他都是1到4月
# 那這個是因為談判錯誤呢
# 還是說這個表期資料是舊的
# 那製作者有分歧
# 我們財務報告的話就是會lag兩個月
# 等於是我們現在報告的都是4月
# 所以他1到4月
# 那他資料是物質
# 對啊 那資料物質
# 好 來 請
# 我確認一下就是41頁的部分
# 剛剛特別有提到
# 那個執行率41%那個部分
# 剛剛有解釋了
# 就是當時的民權社宅是用
# 執行的時候是用代收代付這樣子
# 所以沒有收入
# 那我確認一下這個114年度
# 你們的做法是怎麼樣
# 因為決算總是要跟著這個預算跑
# 114年度是怎麼樣
# 114年預算
# 明年 明年 對
# 是用代收代付的方式
# 所以明年的話
# 所以就不會編了就對了
# OK 那這樣的話就一致了
# 那就跟會議室的期待就是符合的
# 好 了解
# 好 謝謝
# 那 來 請
# 謝謝理事長
# 那個因為剛剛有一個案子
# 我們在5、6月份的中央業務報告
# 有提到板橋民權
# 是因為電梯電纜斷裂的時候產生的故障
# 所以讓我們一起到原本要入住的時間往後遞
# 所以看起來或許在5、6月或是往後
# 可能會產生這個收入會有影響
# 那我們現在回到這個1到4月的執行情況
# 剛好會遇到那個0406地震的那個界點
# 那就會 我想知道就是
# 因為這樣子現在到現在大概6月了
# 那距離地震大概兩個月過去了
# 所以像比方講我自己的社區
# 我們修了電梯就遞延了兩個月之後
# 就出現了一個十幾萬的一個費用
# 那我就不知道0406這個影響
# 有沒有原本沒有預期到的cost
# 將來可能會在5、6月或是之後
# 的支出上會出現
# 可以說明一下
# 那我這邊說明一下
# 因為我們這個板橋民權社宅
# 它是一個一般的社區大樓
# 就裡面除了我們財政局它擁有的235戶
# 它還有一般出售給一般區權人
# 大概130多戶這樣子
# 所以變成說今天裡面相關費用的執行
# 都是由這全部的區權人去做決議
# 那並不單單是由我們中心這邊去做一個
# 一個代為負擔這樣子
# 對 那基本上以電梯修復這件事情來說
# 因為目前還在保固期
# 所以這個是建商他去負責做一個修繕的
# 以上報告
# 好 那個今天我們有那個監事
# 採購處的處長他也出面的意見
# 是不是我們也可以
# 我朗讀一下
# 有關報告三的部分
# 監事這邊意見是
# 精簡式預算執行落後項目
# 表9至表11之
# 用人費用之支出執行率60%到74%
# 顯示各單位人員
# 淨用人未如期預期
# 另表9出資資產成本
# 服務費用之出資
# 會執行處達600餘萬元
# 表示業務費用
# 服務費用之出資執行率僅17%
# 除健行加速和銷作業外
# 並建議自行盤點服務費所對應之
# 委外服務費服務契約是否有延期履約情形
# 加強履約管理
# 以上
# 這個是那個業務單位還是那個
# 基本上我們跟這些物管公司的勤款
# 主要是我們的落差是在物管公司
# 他來跟我們勤款的這個時間
# 有一個落差
# 那這部分我們會請這個資產管理部將來
# 針對合約的這個勤款的時程
# 跟撥款的時程可能要密切的配合
# 這部分我們會去做加強的管理
# 那至於剛剛講人員的這個招聘跟支出的部分
# 我們也這個我想可能是大環境的問題
# 因為現在人都找不到
# 所以我們這個這筆錢
# 我也沒辦法把它花費掉
# 大概我大概是對的說
# 那個月管的那個
# 除了就是說他們申請的時間
# 還有我們審核的流程要精簡
# 以前我們做這個公共建設
# 承包商也是每月估驗
# 他估驗原則上
# 因為承包商他一定是說
# 他這家公司要開支票
# 哪一天要付錢
# 他大部分都會固定
# 所以你不能耽誤到他太多的時間
# 所以譬如說我們審核到付錢
# 大概一個禮拜
# 五個工作天到十個工作天是合適的
# 所以這個我們自己內部
# 因為你估驗的那些項目
# 基本上大概都已經固定
# 那你只要確認說他做的量
# 是不是有按照合約的規定來那個
# 那我們每一個設宅
# 我們都有一個督導的同仁
# 所以他對這些應該是很熟
# 他不要到說一定要這個月滿
# 他下個月中才跟人家開會才確認
# 他可能在第三個禮拜
# 他就可以開始去確認前三個禮拜
# 沒有問題
# 等到這個下個月初
# 他們報上來的話
# 再做最後一個禮拜的確認加強
# 這樣我們就會很快
# 按照這個公款支付的原則
# 是說不能超過五天
# 但是各個機關大概沒有辦法那麼快
# 剩五天到十天就已經是非常好了
# 我們這個應該金額也不是太大
# 因為他們每個月屋苑的話金額不是太大
# 如果公共工程
# 每個月幾千萬到上億都有
# 那項目其實項目都是固定的
# 現在他們應該也都是電腦作業
# 平常的紀錄是最重要的
# 我有跟那個他們職場管理部
# 跟他們溝通過
# 經理回來的時候
# 你們在內部討論一下
# 看這個流程應該怎麼樣
# 再來說吧
# 好 不知道還有沒有其他的資料
# 如果沒有
# 我們是不是就這個部分也洽息
# 那接下去
# 報告案三
# 本中心一百一十三年一到四月預算
# 執行情形報告決議洽息
# 接下來進行報告案四
# 本中心內部稽核業務報告
# 請各位董監事參閱一成資料的
# 第四十一頁到四十三頁
# 及簡報的第四七頁
# 本報告案由基盟專員郭麗清報告
# 四月到五月的時候
# 委託國庫號法廉會計師事務所
# 查核租金及勞務收入循環
# 那抽查色彩輸出的部分
# 都有依照規定公告還有審核
# 還有公文文件
# 那抽查的過程中
# 全程公開並且有公告
# 那租賃契約的部分也有經過公正
# 那抽查那個顛覆出入的部分
# 也有依規定公告
# 那租金抵價的訂定
# 也是有按物價指示的報告
# 還有前置標案金額許高為抵價
# 招標開標及絕標的程序也有符合規定
# 那租賃契約也有經過公正
# 那應收帳款作業的部分
# 抽查就是會計單位也有按月編制
# 應收帳款帳明分析表
# 然後也會辦業務單位
# 然後針對催收款的部分
# 那預期帳款作業的部分
# 就是屆期滿兩個月之後
# 是會催收款
# 那這個部分業務也有積極去協商
# 然後如果無法協商的話
# 也會辦那個法務單位採取一些法律措施
# 發票開立的部分
# 也有在社宅還有店鋪出租收入的話
# 也有依規定開立還有作為發票
# 然後並按期去申報營業稅
# 那銷售退回及折讓的部分
# 如果社宅還有店鋪有提前退租的部分
# 也有依規定提出申請
# 那退租的程序都有確實去點交
# 還有契約終止協議都有簽訂
# 那經抽查的作業
# 向我們發現重大異常
# 那下個月六到七月的話
# 預計要查核新工學化
# 以上報告
# 好 那對這個部分不知道我們
# 這個董經燕
# 有沒有什麼資料
# 有沒有查核報告
# 在我們那個疫情資料裡面有附
# 我再請教一下
# 這個書面資料的四十三頁
# 這裡面就是我們看他的這個
# 內部稽核報告
# 那稽核項目裡一到六項
# 我要詢問的就是說
# 我們的抽查比例
# 有沒有訂定一定的抽查比例
# 因為每一項的抽查比例都不一樣
# 那像這個第一項的社會住宅
# 抽查比例百分之二十九
# 第二項百分之五十
# 第三項百分之十三
# 第四項百分之二十五
# 第五項百分之四十七
# 第六項百分之二十七
# 那看起來這個抽查比例都沒有
# 有沒有限定最低的標準
# 他是按照什麼
# 信賴區捷運九十五的比例
# 還有說可容忍的比例去算
# 那他一定是只按照這樣的模式
# 然後可能按照圈數
# 大概說整個樣本有多少
# 就是在這個期間有多少的量
# 然後去推算出來
# 這樣看起來比例差距很大
# 像這個件數少的兩件
# 抽一件就百分之五十
# 那多的這個有沒有
# 他的公式是固定的
# 但是樣本空間不一樣
# 所以出來的結果
# 那個就會
# 就是說兩件的話抽一件
# 就是百分之五十
# 一百件抽五件
# 就是百分之五十
# 所以公式是一樣
# 就是樣本空間
# 會影響到他抽的這個比例
# 那個應該是抽查的
# 有那個抽查的那個算法
# 這個是我們新進的這個稽核
# 我們等一下會追認
# 因為那是屬於
# 等於是他的抽查結果
# 都要經過我們董事會來認定
# 所以每一次董事會我們都會報
# 大致上是
# 就是剛剛他所說明的是這樣子
# 就像我們稽查
# 可能有人會有一個最低的
# 上面的話
# 譬如說你例行的抽查
# 跟專案抽查
# 也不一定會一樣
# 專案的話就是有特殊的那個
# 在專案簽
# 那如果是例行的話
# 大概是一個最低值
# 那因為人力的關係
# 他也不可能
# 每次都超過百分之五十
# 百分之五十兩件就要看一件
# 那人力也是太那個
# 所以現在我們剛剛講說
# 有按照什麼樣的那個
# 這個信賴的這個
# 百分之九十五嘛
# 是不是
# 那基本上我這邊的話
# 或許我可能會去看一些
# 風險可能比較大的
# 或者是說力量
# 風險比較少的話
# 我可能就有可能會考慮全場
# 或抽兩件再打
# 對啦
# 因為兩件而已
# 你抽一件就五件
# 那比例是很高
# 但是事實上只有兩件
# 五十幾件抽了
# 可能抽二十件
# 當然每一件的案件的複雜性不一樣
# 好
# 不知道還有沒有其他的比較
# 如果沒有
# 我們這個部分是不是也洽息
# 報告案是
# 本中心內部機核業務報告決議洽息
# 接下來進行本次的討論案
# 本次總共有四件討論案
# 討論案一
# 本中心內部機核人員聘任追認
# 請各位董監事參閱一層資料的第四十四頁
# 及簡報資料的第五十一頁
# 本報告案由前一綱代理執行長報告
# 是不是請我們各位小姐
# 要先迴避一下
# 請他迴避啦
# 請他迴避啦
# 討論案迴避
# 我們不用看管啦
# 迴避就好
# 那等一下再請他進來
# 好不好
# 那個行長
# 這個郭小姐是我們從伊底士利一號這邊招聘來的
# 那我們去年度整年都在找這個機核業務
# 因為我們行政法人要找一個機核
# 其實不容易啦
# 因為一般來講
# 機核比較通常會是在金融機構
# 或是在一般上市櫃的公司
# 有這樣的一個職缺
# 那我們行政法人目前
# 去年度招聘了一整年都沒有
# 很高興能夠招聘到這個郭小姐
# 那她的經歷也正如這個簡報上面可以看得出來
# 她在這個生物科技公司這邊也待了十二年
# 這樣的一個資歷的部分
# 那剛剛也有在我們這個前面的
# 我們過去一年
# 內部機核都是委託國父會計師事務所這邊來幫我們查核
# 那他本身也是會計師
# 會計系畢業的
# 所以我想在未來的這個機核的工作項目部分
# 我想他應該是可以升任的
# 以上
# 那選議學經歷
# 在這邊知道
# 各位董事對於這個案子
# 不知道有沒有其他指教
# 如果沒有
# 我們是不是就通過追認
# 是哪些同仁去請他
# 討論案一
# 本中心內部機核人員聘任追認
# 決議
# 本討論案討論前
# 機核人員郭立清與
# 你還有自己的文稿
# 本討論案
# 經全體董監事一致同意通過追認
# 經全體出席董監事
# 好不好
# 這樣會比較
# 接下來進行討論案二
# 本中心110年度業務及營運計畫
# 請各位董監事參閱議程資料的第45頁
# 複冊及簡報資料的第54頁到69頁
# 本討論案由前議綱代理執行長報告
# 各位董監事下午好
# 針對本中心114年度的業務及營運計畫
# 由我來跟各位做個說明
# 本中心的發展總目標主要有兩個
# 就是自立與社會住宅的政策的落實
# 我們希望透過行政法人企業化的經營
# 來提升市有財產的經營效率
# 除此之外
# 我們會積極來推動都市更新的政策
# 建立公民營的推動都市更新的程序跟方法
# 來做為未來招商的一個示範
# 除此之外
# 我們能夠強化跟民間業者跟所有群人之間的
# 這樣的一個互信基礎的橋梁
# 在發展的四目標目標部分
# 在我們簡報裡面可以看到
# 我們第一個是實踐社會住宅的政策
# 我們會專責在社宅的招租營運的履約管理
# 保障這個市民有多元的居住的選擇
# 另外是兼顧社會住宅的品質
# 跟它的量的提升
# 來維護整個居住品質
# 來落實居住的正義
# 另外是在經營社會住宅跟都市更新的不動產部分
# 我們會持續的經營管理市府
# 所受委託給我們的社會住宅
# 另外來接受榮獎回饋
# 都市更新的不動產的經營管理
# 來活化資產的效益
# 我們預計在114年度
# 會接管的社宅達到37處
# 總共超過了近5000戶的這樣的一個水準
# 另外我們會加速來辦理主導公辦
# 來協助民辦來推動都市更新
# 以中心的角色公平公開公正的方式來推動
# 以專業的第三部門的角度
# 來擴大辦理都市更新
# 推動這樣的一個能量
# 另外我們中心很重要的一個宗旨
# 就是要推展不動產的資訊的研究跟交流
# 來提供政策上的建議
# 對於社宅的部分
# 我們會有一些資料的收集 統計 分析
# 也作為未來在興建社宅上面的一個參考
# 另外對於都市更新的資料
# 還有可行性評估的工作業
# 我們也會陪著協助市府的角色來辦理
# 積極來辦理這樣的一個智庫的角色
# 促進產官學的一個交流
# 提供研究發展的能量
# 那在業務計畫 社宅的受作管理部分
# 在我們資產管理部
# 我們對於民眾的承租
# 我們希望來考量市場的行情
# 提供只租不受的社宅
# 我們明年度會達到37處
# 那維持113年度30處以上
# 這個90%以上的這個入住率
# 另外我們在114年度
# 我們會有接管7處社宅的入住
# 跟他的這個社宅的地主簽約的相關的事宜
# 那在店鋪經營的部分
# 我們明年度會健全社會的
# 社區的生活機能
# 來提供33處的這樣的一個管理
# 那我們也希望能夠在入住率達到80%以上
# 另外我們也對於明年度新接管的這個大型社宅
# 包含國光二期
# 還有泰山中山等16戶的店鋪招租的作業
# 我們會積極的來辦
# 另外在社宅裡面還有這個公益空間
# 那我們明年度呢
# 我們會來提升社宅的服務的效能
# 達到26間
# 那配合市府各局處辦理公益空間的這個地約
# 我們希望能夠在使用率達到80%以上
# 那我們也會來積極協助各局處
# 公益空間跟承租廠商
# 還有公益藝術團體來辦理社區的互動的活動
# 來增加社宅民眾的凝聚力
# 另外在管理營運部分
# 我們希望能夠提供高效能的管理營運
# 針對這5500戶
# 那我們會導入我們在紀念度所
# 8月份7月底預計來公布的
# SOP的這樣的一個營運管理的手冊
# 來針對物管公司來做加強的教育訓練
# 跟加強的督導
# 另外我們會導入智慧化跟電子化相關的設備
# 來降低社宅的營運成本
# 另外也讓我們會做社宅民眾的家戶的
# 這個訪視的紀錄
# 針對一些特殊的觀望戶來持續的追蹤
# 那我們明年度
# 我們可以從表格上面
# 可以從59頁的這個簡報裡面
# 從110年度我們接管了9處1565戶
# 到明年度110年度的7處
# 總共有37處達到50500戶
# 那在明年度接管的社宅裡面
# 主要比較大型的社宅有三峽過光二級
# 有達到921戶
# 這是僅次於我們目前
# 相邊央北社宅的一個規模
# 這個是一個比較大的這個公辦社宅
# 除此之外還有5處的榮獎
# 榮獎的這個社宅
# 那在社宅以外的這個業務計畫
# 我們還要再做的是
# 加速推動公辦的都市更新
# 那綜合業務一部主要執行的案件有大城三
# 大城三拆除完成之後
# 記錄到實際的施工階段
# 我們會結合我們PCM廠商
# 來嚴格管理施工的品質跟進度
# 那對於大城一跟四的話
# 我們會辦理選配跟都市更新計畫的報合
# 以及在樹林案的部分
# 會持續追蹤整個都市計畫的變更的審議進度
# 來辦理後續的公開招商
# 另外在新店中華段
# 我們會等待國產署這邊完成需求評估之後
# 我們來看最後的結果
# 再來做後續的一個處理
# 另外在台北市的文山西農案的部分
# 我們會在今年度辦理公告招商之後
# 明年度來辦理選配
# 跟都市更新事業計畫全面的一個報合
# 另外在永和頂溪案
# 我們會辦理公開評選實施者跟簽約
# 來做這個履約管理
# 以及在板橋福州案
# 我們也會來辦理公告的一個招商跟履約管理
# 另外在台北市的木柵案
# 文山木柵案的話
# 我們會辦理先期的規劃作業
# 跟劃定更新地區跟招商的前置作業的相關計畫
# 那在民辦的部分的綜合二部的業務計畫裡面
# 我們執行主要執行案件有三個
# 第一個是在新莊公園一路案的合聯案
# 那目前我們是擔任專案管理的顧問
# 那工程在適逢中
# 預計在115年能夠完成
# 那達到這個實照
# 所以我們中心會擔任專案管理的顧問
# 繼續協助廠商來辦理
# 另外在蘆洲長安街
# 長安街193項案裡面
# 我們擔任全案的這個管理顧問
# 當然會來協助事權的審議跟報合的動作
# 那另外是在油庫口案子
# 目前我們是擔任全案的管理顧問
# 那我們來協來針對住戶的協調整合
# 那還有後續的專業團隊的一個遴選
# 那另外還有在新莊中港路的軍風案裡面
# 我們擔任專業的顧問
# 來提供法律的諮詢
# 來協助實施者跟未同一戶之間的溝通協調
# 做一個平台
# 另外還有在長安街46項
# 這個更新會的部分
# 我們也是擔任法律諮詢
# 那也是協助實施者跟未同一戶來做一個溝通
# 另外在思源路案的部分
# 我們也是擔任顧問案的角色
# 來做事業跟權變的這個審議跟合理的一個動作
# 另外我們在協助市府的580專案的部分
# 我們會持續來推動
# 來加速進行580專案的一個協助
# 那我們也會中心自己部分
# 也會新增受託民間推動度勢科技案
# 一到三處這樣的一個案源
# 那另外在行政部的業務計畫
# 我們對於人員的招募的部分
# 我們對於各部門的人員的需求
# 我們會做滾動式的修正調整
# 另外來辦理至少三場的內部的教育訓練
# 還有針對兩次的績效考核
# 檢視同仁的專業跟工作態度來做一個調整
# 那對於我們的財務規劃的部分
# 我們會依照我們業務的範疇來規劃營運的資金
# 那做預決算的一個編列跟執行控管
# 跟財務管理的一些相關動作
# 那定期來檢討租金的收買進度
# 那降低這個待帳的風險
# 以及在定期檢討這業務的發展
# 我們隨時都會做四年度的財務的預測
# 另外在資訊管理的部分
# 我們也會落實管理作業跟應用系統的流程
# 相關的權限 備份等相關的行政事務
# 那辦理這個資通安全的西級應該辦理的一個事項
# 那我們對於網路的部分
# 我們會透過相關的資訊來提升我們的作業的效率
# 所以在組織建構的部分
# 我們明年度還是編列75個
# 那因為因應到整個市場環境
# 人員招募不順利
# 所以我們明年度還是維持今年度的這樣的一個員額
# 就是75個這樣的一個員額
# 那各個部署的這個部署的部分
# 我們並沒有做一些調整或是增加
# 那對於住宅及都市更新的知識研究發展部分
# 在資管部的專業的知識部分
# 我們會辦理相關的物業管理的教育訓練
# 來提升同仁跟我們外站的物業管理的專業的職能
# 另外我們也會跟國內外的這個社宅相關的研究
# 來提出這個分析來做研究報告
# 另外綜合一部的部分
# 我們對於都市更新的教育訓練
# 我們會跟學界還有跟業界相關的實務經驗來做一個整合
# 那加強我們對於社區協助
# 諮詢都市更新相關的一些駐點的整合的效果
# 另外是對於國內外的都市更新的作業的一個研究規劃
# 還有資料的收集的政策建議
# 我們也都會主動的來做一個收集
# 來提供給業界來做一個分享
# 那綜合業務二部的部分
# 我們會來持續辦理都市更新法令的說明會
# 讓我們都市更新的知識能夠普及到這個市民的身上
# 那我們114年度我們希望能夠辦理
# 不能低於今年度的這樣的目標
# 至少辦理200場為這樣的一個目標
# 那對於國內外的這個都市更新的研究規劃
# 一樣我們會來持續收集相關的政策
# 來提供給都市更新處這邊來做政策上的一個修正
# 修改或是參考訂定的一個依據
# 另外在行政部裡面來講
# 是對於同仁的都市更新的專業知識的教育
# 我們會再做一個調整跟一個加強
# 另外會辦理這一場的都市更新相關的教育系列
# 來增加同仁的都市更新的知識
# 另外在國內外的研究的部分
# 我們至少會提供一次的國內外的住宅
# 以及都市更新的訊息給同仁知道
# 那每一週我們也會提供新北市政府相關的法令的修正
# 還有這個餘勤的部分來提供資訊給同仁來諮詢
# 那再來是114年度的經費的收支的狀況
# 我們在明年度的這個收支的總額是6億4千3百48萬
# 那只是比今年度來成長32%
# 另外在成本及費用的總額部分是3億8千5百5萬
# 那成長比今年度成長24%
# 那結繳支出的支出總額的部分可以達到2億5千8百42萬
# 那比今年度還要再成長46%
# 以上是針對110年度的營運計畫
# 跟各位董先生做個報告
# 好 謝謝
# 那個不知道對於這個我們的業務及營運計畫
# 不知道有沒有什麼指教
# 非常謝謝執行長剛剛對於營運計畫的說明
# 我想我們這裡還有一本完整的114年度營運計畫的報告
# 這裡面對於報告的內容
# 我個人沒有意見
# 但是有幾個問題必須要提醒
# 因為出租中心成立到現在
# 跟營運基礎之間的一個互動的關係裡面
# 包括我們當時的條例在制定過程
# 其實大家可以看得出來
# 我們自治條例的部分中心大概就是以營運等等為主
# 但興建的部分其實在議會當時是被否決的
# 但是在我們的營運計畫裡面
# 是希望將來可以執行興建等等這些
# 那到底興建等等這些事情
# 如果要爭取將來中心的話
# 那很可能自治條例的修正的部分
# 就必須要跟營運處這邊討論
# 我需不需要在議會裡面再去爭取所謂的興建的這個部分
# 讓興建跟營運可以一起
# 在這個地方一起去做處理
# 這是第一個
# 第二個早期我們在做社會住宅的定義的時候
# 其實因為我們是比較多移民的那個城市
# 因為差不多的年輕人都到這邊工作
# 所以我們把定位為青年社會住宅
# 但實際上我們現在的社會住宅不是只有青年
# 我們包括中低收入等等我們都有
# 所以在我們的營運計畫裡面
# 在114年希望將來能夠增加
# 增加接管青年社會住宅
# 這個定義的部分
# 可能在營運計畫裡面
# 我們也可能必須要定義得更加清楚
# 這是第二個建議
# 第三個建議的部分一樣
# 大概我們不管綜合業務的一部跟二部的同仁都非常辛苦
# 那因為我們現在薪資調整之後
# 我們希望營運的招募能夠更加的順利
# 那當時薪資調整的部分
# 讓人員可以招募更順利的原因
# 是因為我們的業務希望能夠擴展
# 但是還沒有到位的時候
# 當然同仁都很辛苦
# 所以在人員不斷的增加的情況底下
# 我們一部跟二部的業務的部分
# 我剛剛特別看了一下
# 114年的部分
# 還是以我們現在在執行的案件為主
# 那至於新的案件的開拓
# 跟新的案件的開發等等這一些
# 在人員逐漸的補齊的情況
# 我們希望人員可以逐漸補齊
# 因為這樣子的話人力上面比較能夠負荷
# 在逐漸補齊的部分
# 那將來的營運計畫的部分
# 實際上這邊可以更加的前瞻性的去提出來
# 我們將來不一定在114年
# 未來的幾年的部分可能有更前瞻性的做法
# 或是一些地區的開發
# 可能我們可以在這個地方可以提出來
# 那這樣子的話
# 就不會說業務上面有幾個案子
# 我們大概過去一直在執行
# 那這些案子其實不容易
# 持續的還是要把它完成
# 那新的地區的開闢的部分
# 也是希望將來我們能夠有新的案件
# 能夠逐漸的在這個地方可以擴展出來
# 所以提供這幾個給中天這邊做個參考
# 我們外面的據點
# 我們現在有那個大城山那邊有
# 那我們現在在三重
# 有一個新的據點
# 他們沒有跟我們報告
# 那邊已經開始使用
# 那主要要讓大家知道就是說
# 其實其他的局處
# 如果在那附近業務上有需要
# 也可以借用那個原來也是四五的財產
# 我們把它又重新整理又加固
# 所以花了差不多半年的時間
# 我們現在已經開始使用
# 這個可以請執行長順便也說明一下
# 回應一下剛剛秘書長的這個指教
# 我先回應一下秘書長的這個指教
# 關於第一點中興要去興建社宅的部分
# 我想目前度就算是明年度
# 我們應該也還沒有這樣的一個能量
# 除了能量應該是說人力之外的這個費用的部分
# 蓋房子的這個部分
# 因為我們中興的這個財務的制度
# 就是我們到了年底
# 我們全部都要上繳回入門基金的部分
# 所以我們並沒有年度的這個營運
# 所以如果要做自行的興建到營運的話
# 那我必須在整個制度面的一個大調整
# 除了剛剛講的法律面的修正之外
# 我可能在財務面跟這個相關的預算的編列部分
# 我都要做一個大幅度的調整
# 目前度我們應該還是比較著重在營運管理
# 如何改善這個目前營運管理的這個績效
# 那另外是在青年社宅的部分
# 那這部分跟秘書長說個抱歉
# 因為其實我自己看的時候
# 我也有發現我們同仁並沒有
# 並沒有很精準用到這個字眼
# 因為我們社宅的提供的對象不是只有青年
# 雖然這都是外來的移民
# 還有這個來台北這個就學的
# 其實我們還有一些弱勢戶跟一些高齡長者的部分
# 所以我們應該還是很歸到社會主宰
# 並沒有強烈的就是針對某一個族群去提供這樣的一個數量
# 這部分我們會去在營運計畫做一個調整
# 另外是在綜合醫療部
# 其實我們還蠻多的這種想要做的東西
# 但是真的是因為受限於能量
# 因為我們新北駐都跟國駐都還有北駐都
# 比較不一樣的是在於我們有去做民辦的部分
# 那我們民辦我們並沒有要去育民增利
# 我們主要是協助自力更新的部分
# 那自力更新當然不限於是自主更新會
# 或是說像一般的這種幫他去做顧問的角色
# 但我們是希望能夠跟更新處來做一些配合
# 就是深入到社區裡面針對這些比較危險
# 或是這些海砂屋的部分
# 我們能夠把自主更新的這個能量再放大
# 那目前我們的自主更新的這個同仁
# 因為受限我們的能力的部分
# 我們還沒有辦法到全部的整個生命週期的服務
# 只能幫他做初步的這個意見的法律的諮詢跟宣導
# 那甚至一些重點的
# 這個譬如說0403這樣的一個地震的
# 地震的這些社區
# 受損的社區
# 大概就是比較重點式的服務
# 但我們是希望說
# 能夠結合更新處的政策的指導之下
# 我們中心能夠進去到社區裡面
# 對於前面的讓他們社區有一個勞動
# 讓他們了解到怎麼來辦理更新
# 這部分我們是比較多的
# 想要在這地方做一個協助
# 那至於這個綜合一部的這個公辦的部分
# 我們其實也有一些想像是除了市府的土地之外
# 我們也想要去開拓一些
# 將來開拓一些案源
# 包含就像那個國家住宿中心
# 國產署是把他的土地交給
# 我國住都來做一個處理
# 那我們也想去找一些國公營事業
# 包含的這個一些郵政機機也好
# 或是說像這種台電公司
# 說中油他們的這些土地
# 我們可不可以來委託我們郵政中心
# 來幫他來做這個招商
# 這部分我想應該都是
# 未來我們可以去做的一個業務
# 業務方向
# 那另外回到剛剛董事長提的部分
# 我們在6月27號
# 我們在我們一大漢就是西北西南
# 因為市府這邊有分西北西南
# 那西南的業務大部分
# 我們都還是透過我們新店這邊行政園區
# 這一個主要的辦公室為來服務社區民眾
# 那未來在西北的部分
# 我們在三重原本是一個派出所的一個使用
# 那因為後來交回去給財源局
# 那我們這邊很順利跟財源局這邊爭取到了
# 那我們也做好了裝修
# 我們在6月27號已經開始正式營運
# 那我們目前有同仁已經在那邊做服務
# 那將來我們目前已經跟建築師公會
# 這邊有做一個配合
# 就是未來在每一個月
# 我們會有做法例的一些宣導
# 那提供民眾可以來詢問
# 那關於這個都市更新的相關的業務
# 那除此之外
# 我們未來在社宅的收件的部分
# 也會在西北辦公室那邊
# 來接受民眾的這個收件跟遞補件
# 那我們也會再跟我們的都跟大聯盟的各個工學會
# 來做一個合作
# 未來讓我們的西北辦公室的能量能夠放大
# 以上
# 稍微講一下那邊的空間怎麼樣
# 那我們就是局處長
# 稍微知道一下
# 如果有什麼樣的
# 他們那邊剛好有些需要
# 可以借用
# 目前我們那一個的空間
# 大概可以辦一個小型的說明會
# 那說明會的部分
# 大概就是20個人左右的這樣的一個說明會
# 那也有一些會議空間
# 那另外的話
# 我們大概是三層樓的一個建築
# 如果說未來的使用效能擴大
# 我們才會用到四樓
# 四樓的這樣的一個空間
# 我們目前大概就是主要是用在一樓跟二樓
# 那三樓的話
# 目前是做我們自己治療的一個方式
# 謝謝
# 不知道還有沒有其他的指教
# 不好意思 我再補充一下
# 那個
# 因為我們這個是114年度的業務跟營運計畫的報告
# 是因為剛剛
# 剛剛你的報告裡面有特別提到
# 積極的興建
# 興建跟營運社會住宅
# 我那時候聽到有點嚇到
# 就是說興建的部分
# 他是用來嚇我們
# 是已經開始要去爭取興建
# 因為這畢竟是114年業務報告
# 我想目前為止我們大概確實是有困難
# 但是其實這是個未來的事
# 以後到底中興要不要走到那個程度
# 我覺得這個是以後是可以討論的
# 那當然如果走到那個
# 所有的財務等等機制跟制度裡面
# 必須要做一個翻新
# 那包括對銀行的貸款等等
# 融資等等這些
# 基本上大概就不會以現在的預算去做執行
# 所以我剛特別仔細的聆聽一下
# 因為114年的報告裡面
# 我突然聽到興建的時候
# 所以我想這邊確認一下
# 那第二個部分是在資訊的應用上面
# 我們現在目前
# 最近非常夯的AI的部分
# 因為我們非常多的說明會
# 大概都靠同仁到現場去做很多的說明
# 可是AI的應用某種程度上面
# 在這個資訊的應用上面
# 它其實可以協助我們
# 做很多類似這樣的工作
# 可以減輕同仁的困難
# 那我們將來在這方面資訊業務的推展上面
# 我覺得可以嘗試看看
# 能夠有一些新的這樣子的一個做法
# 因為畢竟AI在應用上面
# 確實有它的一定的一個趨勢
# 所以提供給中興這邊做個參考
# 我們已經有在規劃
# 這個部分很感謝秘書長的意見
# 我們預計在今年底
# 今年底我已經找AI的廠商
# 來討論一下我們中興有哪一些的業務方向
# 可以走AI的協助
# 讓我們的同仁可以降低一些工作的壓力
# 包含了因為民眾常常都會打電話來問
# 一些社會住宅的資訊
# 還有都市更新的一些資訊
# 我們希望能夠透過AI的一個角色來扮演
# 這部分我們預計在今年底會推出一個東西
# 我們再來跟董介石做個報告
# 我們昨天的青森會
# 吃了公家的食物
# 我們也有請我們受訓的同仁來講受訓的內容
# 因為有兩個是報AI的
# 所以這個確實是同仁也有意識到說
# 現在的時代已經進入到這個
# 我們有重複性的這些知識的傳播的話
# 靠這個AI確實是可以節省很多的能力
# 那那個孫教授是不是有要想要指導的
# 我現在沒有舉手
# 沒有舉手啊
# 那你的頭一直
# 就是剛聽各位這個董介石在吹熊的時候
# 我就不斷的在思考
# 想釐清
# 後來我們看資產負債表
# 所以我一直很想知道我們到底有多少資產
# 後來發現我們只能放這裡面
# 我們只有那個什麼包彩圖
# 那後來猛一看好像有三台車
# 所以我們資產負債表裡面
# 看了一下每年只有大概22萬的交通運輸設備
# 只是剛一直翻
# 因為沒有看到真正的資產負債表
# 所以就沒有看到我們到底有多少的資產
# 只看得到就是一年
# 我們114年度可能就是會
# 折舊團體22萬的交通運輸設備
# 所以我在猜應該就是這三部車的折舊
# 那可能回去我再看一下以前的會議資料
# 因為在目前今天的資料裡面
# 沒有看到我們資產負債表
# 我剛剛是在思考就是說
# 我們中心如果沒有固定資產這麼多的話
# 我覺得是好事
# 因為一個地震來我們所有的資產都變
# 那是很可怕的話
# 就是房子如果都倒了
# 那很顯然就是看起來
# 我們有點像是買工賣工
# 就是管理啦
# 財經局講說我們是空殼公司
# 那如果是這樣子的話
# 我們整個就是看cash flow
# 就是我們的現金流
# 就是收入跟支出出去
# 那我們中間有一些資產可以管理
# 所以可以維持收入金
# 然後我們的預算的支出出去
# 但倘若什麼樣的原因
# 比方講有一個地震
# 然後我們所有的可以管理的資產
# 突然被鎖住了
# 但我們支出還是得給
# 就是我們所有人的支出還是給
# 就不知道那個buffer
# 到底是
# 這個可能可以想一想
# 可能跟今天討論無關
# 比方講突然一個地震來
# 然後我們10%或20%的那個
# 要管理的資產突然不能動
# 雖然我們沒有
# 不是我們的資產
# 所以我們沒有折損的問題
# 那可是很顯然的
# 我們的整個量能
# 收入的量能就會
# 突然會減少30%
# 可是我們支出還是會
# 還是必須有
# 那那個缺口就我們中心來講
# 我們到底要怎麼設計
# 或者是到時候就基金再撥補給我們
# 如果整個機制是這樣子的話
# 那應該還算ok
# 就是說我剛剛是不斷在
# 在思考這個問題
# 這個問題我們大概幾年前就開始思考
# 那我們發現就是說
# 我們可能要先從
# 這個life cycle裡面
# 社宅維修的
# 因為隨著時間的話
# 它會有
# 會出現一些時間
# 它需要比較大的資金來修
# 譬如說電梯
# 譬如說開始外面的那個
# 要拉皮等等這些
# 這個制度要怎麼樣
# 我們是把這個每年的盈餘
# 是不是放一些板筆
# 在我們成立一個基金
# 就像你講的基金
# 萬一碰到什麼樣的時候
# 這個可以拿來周轉
# 應付那個狀況
# 到底會需要怎麼大的規模
# 我們現在是先開始從這個
# 這個life cycle裡面的修復
# 你這個修復的錢
# 如果說你沒有平常
# 這個把它儲備起來
# 到時候我們
# 第一個你要預估說
# 今年是要邊修什麼東西
# 很難抓
# 你突然要用的時候
# 那你預算沒有
# 那就等於要跟明年
# 或者是我們也沒有
# 預備金的這個概念
# 所以現在有請
# 那個政大的教授
# 也來幫忙我們
# 我們是台科大
# 台科大教授抱歉抱歉
# 我是台科大的
# 有請他們幫我們
# 建立一些模式
# 那從這個我們再來看看說
# 以我們現在知識條例
# 跟現在運作
# 我們怎麼樣跟主計處也好
# 或者是我們的財政局也好
# 怎麼樣來建立
# 一樣這樣的這個系統
# 萬一碰到像地震的這個時候
# 我們可能需要
# 有一個足夠的這個周轉金
# 來做
# 那現在目前是這個
# 這個構想我們要量
# 因為剛剛那個
# 行政長官有報告說
# 我們都會做四年的
# 財務的這個預測
# 那現在怎麼樣
# 說收入跟支出
# 因為隨著這個社會住宅
# 接管的這個增加
# 所以我們收入也會增加
# 像明年我們收入
# 會增加百分之三十二
# 百分之三十二我們支出
# 只增加百分之二十幾
# 但是我們回繳的話
# 會比這個增加百分之三十二
# 還要多
# 所以說像這樣有餘裕的時候
# 是要全部都先回繳
# 然後到時候需要的時候
# 再來申請還是再怎麼樣
# 還是我們有一些百分比
# 先再這個由我們來管理
# 成立一個基金
# 這個也可以說
# 從我們董監事裡面
# 再選這個基金管理的委員
# 這也是一個
# 也可以做完
# 照人家那個公司一樣
# 上市公司一樣也有
# 這個是我們已經想了很久
# 但還沒有定案的事情
# 報告董事長
# 我剛剛在想的是
# 因為沒有資產就沒有風險
# 對
# 所以我本來是在想
# 如果我們這房子是背在我身上
# 那我們應該是要去保險
# 因為有資產就有風險
# 目前看起來除了車子跟那些設備之外
# 我們是沒有資產的
# 所以那就是房東的事
# 就是新北市政府的事
# 所以其實我在思考的是
# 如果by contract
# 我們有點像包租代管的公司
# 如果包租的是這十年
# 那十年裡面的修繕費
# 是要我自己付
# 那我們可能就要編在裡面
# 看看要累在哪裡
# 因為我們不能有盈餘
# 可是它一定要parking在某個地方
# 另外一個是
# 如果我們的合約跟市政府合約是
# 我們這部分我們就包租代管
# 舉凡什麼東西壞了
# 我就找房東
# 那就是市政府
# 就是資產所有人一定要出來買
# 包租代管好像比較簡單
# 對
# 那這樣子就要跟市政府講
# 設宅的時候
# 以後什麼東西壞了
# 一定是你修
# 我們住宿中心我們只保
# 就是只做包租代管
# 可是這兩件事一定要先確認是哪一個
# 如果是資產是在房東身上
# 就是新北市政府
# 那我們只做包租代管
# 那我們這個過程中
# 就是cash flow in跟out
# 我們就balance就可以了
# 可是如果我by contract
# 是15年或20年
# 可是這中間過程某些東西壞了
# 歸我管
# 歸我修
# 那這個部分可能就跟通商長一樣
# 我們就必須把這個錢parking在某個地方
# 可是又不能算是盈餘
# 變成是未來要付的一個
# 未來應付帳款的一個暫存區
# 那這個就必須設計
# 那如果現在跟房東還沒有講清楚
# 那可能就是要思考什麼時候把它講清楚
# 否則一旦東西要修了
# 那就他會說我們住宿中心要修
# 可是我們會說你是房東
# 新北市政府也要修
# 那到底是誰編這個錢來修這樣
# 我發那時候房東還是我們建國修
# 現在這個
# 其實教授剛剛講的蠻遠的
# 其實現在這個房東是誰
# 這個房東是我們那個城鄉局
# 對 就是市政府
# 你看那個
# 你就看這張表
# 收入跟成本
# 後面有一個那個結繳
# 對結繳
# 結繳
# 其實結繳那部分的話
# 你去看這本書的話
# 其實它寫的不太一樣
# 但事實上
# 事實上
# 內容是一樣的
# 那因為結繳那部分其實也是放在成本與費用裡面
# 所以你看那個
# 21頁有沒有
# 我們這本21頁
# 你看那個成本與費用
# 這邊跟這邊的成本與費用
# 差了兩億多嘛對不對
# 那個兩億多那部分
# 事實上就是我們結繳
# 城鄉基金兩億五千多萬
# 大概就是那個數字
# 那剛剛教授提到說
# 未來房東到底要不要繳
# 事實上如果是說
# 今天
# 當然今天還沒有跟房東談好
# 就是說未來如果是說
# 真的這個東西談好的話
# 是由房東來負責的話
# 那這邊的那個數字就會動了
# 你那個結繳那部分的話
# 可能會少一點
# 這邊的成本與費用的話
# 那邊可能會多一點
# 那這個就是
# 大家如果談好的一個結果
# 是這樣一個概念
# 不過現階段我就覺得這個問題還不會發生
# 為什麼
# 因為你這個支出有沒有
# 那個結繳的房東
# 城鄉基金那個部分的話
# 有兩億五千多萬
# 所以這個數字的話
# 還不會說到達那種已經
# 已經很危險很風險
# 很高價的一個地步
# 但是那個教授這麼一個長遠的
# 我滿佩服的
# 這個一個概念非常非常好
# 那個讓我們
# 這個讓房東也知道
# 他未來
# 城鄉局可能
# 城鄉基金這部分
# 是不是未來要
# 這大家可以再坐下來
# 做一個討論 做一個思考
# 對啊 我們就想要怎麼樣來啟動這個
# 這個大家來談這個事情
# 總是說要比較清楚
# 跟各位董監事報告
# 其實在第一屆董事會的
# 第一次的會議上面
# 我印象很深刻
# 就董監事有提到說
# 在我們的這個機制裡面
# 並沒有針對
# 社宅的設備去做這個
# 做準備
# 因為一個社宅裡面有
# 我們直接講電梯好了
# 電梯可能十年
# 二十年之後一定要開換
# 那一台電梯都是一百萬左右
# 那有這麼多的社宅的時候
# 那個中心依照我們的機制
# 我們全部都要上繳
# 那我們是不是應該要
# 提前做分年的這個提列到
# 一個剛剛董事長講
# 也許是一個基金
# 或是一個準備金的部分
# 那講完那一次之後
# 其實我們一直都放在心上
# 那我們終於在去年的時候
# 我們有委託台科大跟
# 這個成大的建築系的這個教授
# 針對我們目前手上的
# 大中小的這種
# 三種類型的社宅
# 去做長期修繕計畫
# 把當初
# 強取在做社宅發包施工的
# 這個費用的部分
# 每一項的資產去做一個盤點
# 在什麼時候會壞掉
# 大概什麼時候會發生
# 大量的這個預算
# 可能要做編列的時候
# 做一個model
# 那我們在目前已經算出來了
# 我們大概每五年
# 可能要去做一次
# 這個費用的一個提列
# 做一個準備
# 應該說一個準備
# 那我們預計大概就是
# 我們希望能夠在明年之後
# 開始去做這筆經費的一個提撥
# 因為我們開始針對
# 社宅的這個營運
# 大家都知道已經上軌道
# 我們知道什麼時候
# 應該會發生什麼樣的一個費用
# 那剛剛主席處長這邊有提到
# 就是說我們目前上繳的部分
# 還算是可以支應
# 未來我們突然發生的一些
# 這個東西的一個損壞
# 或是必須要做重置
# 那至於說
# 那個資產的這個
# 這個登記的部分
# 的確我們只有三台車
# 但是相關的這些登記的部分
# 都還是由我們的房東
# 就是江局這邊來管
# 我們只是代管
# 但是將來我們修繕完成之後
# 那就變成是我們的資產
# 那另外保險的話
# 我剛才詢問同仁
# 保險的部分
# 目前都我們有在做保險
# 我們有做保險
# 好 不知道還有沒有幾項
# 來 康康剛剛講
# 剛剛因應這個我們孫教授提的
# 我想請教一下
# 就是說這些社宅
# 目前到底是登記在城鄉局
# 是歸城鄉局的資產
# 還是歸在都更基金的資產
# 因為如果是在都更基金的資產的話
# 它就會有所謂的
# 折舊的一些編列
# 所以這些以後的最後修繕
# 應該是在他的基金裡面會修繕
# 來 第二個 城鄉局
# 知道嗎
# 包租貸款的所有所謂的一併是
# 應該是就是
# 因為我本來就是要看
# 我們的這個舊房子到底能賺多少
# 可是資產不在我身上
# 城鄉局報告
# 目前社宅是登記在市府
# 但是管理機關是中興
# 所以中興是管理人
# 但是我們就是無償提供給中興
# 去做收益
# 對啊 因為它是包租貸款
# 所有權益一定是承擔
# 跟各位董事電視報告
# 就是我們在那個財產跟市府
# 就是城鄉局會計師這邊的配合
# 就是我們每個月會把
# 就是財產攤平折舊的數字
# 結算出來之後
# 提供給會計師
# 你們去做市府折舊數的認別
# 所以整個市府是有財產的
# 那個折舊師在市府那邊去做攤平
# 所以他會算到基金那邊去
# 所以他所有權益是他
# 所以他那邊也會有折舊的
# 折舊就是有一個
# 重置成本的一個概念
# 所以基本上的話
# 他是市府
# 是房東社會來負責的
# 那另外一種方式
# 如果房東重置成本
# 他不處理的話
# 那就是由你們那邊去調整
# 腳步數在那邊調整
# 然後這邊再來處理
# 這也是第二種方式
# 不過看樣子的話
# 剛剛是所有權那邊來負責
# 那個比較貪心就是說
# 你確實是需要用
# 你就把它用
# 用完了以後
# 看還應該回繳那個剩餘
# 譬如說這是兩億五
# 因為什麼理由
# 我們多花了一億
# 只能夠繳一億五回去
# 那你就說明理由
# 為什麼今年只能繳一億五回去了
# 大概是這個概念
# 所以我們的金國兄
# 就叫我們現在不用太擔心
# 我這邊還有一個小問題
# 請我們中心這邊釐清一下
# 就是在我們114年的營運計畫
# 第18頁裡面
# 1580專案是目前有10案在申請
# 可是在我們的議程資料裡面
# 22頁聽到是目前已經有20案申請
# 所以到底是10案還是20案
# 這個封卡要怎麼寫
# 應該是20案
# 因為我們114年營運計畫是比較早編
# 那58年是最近一直陸陸續續都有進來
# 所以我們會選擇
# 所以這邊是20案
# 就是簡報的是20案
# 還有沒有
# 我是想說那個
# 剛剛提到那個社宅租金的部分
# 那因為我們今年新北市的社宅
# 開始有那個分級租金
# 那過去我們的社宅的租金的收入
# 其實比較好去估算
# 是因為社宅的一般戶優先戶
# 他的租金的折扣其實是
# 就是戶數跟那個租金其實會比較是固定的
# 那現在的話就會變成因為分級租金的關係
# 會等到入住之後
# 才會去呈現說我這一處的社宅
# 他的租金大約會落在多少的收入
# 那因為我們剛好就是這兩年
# 可能有一些戶數比較大的社區
# 所以我在想說他的那個租金收入的那個計算
# 會不會因為這樣子的調整
# 就是說我在今年在設定這個收入的話
# 會有一些差異
# 那這個差異也許可以有一點準備
# 就是說我們現在估的收入其實是還滿高的
# 可是確實不確定說
# 我們實際入住的那個住戶的那個收入
# 他的租金會落在哪一個層次上面這樣
# 所以這個部分
# 這個我們可以說明一下
# 我們現在是怎麼樣預估
# 這確實是一個很好的問題
# 那資產管理部這邊說明一下
# 就是當初局這邊在年底這個促進分級制的時候
# 那也有委託外部的顧問公司
# 那就目前社宅租戶的一個
# 實際上他們的收入的資料
# 那去做一個研擬說
# 那日後變成如果走租金分級制的時候
# 他對於這個租金收入的影響數會到多少這樣子
# 那我們在編列114年預算的時候
# 有去參照他這個研究的成果
# 那他初步抓的大概是在7%
# 會影響到7%
# 會短少7%這樣子
# 那我們在預算編列的時候
# 就把這個其他的數字就先把它考慮進去
# 那後續當然實際上上路的時候
# 這個一定還會有一個波動在
# 那我們也會把今年度
# 這個分級促進制他實際上上路了以後
# 那跟我們原本預期的一個落差的情況
# 再把它做一個明年度預算編列的一個參考
# 以上回覆
# 這個可能確認一下
# 但我依稀記得的是這樣子
# 就前幾天我們在北市住都的時候
# 開會的時候
# 好像是市政府針對租金差額的部分
# 他是編了一個預算當成補助款
# 然後百%進來
# 所以住都中心我們本身的成本
# 會影響
# 就是多少
# 所以我們這邊這樣是很清楚的
# 只是因為老闆嘛對不對
# 市政府或市長他想要給大家多少優惠
# 那你就市政府那邊要去編預算
# 那編預算之後樓好進來
# 我們這邊才會stable
# 就是說我們是在營運嘛
# 就是你不能你開著支票
# 然後我幫出代管
# 我來降租金
# 那這樣子帳會亂掉嘛
# 所以我記得會是這個樣子
# 就是北市府針對於租金降低的部分
# 他是提列一個預算補進
# 那我們這邊就是營運
# 那當然有多我還是繳回去嘛
# 那用這樣的方式看起來是比較清楚
# 那否則的話就是執政團隊會
# 就是很開心的開支票
# 可是我們這裡差額的部分
# 由我們這邊去調整
# 那永遠會算不清楚我們的成本
# 就是營運成本跟整體的收入支出的一個關係
# 反正我們這邊有多賺我們還是不會繳回去
# 所以就看用哪一個方式去做
# 請問一下你說的是哪個市政府
# 台北市政府
# 我們支持他
# 這個部分我再補充說明一下
# 台北市的那個市政府補貼的那個部分
# 只有台北市有一部分的一個低收入戶
# 然後他原來住的是平價住宅
# 平價住宅那一個部分
# 那那個部分他收的租金
# 他的繳的租金就非常的少
# 每一戶非常的少
# 那那個的
# 那可是住宅中心這邊要收的部分的租金
# 是一個額度
# 那這個部分由社會局整個補貼給
# 住宅中心
# 我是覺得我們
# 這個分級的這個還有一點
# 我是覺得我們的收入
# 平常都有結餘
# 所以我們自己能夠那個
# 而且事先編的時候就有考慮到那個
# 那個是7%
# 大概7%
# 差不多是這樣
# 我覺得我們新北市政府
# 就不需要額外再有本益算再編那個
# 因為這個倒回
# 用剩的還是要繳回去
# 盈餘的部分還要繳回去
# 只是說真的不足的時候
# 就是那個基本營收繳回款那個部分
# 再來跟那個我們的房東
# 再來跟他討論
# 今年度因為是怎麼樣
# 所以就會短少多少錢
# 當然這樣就比較好
# 這樣就可以了
# 因為我們的老人
# 不是老人啦
# 這個進勞卡的部分
# 昨天李副市長來我辦公室聊天
# 他講到說你都催他去領那個進勞卡
# 對啊他說
# 要把他用光光
# 我說我們編益算
# 其實也沒有編滿
# 還是很多人都
# 台北市也用
# 不可能編滿
# 因為很多人就是沒辦法用
# 都用三分之一
# 他有的缺陰我們一定要通知他
# 不然就會發生沒通知又來抱怨
# 他昨天就是去板橋市公所
# 辦這個然後到我辦公室來聊天
# 還有特別談到說
# 我們社會局
# 一直逼他進來
# 480點要用完
# 你知道多少錢嗎
# 如果編組的話
# 那不得了那是補貼
# 那不得了耶
# 這個我們參考
# 我們應該已經有在因應了
# 應該我們的現在收入
# 還沒達到的收入
# 如果真的是不行的話
# 我們等於是從基本營收那邊
# 來調解
# 包括我們所講LiveCycle
# 裡面的重大的秀
# 那個才是我們可以想看看
# 什麼時候啟動跟我們房東
# 跟我們財主單位可以來討論
# 至於說我們現在包租貸款
# 不過那個比較單純
# 反正財政局他是房東
# 所以他會負責
# 我們等於是說
# 供錢
# 跟他供錢
# 貸付給我們不會上
# 好 不知道還有沒有什麼
# 請大家指教
# 林監事這邊有書面意見
# 針對業務及營運計畫四
# 114年度工作計畫一
# 第六項的國內政策建議之內容
# 總統提及社宅管理流程項目
# 建議實際研究規劃時
# 能按所欲解決之管理問題
# 有採取執行力措施
# 具體提出研究細項
# 這個
# 那個
# 我們目前中心有針對
# 用戶評估還有
# 社宅這些住戶在使用上
# 有沒有什麼問題
# 其實我們每一年度都會做一個檢討
# 還有問卻的部分
# 我想這部分我們會跟
# 也有一些可能會跟
# 這些研究單位來做看怎麼樣去做配合
# 作為未來在政策在制定
# 還有在興建
# 社宅的時候的一個參考
# 那這部分我們會去做一個加強
# 我們已經差不多
# 今年第四年
# 大概會碰到什麼樣的問題
# 比較清楚的可以
# 初步的列出一些
# 這個研究
# 覺得說可能還可以更進一步
# 去精進
# 去了解那些研究案
# 那另外我們
# 收集的這些資料或是我們問卷的資料
# 等等是國家住宿中心跟
# 台北市的他們也是
# 因為現在住宅管理的單位
# 都有定時會有聯誼
# 他們也是蠻期待就是說
# 我們的這個資料可以
# 跟大家分享那我們也很願意
# 這個可以
# 三個中心
# 目前就新北市就是我們
# 我們管理的最多
# 因為國家只有林口而已
# 台北市只有逛市
# 才今年度開始
# 那目前是我們的經驗最豐富
# 那我們定期這三個中心
# 大概每半年會有一次
# 大型的這個研討會
# 會針對社宅管理上面
# 的一些問題做一些
# 交流
# 我們最近得了兩個獎
# 也順便跟我們
# 董監事報告一下
# 一個是社宅管理一個是那個
# 那個
# 雖然說獎牌是我們自己出錢去買的
# 出錢給他們
# 幫我們做的
# 那個叫什麼
# 國家卓越建設
# 國家卓越建設獎
# 那一個得
# 金獎就是我們央北社宅
# 一千多戶
# 那另外一個是
# 我們大城
# 更新單元三
# 是都市更新規劃類的
# 特別獎因為在
# 整合上面
# 目前公辦都更案並沒有像我們這個案子
# 有這樣的一個
# 做法
# 是不是也報告一下
# 上次會議有一個特殊的個案
# 後續處理
# 打官司的那個
# 那個有
# 說明一下
# 我們跟社會局跟我們合作
# 圓滿解決
# 那個
# 應該是剛剛那個
# 董監事問到的應該是
# 受攬社宅的那個無知一戶
# 的那個部分
# 後來我們的處理方式就是
# 我們跟社會局這邊
# 有達成一個協議
# 就是說他是用一個專案的方式
# 他等於說他不是
# 他現在不是我們社宅的一般的
# 主股那他是用一個
# 專案的方式做一個案子
# 因為他們家的這個
# 他的承租人就是母親的部分
# 他就是年事已高
# 而且他也沒有辦法做一個移動
# 所以我們接下來就是會用
# 一年一簽的方式然後去
# 去評估看他是不是
# 他的狀況是不是還是
# 繼續適用這樣的一個
# 專案的方式然後每年就再做
# 重新的訂約
# 這個評估的部分社會局會幫
# 原則上就是服務
# 那個年紀大的
# 也要讓他
# 身體或者因為
# 這個沒有住搬來搬去
# 他那個環境有改善嗎
# 安全有改善嗎
# 對他裡面的那個環境
# 我們還是要求
# 基本上這個租戶
# 他還是不希望我們進去做訪視
# 因為他還是
# 他本身態度上還是有一些
# 堅持對那這個部分我們也是
# 比較轉向說
# 有一個設公司他進去
# 跟他做一個訪視跟了解這樣子
# 然後再把裡面的狀況再跟我們做一個
# 一個交流
# 對所以
# 真的是各局處配合
# 是蠻重要的
# 所以人的部分是繼續安置在那裡
# 對
# 但是他的公安問題如果他還是
# 肯處理的話這個公安對這個
# 整個社宅來講還是一個
# 潛在的
# 特別提醒他
# 這個部分
# 因為我們還是有一個
# 訪視的機制在
# 變成說他們現在是
# 比較不同意讓我們
# 去做訪視
# 我們社工這邊比較可以
# 一個協助跟關懷的角度
# 進到他的屋內
# 那我們也會去了解說他目前是不是有一個
# 比較改善的一個狀況
# 跟他新的企業上面是有要求
# 合約上面是有訂定
# 如果有違反公安消防那些的話
# 就必須要
# 就是終止合約的這個部分
# 往以前來講我們住戶都是
# 三年以前
# 那現在住戶就是一年以前
# 那配合社工的這個機制定期的訪視
# 那社工也會回報給我們的
# 中心的同仁讓他知道說
# 現在裡面的這個狀況
# 那這個社工的時候進去之前
# 我們也會跟他做一個保持聯繫
# 這樣子來定期的訪視
# 所以這個訪視的一個
# 機制可能就是要請
# 社會局這邊的社工人員
# 譬如說去的時候
# 可能有一些拍照
# 或什麼你要傳給我們
# 跟中心這邊
# 他才能夠去掌握他到底會不會影響公安
# 那才能夠掌握到
# 要不然的話
# 處理上還是要有一些技巧
# 我想剛剛委員提的這個
# 當然我會交代我們同仁
# 不過至於拍照這個部分
# 我們要來處理
# 不見得一定要拍照
# 如果我們透過過程可以協助他
# 我覺得不應該一定要求要拍照
# 要達到效果就好
# 達到效果就好
# 基本上來講
# 他經過這一次事件之後
# 他的態度其實是有改變的
# 因為他認為
# 他如果到外面去住
# 他可能也住不到這麼便宜
# 那他可能因為媽媽也年事已高
# 身體有一些問題
# 所以他也覺得說
# 就稍微收斂一點
# 所以我們目前
# 跟物業管理他之前的態度比較差
# 那現在的態度是有些比較收斂
# OK 還有沒有其他的建議
# 如果沒有這個
# 就通過
# 財務
# 明年的
# 文字部分需要修改
# 再做最後的確認
# 討論案二
# 本中心114年度
# 營業物及營運計畫
# 經全體出席
# 皆是一致同意通過
# 並授權住都中心
# 依照會中建議文字修改
# 後續依
# 新北市住宅及都市更新中心
# 設置自治條例規定
# 報新北市政府備償
# 先下來進行討論案三
# 本中心114年度
# 預算案
# 請各位董監事參閱
# 依存資料的第46頁
# 複測及簡報資料的第72頁
# 到77頁
# 本討論案由行政部
# 財務組組長吳妙慧報告
# 各位董監事
# 大家午安
# 請參閱簡報第72頁的部分
# 下述你
# 本中心114年的預算案
# 本中心114年的
# 預算書呢
# 會依照新北市行政法人
# 預算編制注意事項規定
# 已經完成編報
# 有依存資料的複測
# 會前我們已經送請
# 城鄉局會計師以及主計處
# 預做審查
# 有關社會住宅當年度營業收入的部分
# 會依照新北市住宅
# 及都市更新中心
# 盈餘回繳
# 城鄉發展基金辦法
# 去計算營收繳回款
# 以及盈餘結繳基金的部分
# 我們的預算會以
# 收支平衡為原則來進行編列
# 那以下僅就
# 114年收支概況
# 再要進行報告
# 在簡報第73頁的部分
# 是114年
# 預算收入跟
# 成本費用編列的部分
# 那收入跟支出
# 的部分是統合
# 為六億四千三百四十八萬一千元
# 較上年度
# 四億八千六百七十四萬一千元
# 提升了百分之
# 三十二點二
# 在簡報第74頁
# 是有關於收入的部分
# 114年的預算總收入
# 比113年的
# 預算數增加了一億五千六百七十四萬元
# 那各項收入的部分
# 勞務收入
# 是一億兩千五百一十一萬六千元
# 比113年度
# 增加了兩千四百三十三萬元
# 六千元
# 成長了百分之二十四點一
# 那這個部分會依照
# 前面業務計畫的說明
# 各個都更案件以及受託
# 財政局委託就是
# 涉宅營運的服務收入的部分
# 依照就是
# 規劃的作業行程進行
# 那在租金離權
# 歷經收入的部分呢
# 金額是五億一千一百五十二萬兩千元
# 比113年度增加了
# 一億兩千七百五十六萬一千元
# 成長的比例是
# 百分之三十三點二二
# 那目前的話
# 我們的規劃是依照114年
# 受託的三十處的
# 一個受託管理的
# 社會住宅入住率都能夠維持
# 達到百分之九十以上
# 以及在114年
# 新接管的設宅
# 開始進行委託接管營運的部分
# 那其他業務
# 收入的部分呢 預算數是
# 三百八十四萬三千元
# 那去年度沒有編列預算
# 那這個部分是
# 我們針對目前就是
# 社會住宅一些行動電話機房的
# 使用收入
# 依照規劃進行編列
# 那在財務收入的部分呢
# 預算數是編列三百萬
# 是隨著
# 就是社會住宅營運的
# 那個戶數的增加
# 那我們針對設宅跟停車位
# 會收取押金這個部分呢
# 作為一個
# 就是一年期的定存
# 去做規劃 那這個部分呢
# 會有一些支息收入
# 整體評估下來會比113年的預算
# 會增加大概過近百萬
# 在
# 簡報第75頁的部分呢
# 針對支出的部分做說明
# 那支出呢我們會包含
# 有成本、費用以及
# 結繳數的部分
# 那就上面的四項
# 就是各項成本跟
# 費用的部分呢
# 因著
# 業務收入的增加會有一些增加
# 的比例
# 那就是
# 包含在公司資產成本、業務費用
# 以及管理及總務費用、財務費用等
# 合計的金額
# 大約是佔總支出的百分之六十
# 那剩餘的百分之四十
# 的部分呢就是
# 結交款的部分
# 那總額是包含基本營收小本款
# 跟營運結交的部分
# 總數是兩億五千八百四十二萬八千元
# 那這個部分呢
# 就是我們在
# 就是會議資料提供之後
# 有發現就是
# 數額有一些不值的部分
# 那依照
# 就是基本營
# 就是結繳犯法的計算
# 實際上應該是
# 基本營收小本款應該的數額是
# 兩億五千六百零八萬三千元
# 跟我們
# 所提供的會議資料
# 兩億五千五百九十二萬八千元
# 會增加了十五萬五千元
# 那同時呢
# 也會影響到就是
# 營餘結交的部分
# 因為我們整個收入支出的計算
# 是以平衡預算來編列
# 所以呢營餘的部分就會同步減少
# 十五萬五千元
# 那這個部分呢就是要請董監事同意
# 中心予以修正
# 那因著
# 租金及權利金收入的增加
# 一百一十四年的
# 基本營收小本款是
# 就是兩億五千六百零八萬三千元
# 那比
# 一百一十三年的增加數是
# 八千兩百五十三萬兩千
# 那成長的比例是
# 四十七點五
# 跟簡報的資料會有一些差異
# 那另外在
# 簡報第七十六頁的部分呢
# 是本中心
# 近五年來的收入跟支出的
# 一個執行
# 那從中心
# 一百一十年成立以來
# 經過五年的持續的成長
# 那一百一十四年的
# 預期的收入大概會是
# 比一百一十年的預算收入的
# 大概四點八倍
# 那收入的增加率是
# 指數也會持續的增加
# 在簡報第七十七頁的部分
# 有關固定資產
# 改良擴充的部分呢
# 一百一十四年的設備擴充
# 在上面的
# 動產廠房設備的部分呢
# 主要是
# 配合農甲分肥
# 設宅的一些
# 試裝工程
# 冷氣的設置跟熱水器的
# 安裝這個部分
# 還有就是採購會用的平板
# 等等的支出
# 那在無薪資產的部分呢
# 有兩百萬的部分
# 是針對官網的優化
# 去做一個規劃
# 那以上是我們一百一十年
# 預算摘要的一個報告
# 看看有沒有什麼
# 什麼指教
# 如果沒有的話我們是不是
# 可以
# 監事這邊有一個意見
# 勞動一下
# 一百一十四年預算需求
# 是否已充分對應
# 所提出一百一十四年業務
# 及營運計畫
# 以及各項收支用
# 預算需求必要性
# 與合理性等
# 提報前再自行檢視
# 並過去年度
# 收支執行實際數與
# 編列數有重大差異項目
# 提醒於一百一十四年編列
# 作業要充分考量
# 避免再發生
# 請執行長參考
# 有沒有什麼指教
# 對這個目前編列的
# 這個預算的部分
# 我們有意見
# 可是我有一個要強調
# 我們的這個資料裡面
# 從我們的
# 這個預算的資料裡面
# 二十六頁這邊
# 我們住宅租金收入的話
# 是四億多
# 那我們的這個
# 各處設宅物管的
# 費用的話
# 是兩億多
# 那是大概佔到百分之二十五
# 就是物管佔我們住宅收入的
# 這個部分
# 我猜清楚
# 就是說這樣子的
# 物管費
# 是合理
# 或者是
# 剛剛我們在那個
# 相關的這個
# 我們下年度的這些營運計畫裡面
# 有講說要導入智慧化
# 電子化設備
# 可以降低這設宅管理責任
# 那將來針對我們這些的
# 設宅漸漸的越來越多
# 達到一定規模以後
# 是不是達到規模
# 將近或怎麼樣可以降低
# 或者是這些的
# 電子化設備
# 降低的
# 這個費用
# 物業管理
# 現在佔百分之二十五是蠻高的
# 對
# 有哪一位要
# 跟總監事報告
# 就是
# 我們的向來就是物管費用
# 其實算是我們
# 為於設宅其實蠻大宗的
# 一個成本
# 那包含就是
# 現地的那個保全人員
# 跟物管箱的那個部分
# 那另外就是說目前我們
# 在就是
# 目前就是物管費用
# 這個部分我們有談過
# 就是針對機電的一些維修
# 保養的部分也都涵蓋在裡面
# 還有設宅的一些
# 植栽的部分
# 所以其實
# 例行性的維修的部分
# 現在目前就是放在物管費用
# 所以他的那個
# 加上這幾年就是針對人事成本的提高
# 所以目前我們在
# 物管費用的邊界上面
# 確實有比就是前兩年要增加一些
# 那其實也是反映到
# 人事成本的提高
# 目前的平均這個
# 旅賓的管理費大概是多少
# 我們有賣這個數據
# 管理費也是包括在這個裡面
# 管理費有包括在租金裡面
# 對 管理費是在租金裡面
# 對 差不多佔多少錢
# 這個部分我們可能
# 要再做一個細算
# 就把這個物管費用再攤算到
# 裡面去看這樣子
# 董事的意思是說我們現在佔四分之一
# 成本大概佔四分之一
# 就是物管費用
# 那好像是稍微高了一點
# 那如果說我們含
# 那些要算
# 就是比較的基礎要把它弄成一致的話
# 這樣才會比較那個
# 這個可能我們回去可以再
# 進一步把它分析
# 因為我們現在那麼多年
# 應該是可以更進一步的
# 那這個是後續
# 新的標案出來
# 或者是說續約的時候
# 這個都可以做為我們那個
# 招標的這個基礎
# 這是管理上是可以
# 就是說假設我們每一瓶
# 收一百塊
# 我多少錢我不知道
# 那如果我的物業管理的
# 支出是一百二十塊
# 對 那我們就虧本了
# 就虧本了
# 現在應該
# 因為還要付
# 我們的薪水等等
# 沒有那麼多
# 這部分我會後之後
# 我會跟資產管理部這邊來做一個分析
# 那基本上我們目前
# 社團並沒有收管理費
# 如果用管理費的角度
# 的確剛剛阿雪董事
# 提的這個想法
# 我覺得是可以去討論去分析的
# 就是我們目前
# 我們其實是租金
# 租金裡面
# 含管理費
# 租金的架構
# 有一定的算法
# 管理費也有一定的算法
# 所以這個我覺得我們經營的
# 越來越多的時候
# 那這個部分應該要
# 要好好複習
# 好
# 好 還有沒有
# 那請
# 這一點大概也是請教
# 就是跟會計商多嘗試怎麼做
# 比方講我們四十一頁的固定資產
# 擴充明細表這裡
# 我把建物改名拉了兩個
# 一個部分是這個管線包覆工程
# 這邊大概是
# 一千兩百萬左右
# 然後另外一塊是這個門窗
# 跟防水修繕
# 這邊是七百多萬
# 那就現金來講
# 我們就是付掉
# 只是你把它列為我們資產
# 然後再去折回來
# 可是基本上是
# 就是說主體不是我們
# 那修
# 可能你也搞不清楚修哪裡
# 所以你財產還真的不知道
# 貼哪裡對不對
# 所以就這個部分來講
# 就我們中心的管理
# 是要把它當成一次性支出
# 就支掉
# 還是必須掛一個帳
# 建物改良
# 不會再折舊了
# 這個應該是
# 那一直掛著也不是個事
# 因為
# 這看起來可能還是會折吧
# 你如果這樣的話
# 理論上是會折到
# 所以到底要不要掛帳
# 這是我一直在看這一頁的想法
# 就是說其實也不多啦
# 就兩千萬
# 那修完之後
# 有時候修修補補
# 你還真的不知道去補哪一行
# 所以它就會形成一個
# 對我來講是一個支出
# 那不知道會計上很習慣的是
# 會把它列到一個固定資產
# 然後就掛在那個帳上
# 因為畢竟那個房子不是我們的
# 那這是我的疑問
# 跟董事說明一下
# 就是針對建物改良這個部分
# 我們當初就是也
# 就是在客戶使用上
# 也跟會計師做了很多的討論
# 因為畢竟建物的主題不是中心的
# 可是它的金額又達到一定的規模
# 那在會計師的認定上
# 他也沒有辦法
# 就是同意我們在當年度
# 把所有的費用在年度裡面去做一個認列
# 所以針對這個部分
# 他其實給我們的金額
# 用一個建物改良的客戶
# 然後他實際上是
# 比照財產的方式
# 就是看體數
# 所以我們目前列了這兩項
# 第一項是針對就是融價
# 分回社宅的就是初期的一些建築的部分
# 那第二個項目是
# 我們就是
# 如同剛剛金導有提到
# 我們跟那個學界
# 那邊有討論過說
# 依照大中小的一個社宅的
# 皮膚起來我們大概在明年的時候
# 能夠規劃的一些
# 大型的修繕的一些
# 那整個就是估下來
# 我們現在立即要處理的
# 我們就先
# 就算編列的方式把它編入
# 未來的規劃
# 來一次我們就這樣的一個執行
# 所以他有他們
# 他們的辦法
# 這個會計師
# 好不知道還有沒有其他指教
# 這個是不是
# 這個部分
# 是不是應該
# 監察你們這邊應該可以協助一些
# 因為事實上這個
# 預算的費用只能編一個地方
# 那如果我們這邊編了
# 都更基金那邊應該就
# 沒有這一筆
# 所以這個部分
# 他只是結語的部分
# 講回去的話才有
# 但是他事實上要折舊的時候
# 他就有一些所謂的
# 所謂的維護成本的部分
# 所以這個部分應該是說從
# 我們的預算裡面
# 怎麼樣去區別
# 不然重複編列應該
# 到底是我們這邊來編還是
# 城鄉局的那邊
# 應該反正
# 往往出在養生上
# 你不夠的最後還是有基金那邊來支應
# 應該是說
# 在哪裡使用在哪裡編
# 只要有一致的做法就可以
# 就是要有一邊要處理
# 對啊一邊處理
# 了解一下看有用
# 我剛剛的意思是說
# 其實是一次新支出已經支出去了
# 對啊
# 然後你這邊
# 到底要貪二十年還是三十年
# 就是一個門窗防水工程
# 比方講他讓我們折
# 那就等於在
# 帳上還要再掛十年
# 但是這個cash flow已經付出去了
# 只是好像感覺
# 我們有一個固定資產
# 在那裡
# 那對我而言
# 還是
# 我們要真正
# 得到一個資產
# 跟會計師再討論一下的確
# 剛剛教授講得不錯
# 修完
# 不應該是不動產
# 會計師有
# 會計師一定有他的道理
# 他會有他的一個會計的原理原則
# 因為修上
# 在會計的角度裡面
# 他有分什麼
# 他有分大修跟小修
# 小修的話當費用
# 大修的話我們這邊有那個會計
# 大修的部分他可以延長
# 耐用連線的部分他把它當資本
# 那他這個金額
# 他來看的話他看出說他是不是可以延長
# 他的耐用連線
# 或者說他金額達到某一定的一個金額
# 的情況之下
# 那他就是他的固定成本
# 就不是上一次的費用
# 我想那個會計師他一定是有這樣的一個概念
# 他們有討論過嘛
# 會計師就是要這樣
# 金額大的要這樣
# 要這樣弄
# 五塊以後這個會裂一百
# 就是這種中間就會裂
# 項目
# 但是沒關係
# 他說會延長壽命的他會這樣
# 跟那個
# 虧損認列一樣
# 那我另外提一個
# 就是
# 一個是小問題
# 就是說我們現在按照我們的
# 行政法人法還有按照
# 中興的這個自治條例裡面
# 特別有規定說
# 什麼樣的條件之下
# 你就只要送市府就好了
# 不用再送議會審查
# 那是不是可以建議這邊標註一下
# 讓所有的董監事知道一下
# 114這個預算到底要不要送議會
# 在這邊
# 不然董監事可能不知道這個東西
# 到底要不要送
# 應該是不用嘛對不對
# 因為裡面有50%嘛對不對
# 所以找個地方標一下註明一下
# 其實我們這東西
# 你們放心
# 這個東西我們到時候不會送到議會去
# 送到去那邊被討論之類的
# 這個註明一下
# 你是要讓議員放心還是
# 讓我們放心
# 讓我們現在做的董監事稍微放心一下
# 這個部分我們114年
# 依照我們的設置自治條例
# 未定的
# 只有是送市府備查
# 不需送到議會
# 這個註明一下
# 就是後續我們在簡報的時候再提醒一下
# 對 以後就讓董監事知道一下
# 把他塗黑了
# 謝謝
# 好
# 如果沒有其他意見的話
# 我們還是決議
# 如果有錯誤的
# 剛剛有講的那個就是我們
# 其實是超過那個級距
# 他忘了說這個級距
# 要變成70
# 因為我們是累積的級距
# 那個級距的話
# 那部分的話就是要回繳的比例會增加
# 但是最後那個級距
# 他沒有把它分出來
# 所以少了15萬
# 這個城鄉局的那個幫我們看出來
# 所以我們就15萬
# 那個部分我們還是要再修訂一下
# 討論案生本中心114年度預算案
# 經全體出席董監事一致同意通過
# 後續爐溫涉及重大改變
# 而有誤寫物質
# 明顯錯誤或新北市政府建議修正者
# 授權本中心予以修正
# 並依新北市住宅及都市更新中心設置自治條例規定
# 報新北市政府備查
# 接下來進行討論
# 本中心擔任台北市文山區木柵段一小段912D號等24筆土地
# 公辦都市更新實施者案
# 請各位董監事參閱議程資料第47頁到48頁
# 複測及簡報資料第80頁到102頁
# 本討論案由綜合業務與部專案組主展業養報告
# 這個二樣的報告
# 各位董監事大家好
# 現在由綜合業務來報告一下
# 這次提報的公辦都市更新案
# 那今天簡報公安總共分為五個部分
# 首先在簡報第82頁的部分
# 那我們這個案子的基地是位在台北市文山區的九康街
# 以及秀明路一段的交叉口旁邊
# 那土地面積大約是1816平方公尺
# 那在簡報第83頁的部分
# 那我們基地內總共有24筆的土地
# 所有權的單位有22人
# 那產權的部分
# 公有土地佔了89%
# 私有的部分佔了11%
# 那在簡報第84頁
# 那我們基地內只有一筆合法的私有建築物
# 只是一個人持有
# 那在簡報第85頁的部分
# 那我們是依照文山區的一個都市計畫所載的一個內容
# 那我們全區都是第三種的住宅區
# 那在簡報第86頁
# 那基地現況的部分
# 目前的話多數都是以一層樓的一個老舊建築物為主
# 那大約有14戶
# 那合法建築物只有一戶
# 那增建的部分也有佔用到計畫道路上面
# 那接下來說明一下容積獎勵的部分
# 簡報第88頁
# 那目前我們依照整個基地的規模以及條件
# 那我們預計會去爭取整個容積獎勵到48.23%
# 那在我們容積獎勵評估過後
# 那我們在簡報的第90頁的部分
# 那我們參考了周邊的一個市場的行情
# 那我們在15年內的一個住宅的產品的部分
# 目前的銷售價格大約是61到67萬一平
# 那新成屋的部分大約是在65到75萬一平
# 那平均大約是70萬
# 那在簡報第91頁的部分
# 那我們剛剛講到依照基地的條件
# 算出了建築的量體
# 以及未來的銷售的一個面積
# 那目前我們大概預估是在
# 銷售面積大約是2840平左右
# 那在整個量體的部分
# 預計是規劃在地上15層
# 地下3層這樣子一個規劃
# 那在簡報第92頁的部分
# 那我們有初步以住宅產品來預估
# 未來更新後的一個價值
# 所以我們未來整個案子更新後
# 大約會創造大約21.36億的一個
# 一個更新後的總價值
# 那在簡報第93頁的部分
# 那共同負擔的部分的話
# 我們目前依照規定
# 計算大約是9.96億的一個成本
# 那所以我們目前依照這樣子的成本的話
# 共同負擔比例大約是46.63
# 那我們在依照了整個基地的一個條件
# 那我們有模擬了幾個
# 開發上面的一些課題
# 那第一個課題是
# 我們未來是需要經過台北市政府審查
# 選定我們整個基地為公辦都更的一個案子
# 所以那我們建議是後續我們會
# 依照台北市的一個公辦都更實施辦法
# 來辦理事宜性的評估
# 來選定我們整個基地為公辦都更案
# 那完成之後
# 我們後續還有發訂更新地區的一個作業
# 那這樣子作業完成之後
# 後續我們就可以來做招商
# 那在簡報第96頁
# 第二點的課題的部分
# 那我們後續會擬具
# 事宜性的評估來送審的時候
# 我們會了解更新單元
# 除了事宜性檢討之外
# 那周邊的林地的一個居民的意願的調查
# 我們也會去做一個調查
# 那避免是造成林地
# 他沒有辦法去做都更的一個情形
# 所以我們後續依照相關的規定
# 我們會去徵詢林地的相關授權
# 並且剛剛說明說
# 整個公辦都更的一個程序
# 以及推動的方式
# 那在簡報第97頁
# 第三個課題的部分
# 因為我們基地景林的987地號
# 在我們簡報上面的圖上的範圍三這個部分
# 它是面積只有67平方公尺
# 那依規定它是被認定為是基林地的部分
# 那後續我們建議說
# 我們去在整合的階段
# 我們去徵詢這塊基林地的所有權人
# 他的參與意願
# 那如果他沒有納入這次的更新單元的話
# 那我們後續會依照規定來做調除
# 那在簡報第98頁的部分
# 那第四點課題
# 本案基地景林988的地號
# 在簡報的上面
# 我們有標示範圍四的一個部分
# 那這個範圍是道路用地
# 那所有權人一樣是新北市政府的財政局
# 那因為遭到佔用
# 導致這個計畫道路沒有辦法去做完整的通行
# 那我們後續是會建議說
# 這個這一塊988的地號納入在我們更新單元之內
# 並且我們會跟佔用人來做協議
# 讓這個計畫道路能夠順利的來開發的通行
# 那在簡報第99頁第五點的課題的部分
# 那依據我們現場的勘查的結果
# 那其中有14筆的門牌
# 是有跟新北市政府財政局有租約
# 租占的一個關係
# 8筆有做一個租賃的契約
# 6筆有做一個繳交使用補償金的一個情況
# 那所以我們目前這個基地範圍內的租占的狀況
# 可能會影響到我們後續的一個案件的一個推動的期程
# 所以我們建議說在前期階段的時候
# 我們會去初步的去調查這個租戶的餐飲意願
# 那我們同步的會去檢核說
# 這些舊違章的建築物的一些資格
# 以及它的面積的測量
# 那我們在招商之前能夠順利的先跟這些數目達成協議
# 那後續的一個實施價位跟時程的話
# 那我們經過這次董事會通過之後
# 那我們會開始做一些林地調查的一個作業
# 後續就會提送到台北市做一個公辦都會事宜性的評估
# 劃定更新地區取得中興單位實施者的一個資格
# 那在程序完備之後
# 我們就會啟動整個先行規劃的一個作業
# 以及招商的一個程序
# 那我們是預計在115年底來做招商
# 那在簡報第102頁的部分
# 那在實施架構的部分
# 我們將後續中興取得了實施者的資格之後
# 那將由中興來擔任前期的一個規劃整合
# 以及拯救出資人 專案管理等等的這些工作
# 讓我們整個案件能夠順利的一個推動
# 以上為本次友善物價案的一個報告計畫
# 好 我們看我們董介師有沒有什麼要指教的
# 這個位置不錯啦
# 那個應該還會 這樣子還會再往上
# 好 來 請
# 我贊成這個案子
# 那這個案子其實基本上也算單純
# 所以那個我們是到115年12月才公告招商
# 我覺得這個期程也許可以檢討再往前移
# 好 謝謝
# 還有沒有答案 那離政大很近
# 其實這件事情我們新北住宿中心當實施者
# 我們想說更新完
# 因為我們想要看到的故事
# 完成交付之後怎麼處置或處分
# 其實是一個很大的重點
# 那我們新北住宿中心去當實施者
# 弄完之後當社宅 社宅住的是台北市的
# 那算你新北市的社宅
# 這個是財政局的
# 對不對
# 如果是財政局那他就是收益或是處分
# 對不對
# 那如果是這樣子的話
# 我在想說我們新北住宿在這個過程中到底
# 因為我們看收入
# 到底是哪一塊勞務收入
# 還是哪一部分的收入會挹注到我們
# 就是去run這個project
# 那當然是我們自己按照平台自己去做
# 所以如果我們不管交付之後的事
# 那就是我們新北住宿就是去跟財政局談一個deal
# 然後去變成我們的勞務收入
# 是這樣
# 那如果回到財政局
# 那他回給我們比較划算
# 還是回給其他單位可能會比較划算
# 這個就會是走到另外一項
# 那另外一點我在看那個部分條例第12條
# 他到底是在講該管政府直轄市或縣市政府
# 可以實施都市更新的方式
# 可是我們今天跨區了
# 所以是不是用這個12條
# 我剛剛也一直在思考
# 因為我從來沒有思考過這個問題
# 就是說他寫的是我直轄市
# 我新北市
# 然後我怎麼在我新北市裡面
# 有就是官方主導的都市更新
# 可是我們今天是新北市要划到台北市
# 因為那是我的地
# 去做這些事情
# 是不是適用12條
# 我可能這陣子我再思考一下
# 或許這是沒有問題是對的
# 所以OK
# 那我知道我們就是去跟財政局
# 然後去收勞務收入
# 然後就談一個deal
# 然後就放這個更新案
# 那最後就會看我們跟財政局收的這個錢
# 我們的cost的支出
# 會不會至少balance或是小賺一點
# 那如果是這樣的話
# 可能是大賺一點
# 跟教授說明一下
# 大概兩個事情
# 第一個是依照更新條例第12條
# 我們那個有一張表
# 第101頁
# 目前依照法律的規定
# 的確不是新北市政府同意
# 新北駐都中心擔任實施政策
# 台北市同意新北駐都中心擔任實施政策
# 所以這個法律上是沒有問題
# 然後第二點就是剛剛講的
# 我們中心擔任實施者
# 那我們獲取什麼樣的一個報酬
# 基本上就跟大城山一樣
# 我們沒有分房子
# 因為沒辦法擔任名義上的這個
# 實際上的實施者
# 出資換折抵這個樓地板面計畫
# 我們基本上來講
# 我們就是跟未來的投資人出現之後
# 我們收取權利金
# 就是工程管理費的一部分
# 作為我們的大半費用
# 這一年來的這個大半費用
# 我們已經有另外一個案子
# 也是在新榮路附近的
# 也是有台北市政府也同意我們擔任實施
# 至於說財政局違給他自己做
# 還是說他違給中心哪個比較好
# 其實基本上應該回到市府的政策
# 因為住都中心成立的宗旨就是
# 未來的話所有的公辦
# 應該都會回到我們住都中心那邊
# 來推這個公辦的主政這樣子
# 至於剛剛那個阿雪董事問的說
# 可不可以縮短時程
# 我們也希望
# 但是因為這案子就是考量到
# 因為在台北市
# 那必須依照台北市的這個
# 他的程序必須要做適應性的分析
# 那台北市是比較
# 我們沒辦法去做
# 但我還是會去跟他們做
# 保持這個聯繫跟溝通
# 希望能夠加速
# 同意我們擔任實施這樣的一個時程
# 因為這是我們的盈餘
# 我們也是會回繳到
# 回繳到我們的土耕基金
# 如果是委託外面的話
# 他就賺走了
# 所以我們是更新會的
# 原來這個案子
# 記者的條件不錯
# 我再補充說明幾點
# 因為剛剛我沒有發言的一部分
# 因為除了我是董事以外
# 我也是福利秘書長
# 所以剛剛孫老師
# 大家在討論那個攤體择就
# 等等相關的問題
# 到底是從房東還是從中心這裡
# 是從府的立場來講
# 對外來講
# 我們會有一個答案
# 一定會有答案
# 他不會重複去編列
# 但是這裡面也顯得到財政局
# 租屋中心 城鄉局
# 工作上的協調
# 我想那個董事長
# 那個陳副他也是福利的
# 我想最終一定會把這個部分
# 只是現在因為
# 畢竟租屋中心成立
# 現在的社宅的部分
# 還沒有到營運管理
# 營運的部分
# 或者是維護的部分
# 大量的相關的支出
# 但是這個問題
# 其實在裡面都會心裡有底
# 這個將來勢必會把它做一個
# 整個的釐清
# 我想這個絕對沒有問題
# 那至於這個案子的部分
# 原則上因為我們以前
# 興隆已經有個案例
# 是有一點那個財務分析上面
# 給中心做個參考
# 你們預估這裡
# 你們有看一下
# 實價登錄的時候
# 這是15年之內的房子
# 大概70萬
# 我想蘇老師跟阿許這邊
# 應該是很清楚
# 我至少到目前為止
# 附近新蓋的房子
# 我沒有聽到70萬的
# 但我聽到的三個新的案子
# 是三位數的
# 昨天的新聞
# 是三位數
# 所以我們估價的部分
# 跟那個恐怕
# 不要落差太大
# 不然當然對中心的信心會
# 那個實際上估價的部分
# 而且他那個也是預售的
# 就在對面
# 那也是預售的
# 所以這個其實就像
# 對 這個恐怕在估價的數字上面
# 可能要稍微分析
# 降鐵在那邊
# 哇 那一大片
# 他不知道要蓋什麼
# 降鐵那個是
# 是公司的社宅
# 然後公辦屏東
# 然後底下因為跟
# 也是公辦屏東
# 跟鐵路
# 跟鐵路混合在一起
# 所以
# 我們這個是實價登錄的資訊
# 聽說是要上百萬
# 現在幾乎都三位數
# 這部分我們跟品廠報告
# 還會再做招商前的那個
# 可能一切評估的時候
# 我們會重新的
# 針對這個資訊調查
# 對 純粹是我們內部的這個
# 對 針對我們做調整
# 好 不知道還有沒有什麼比較
# 好 如果沒有的話
# 林監事有一個建議
# 印象
# 就是本案推動五項課題
# 尤其私有土地
# 所有權人 住在居民
# 過期離地 所有權人等
# 協調事宜甚為關鍵
# 如已有錯誤接洽結果
# 請與會中補充說明
# 這個就是邊我們大臣
# 跟那個我們辦理的
# 都是同樣的單位
# 兩個月的那個業務報告
# 我們會針對個案的地方
# 都會重新做報告
# 好
# 那我們就
# 決議吧
# 討論案是
# 本中心擔任台北市
# 文山區木柵段一小段
# 9121號等
# 24筆土地公辦都市更新
# 實施者案決議
# 經全體出席
# 董監事一致同意通過
# 依新北市住宅及都市更新
# 中心設置之日條例
# 第五條規定報請新北市政府
# 核定
# 接下來進行臨時動議
# 不知道各位有沒有什麼
# 臨時動議
# 如果沒有我們今天會議到這邊
# 不好意思 差不多兩個小時
# 今天會議到此結束
# 謝謝董監事的參與
# 再見
# 謝謝大家 請請
# 這件事是極大難題啊

# %%
# 將輸出會議逐字稿和會議 agenda 組合成 Prompt  

agenda = '''
會議名稱: 新北市住都中心第二屆第四次董監事會
日期: 2024/07/04 14:00-16:00
地點: 新北市新店區公所住都中心辦公室
出席人員: 董事: 9人 , 監事: 2人

會議主要內容: 報告案 (4項), 討論案 (4項), 臨時動議

會議時長: 約2小時 (根據主持人最後的發言推測)

1 報告案
1.1 上次會議決議執行情形說明
1.2 本中心113年5-6月重要業務報告
1.3 本中心113年1-4月預算執行情形報告
1.4 本中心內部稽核業務報告
2 討論案  
2.1 本中心內部稽核人員聘任追認
2.2 本中心114年度業務及營運計畫
2.3 本中心114年度預算案
2.4 本中心擔任台北市文山區木柵段一小段912-1號等24筆土地公辦都市更新實施者案
3 臨時動議 

'''


meeting_minutes_prompt = f'''
你是一位專業的會議記錄助理。你的任務是接續生成會議紀錄,請注意以下幾點:
   1. 仔細閱會議逐字稿、Agenda。
   2. 不要重複已輸出的內容。
   3. 遵循固定結構和格式,保持一致性。特別注意:
   - 明確區分"報告案"和"討論案"部分
   - 保留原有的案由編號(如"案由一"、"案由二"等)
   - 使用適當的格式(標題、子標題、項目符號等)和排版(加粗、縮進等)
   
   架構參考 : 
   ####
    ex. 案由編號:[標題]
    董監事意見:
      - [董監事對於此案由意見列表]
    中心說明:
     - [中心對於此案由說明]。
    決議:[決議內容]
   ####
   
   4. 確保包含以下元素:
      a) 詳細記錄每個議題的討論內容
      b) 突出主要決策和結論
      c) 記錄董監事意見和中心的回應
      d) 使用"決議:"標記每個議題的最終決定
      e) 列出行動項目(如有),包括負責人和期限
   5. 只基於逐字稿中的事實,對不確定的資訊使用[待定]標記。
   6. 使用清晰、專業的繁體中文。
   7. 注意捕捉重要數據和統計資料。
   9. 當你完成所有議程項目，請加上"[會議結束]"標記。

請記住,你的產出對於工作效率和決策執行至關重要,務必謹慎、準確地完成任務。
####
逐字稿:
{transcribed_text}
####
Agenda :
{agenda}
會議紀錄 : 
'''

# %%
### 呼叫大語言模型生成會議紀錄 
### 目前輸出字數限制 8192 : 長時間的會議紀錄會超過 Token 限制
#### 新增模型判斷目前的會議紀錄是否完成：如果 Y 則完成輸出會議紀錄，如果 N 則組合 Prompt 前面加請接續生成 Prompt，後面加上目前的會議紀錄，並將結果與之前的輸出組合，直到模型判斷完成輸出會議紀錄

from google.cloud import aiplatform
import vertexai
from vertexai.preview.generative_models import GenerativeModel, SafetySetting

project_id="nthurc-aisearch-202406"
region="asia-east1"

vertexai.init(project=project_id, location=region)
aiplatform.init(project=project_id, location=region)
model = GenerativeModel(
    "gemini-1.5-pro",
  )

generation_config = {
    "max_output_tokens": 8192,
    "temperature": 0.2,
    "top_p": 1,
    "top_k": 1,
}

generation_config_conditional = {
    "max_output_tokens": 1,
    "temperature": 0.0,
    "top_p": 1,
    "top_k": 1,
}

safety_settings = [
    SafetySetting(
        category=SafetySetting.HarmCategory.HARM_CATEGORY_HATE_SPEECH,
        threshold=SafetySetting.HarmBlockThreshold.BLOCK_NONE
    ),
    SafetySetting(
        category=SafetySetting.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT,
        threshold=SafetySetting.HarmBlockThreshold.BLOCK_NONE
    ),
    SafetySetting(
        category=SafetySetting.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT,
        threshold=SafetySetting.HarmBlockThreshold.BLOCK_NONE
    ),
    SafetySetting(
        category=SafetySetting.HarmCategory.HARM_CATEGORY_HARASSMENT,
        threshold=SafetySetting.HarmBlockThreshold.BLOCK_NONE
    ),
]

# 初始化會議紀錄
meeting_minutes = ""
count = 0

while True:
    # 如果是第一次生成，使用原始的 prompt
    if not meeting_minutes:
        current_prompt = meeting_minutes_prompt
    else:
        # 如果不是第一次，則在原始 prompt 前加上請求繼續生成的指示
        current_prompt = f"""
        你是一位專業的會議記錄助理。你的任務是接續生成會議紀錄,請注意以下幾點:
        1. 仔細閱讀之前提供的會議逐字稿、Agenda和已生成的部分會議紀錄。
        2. 從上次中斷的地方繼續生成,不要重複已經輸出的內容。
        3. 遵循之前的結構和格式,保持一致性。特別注意:
        - 明確區分"報告案"和"討論案"部分
        - 保留原有的案由編號(如"案由一"、"案由二"等)
        - 使用適當的格式(標題、子標題、項目符號等)和排版(加粗、縮進等)
        
        架構參考 : 
        ####
            ex. 案由編號:[標題]
            董監事意見:
            - [董監事對於此案由意見列表]
            中心說明:
            - [中心對於此案由說明]。
            決議:[決議內容]
        ####
        
        4. 確保包含以下元素:
            a) 詳細記錄每個議題的討論內容
            b) 突出主要決策和結論
            c) 記錄董監事意見和中心的回應
            d) 使用"決議:"標記每個議題的最終決定
            e) 列出行動項目(如有),包括負責人和期限
        5. 只基於逐字稿中的事實,對不確定的資訊使用[待定]標記。
        6. 使用清晰、專業的繁體中文。
        7. 注意捕捉重要數據和統計資料。
        8. 如果尚未完成,請在會議紀錄最後提供簡潔的會議摘要。
        9. 當你完成所有議程項目，請加上"[會議結束]"標記。

        請直接從上次中斷的地方繼續生成,無需重複介紹或總結已完成的部分。你的任務是完成整個會議紀錄,直到涵蓋所有議程項目為止。

        ####
        逐字稿:
        {transcribed_text}
        ####
        Agenda:
        {agenda}
        ####
        已生成的會議紀錄:
        {meeting_minutes}
        ####
        
        請從上次中斷的地方繼續生成會議紀錄。
        
        
        """
        count += 1 

    # 生成會議紀錄
    print(f"开始第 {count + 1} 次生成")
    response = model.generate_content(
        contents=current_prompt,
        generation_config=generation_config,
        safety_settings=safety_settings,
    )

    # 更新會議紀錄
    meeting_minutes += response.text
    
    print(f"當前會議紀錄長度: {len(meeting_minutes)} 個字")

    # 檢查是否完成
    
    needContinue_prompt = f'''
    你是一位專業的會議紀錄審核員。你的任務是根據提供的 Agenda 和會議紀錄內容，判斷會議紀錄是否完整完成。請仔細閱讀會議紀錄，並根據以下標準進行評估：

        1. 會議基本信息是否完整（日期、時間、地點、參與者等）
        2. 是否包含所有 Agenda 中列出的議題
        3. 每個議題是否有詳細的討論內容記錄
        4. 是否記錄了董監事的意見和中心的回應
        5. 每個議題是否有明確的決議
        6. 是否列出了行動項目（如有）
        7. 是否有一個總結性的會議摘要
        8. 會議紀錄是否以 "[會議結束]" 標記結束

    評估完成後，請根據以下規則輸出結果：
    - 如果會議紀錄滿足上述所有標準，並且以 "[會議結束]" 標記結束，請輸出 "Y"
    - 如果會議紀錄缺少任何一項上述內容，或者沒有 "[會議結束]" 標記，請輸出 "N"

    請只輸出 "Y" 或 "N"，不需要其他解釋或評論。
    ####

    會議 Agenda : {agenda}

    ####

    會議逐字稿 : {transcribed_text} 

    ####

    目前會議紀錄 : {meeting_minutes}
    '''
    
    continue_response = model.generate_content(
        contents=needContinue_prompt,
        generation_config=generation_config_conditional,
        safety_settings=safety_settings,
    )
    
    print(f"第 {count + 1} 次生成是否完成: {continue_response.text.strip().upper()}")

    # 如果完成，則跳出循環
    if continue_response.text.strip().upper() == "Y":
        break
    
    if count >= 4 :
        break
# Out:
# 开始第 1 次生成
# 當前會議紀錄長度: 2620 個字
# 第 1 次生成是否完成: N
# 开始第 2 次生成
# 當前會議紀錄長度: 8469 個字
# 第 2 次生成是否完成: Y

# %%
print(meeting_minutes)
# Out:
# ## **新北市住宅及都市更新中心第二屆第四次董監事會 會議紀錄**
#
# **時間:** 中華民國113年7月4日(星期二)下午2時0分至4時0分
#
# **地點:** 新北市新店區公所住都中心辦公室
#
# **主席:** 陳董事長純敬                **紀錄:**  [待定]
#
# **出席:**
# * 董事: 9人
# * 監事: 2人
#
# **列席:** 各部門主管
#
# **壹、報告案**
#
# **案由三、本中心113年1-4月預算執行情形報告**
#
# **說明:**
#
# * 本報告案由行政部財務組組長吳妙芬報告，說明本中心113年1-4月預算執行情形。
#     * 1-4月收入執行率為99%，執行數為1億1,600萬1,000元。
#     * 成本及費用執行率為71%，執行數為4,460萬5,000元，剩餘數為7,139萬6,000元。
#     * 業務收入執行率為98%，主要為社宅租金及權利金收入。
#     * 其中，財政局委託管理的社宅及出租宅執行率為41%，因1-4月貸款社宅採用「收付實現制」列帳，故未認列社會住宅收入，產生預決算差異數。
#     * 經與會計師討論後，5月份起將依照預算編列原則，調整為「收付實現制」與「權責發生制」並列方式表達，未來報表將呈現收入與支出金額。
#     * 若將民權社宅收入計入，1-4月業務收入執行率可提高至103%。
#     * 公辦社宅住宅收入整體執行率為105%，既有社宅(相次1-7)執行率皆在95%以上，新接管社宅(相次8-12)預計8月份開始陸續點交招租，故1-4月尚無預算分配數。
#     * 榮獎社會住宅租金1-4月執行率為67%，落差原因說明如下：
#         * 三峽北大社宅(相次1)執行率為79%，因部分房舍漏水修繕，期間無租金收入。
#         * 永和國光社宅(相次2)於2月份點交予社會局管理，預算僅編列1-2月，執行率為53%。
#         * 五股城州1號社宅(相次9)執行率為0%，配合招租作業期程，預計8月份開始招租入住。
#         * 新接管社宅(相次10-14)因4月底前仍在業務點交及裝修作業中，執行率為0%，後續將配合招租期程開始招租入住。
#         * 若排除受建商延遲點交影響的社宅(相次10-14)，執行率可回升至99%。
#     * 成本及費用執行方面，1-4月執行率為71%，實際執行數為4,461萬元，較預算分配數6,256萬元減少約1,796萬元，主要落差原因有三：
#         * 整體用人費用執行率為76%，預算分配數1-4月減少約779萬元，因4月份禁用員額為55員，與預算編列的75員有所落差，影響執行率。目前正積極進行人員招募。
#         * 出入資產成本-服務費用執行率為74%，較預算分配數減少約620萬元，主要為社宅物管費用核銷延遲，目前正積極辦理核銷中。
#         * 業務費用-服務費用較預算分配數減少約257萬元，主要為都更委外案件支出及行銷宣傳費用與預期有所落差，預計下半年執行。
#     * 6月份起，中心將按月針對全年度執行率進行預估及檢視，並盤點各項目必要支出，以掌握全年度決算情形。
#
# **決議:**
#
# * 針對監事提出的意見，決議如下：
#     * 有關用人費用支出執行率僅60%-74%，顯示各單位人員進用未如期預期乙節，中心說明目前正積極招募人員中。
#     * 有關出資資產成本-服務費用-出資會執行數達600餘萬元，表示業務費用-服務費用-出資執行率僅17%乙節，除建議中心加速核銷作業外，並建議中心自行盤點服務費所對應之委外服務費服務契約是否有延期履約情形，加強履約管理。
# * 針對董監事提出的問題，決議如下：
#     * 有關114年度民權社宅租金收入認列方式，中心說明114年度預算將不再編列民權社宅租金收入，與會計室期待相符。
#     * 有關板橋民權社宅電梯電纜斷裂事件之額外支出，中心說明電梯修復費用由建商負擔，不會產生額外支出。
#     * 有關內部稽核業務報告中各項目的抽查比例，中心說明抽查比例係依據信賴區間95%及可容忍誤差比例計算，並考量風險程度及人力資源等因素彈性調整。
#     * 有關能力招募情形，中心說明薪資調整後，人員招募狀況雖有改善，但仍未達預期目標，目前員額僅56位，與編制員額仍有相當差距。多元招募管道中，以台北駐都轉任及大型博覽會成效較佳。
#     * 有關104人力銀行招募資訊露出時間，中心說明已調整為長期露出，讓求職者隨時都能看到職缺資訊。
#     * 有關重大採購廉政平台，中心說明已依市長指示成立採購廉政平台，網頁已正式運作，未來將視需要召開會議，落實市長政策。
#     * 有關新店中華段國有土地分回規劃案，中心說明目前國產署表示優先評估中央辦公廳舍使用，與中心推動方向不符，刻正與國產署溝通協調中，預計1-2個月內會有明確結果。
#     * 有關社宅修繕費用分攤方式，中心說明目前社宅登記於市府名下，由城鄉局管理，中心僅代為管理，故修繕費用應由市府負擔。未來將與市府研議建立長期修繕基金，以支應社宅長期維護需求。
#     * 有關社宅租金分級制度對租金收入之影響，中心說明已委託顧問公司進行評估，預估租金收入將減少7%，並已將此因素納入114年度預算編列。未來將持續觀察分級租金制度實施狀況，作為預算編列參考。
#     * 有關建物改良費用之會計處理，中心說明因建物非中心所有，但金額龐大，故採用「建物改良」科目入帳，並比照財產攤提折舊。未來將與會計師研議更合適的會計處理方式。
#     * 有關114年度預算案是否送議會審查，中心說明依據設置自治條例，114年度預算案僅需送市府備查，無需送議會審查。
#     * 有關社宅物業管理費用佔住宅租金收入比例過高，中心說明將進一步分析物業管理費用結構，並研議降低物業管理費用之可行方案。
#
# **決議：洽悉**
#
# **案由四、本中心內部稽核業務報告**
#
# **說明:**
#
# * 本報告案由稽核專員郭麗清報告，說明本中心內部稽核業務執行情形。
#     * 4-5月委託勤業眾信聯合會計師事務所查核租金及勞務收入循環，抽查結果均符合規定。
#     * 6-7月預計查核新增工程款項。
#
# **決議：洽悉**
#
# **(以下會議內容將於後續部分提供)**
# **貳、討論案**
#
# **案由一、本中心內部稽核人員聘任追認**
#
# **說明:**
#
# * 本案由代理執行長錢奕綱報告，說明本中心內部稽核人員郭麗清之聘任案，請其迴避。
#     * 郭麗清女士係由益鼎信實一號公司招聘，曾任職於生物科技公司12年，具備會計師資格及相關經驗，符合本中心內部稽核人員之資格條件。
#
# **決議:**
#
# * 本討論案於稽核人員郭麗清迴避後進行討論，經全體董監事一致同意通過追認。
#
# **案由二、本中心114年度業務及營運計畫**
#
# **說明:**
#
# * 本案由代理執行長錢奕綱報告，說明本中心114年度業務及營運計畫。
#     * **發展總目標:**
#         * 自立經營：透過行政法人企業化經營，提升市有財產經營效率。
#         * 落實政策：積極推動都市更新政策，建立公辦民營推動都市更新之模式，作為未來招商示範。
#         * 強化溝通：強化與民間業者及所有權人之間的互信基礎。
#     * **發展四大目標:**
#         * 實踐社會住宅政策：專責社宅招租、營運及履約管理，保障市民多元居住選擇，兼顧社宅品質與數量提升，維護居住品質，落實居住正義。
#         * 經營管理不動產：持續經營管理市府委託之社宅及榮獎回饋都市更新不動產，活化資產效益。預計114年度接管社宅達37處，總戶數超過5,000戶。
#         * 加速推動都市更新：加速辦理主導公辦及協助民辦推動都市更新，以公平、公開、公正方式推動，擴大都市更新能量。
#         * 推展不動產資訊研究及交流：提供政策建議，辦理社宅及都市更新資料收集、統計、分析及可行性評估作業，促進產官學交流，提供研究發展能量。
#     * **業務計畫:**
#         * **社會住宅租賃管理:**
#             * 考量市場行情，提供只租不售之社宅，明年度預計達37處，維持113年度30處以上，入住率達90%以上。
#             * 114年度將接管7處社宅，辦理入住及與地主簽約等事宜。
#         * **店鋪經營管理:**
#             * 健全社區生活機能，提供33處店鋪，入住率達80%以上。
#             * 辦理國光二期、泰山中山等16戶店鋪招租作業。
#         * **公益空間管理:**
#             * 提升社宅服務效能，達26間公益空間，配合市府各局處辦理公益空間租約，使用率達80%以上。
#             * 協助各局處、公益空間承租廠商及公益藝術團體辦理社區互動活動，增加社宅民眾凝聚力。
#         * **管理營運:**
#             * 提供高效能管理營運，針對5,500戶社宅，導入預計於7月底公布之SOP營運管理手冊，加強物管公司教育訓練及督導。
#             * 導入智慧化及電子化設備，降低社宅營運成本。
#             * 建立社宅民眾家戶訪視紀錄，針對特殊個案持續追蹤。
#         * **加速推動公辦都市更新:**
#             * 綜合業務一部執行案件：
#                 * 大城三：拆除完成後，進入實際施工階段，將結合PCM廠商嚴格管理施工品質及進度。
#                 * 大城一、四：辦理選配及都市更新計畫報核。
#                 * 樹林案：持續追蹤都市計畫變更審議進度，辦理後續公開招商。
#                 * 新店中華段：等待國產署完成需求評估後，再行處理。
#                 * 文山溪農案：於今年度辦理公告招商後，明年度辦理選配及都市更新事業計畫報核。
#                 * 永和鼎溪案：辦理公開評選實施者及簽約，進行履約管理。
#                 * 板橋福州案：辦理公告招商及履約管理。
#                 * 文山木柵案：辦理先期規劃作業、劃定更新地區及招商前置作業。
#             * 綜合業務二部執行案件：
#                 * 新莊公園一路案：擔任專案管理顧問，工程施工中，預計115年取得使用執照。
#                 * 蘆洲長安街193巷案：擔任全案管理顧問，協助事業計畫審議及報核。
#                 * 板橋油庫口案：擔任全案管理顧問，協助住戶協調整合及後續專業團隊遴選。
#                 * 新莊中港路中美社區案：擔任專業顧問，提供法律諮詢，協助實施者與未同意戶溝通協調。
#                 * 蘆洲長安街46巷案：擔任法律諮詢顧問，協助實施者與未同意戶溝通。
#                 * 新店區斯馨路案：擔任顧問，協助事業計畫及權變計畫審議。
#                 * 協助市府580專案：持續推動，加速案件辦理。
#                 * 新增受託民間推動都市更新案件1-3處。
#         * **行政管理:**
#             * 人員招募：依各部門需求，滾動式修正調整，辦理至少3場內部教育訓練及2次績效考核。
#             * 財務規劃：依業務範疇規劃營運資金，辦理預決算編列及執行控管，定期檢討租金收繳進度，降低呆帳風險，並定期檢討業務發展，進行四年期財務預測。
#             * 資訊管理：落實管理作業及應用系統流程、權限、備份等行政事務，辦理資通安全評鑑，並透過網路資訊提升作業效率。
#         * **組織建構:**
#             * 編制員額75人，維持不變。
#         * **住宅及都市更新知識研究發展:**
#             * 資產管理部：辦理物業管理教育訓練，提升同仁及外站物業管理專業職能，並與國內外社宅研究機構合作，提出分析研究報告。
#             * 綜合業務一部：辦理都市更新教育訓練，整合學界及業界實務經驗，加強社區協助及諮詢，並進行國內外都市更新作業研究規劃及資料收集，提出政策建議。
#             * 綜合業務二部：辦理都市更新法令說明會，普及都市更新知識，114年度目標辦理200場以上，並持續收集國內外都市更新研究規劃及政策資訊，提供都市更新處參考。
#             * 行政部：加強同仁都市更新專業知識教育，辦理1場都市更新相關教育系列活動，並至少提供1次國內外住宅及都市更新訊息，每週提供新北市政府相關法令修正及餘勤資訊。
#     * **經費收支:**
#         * 114年度收支總額為6億4,348萬1,000元，較今年度成長32%。
#         * 成本及費用總額為3億8,505萬元，較今年度成長24%。
#         * 結繳支出總額為2億5,842萬8,000元，較今年度成長46%。
#
# **決議:**
#
# * 經全體出席董監事一致同意通過，並授權住都中心依照會中建議文字修改，後續依「新北市住宅及都市更新中心設置自治條例」規定報新北市政府備查。
# * 針對董監事提出的問題及建議，決議如下：
#     * 有關中心是否應爭取興建社會住宅之權限，中心說明目前尚無此能量，將先著重於提升營運管理績效，未來再視情況評估。
#     * 有關青年社會住宅之定義，中心說明將修正為社會住宅，並針對不同族群提供多元居住選擇。
#     * 有關綜合業務一部及二部之業務推展，中心說明將持續深耕社區，協助社區進行自主更新，並積極開拓公辦都市更新案源，例如與國公營事業合作。
#     * 有關三重新據點之設置，中心說明已於6月27日正式營運，未來將提供都市更新法令諮詢、社宅收件及與都更聯盟合作辦理活動等服務。
#     * 有關AI應用於社宅及都市更新業務，中心說明已著手規劃，預計於今年底推出相關服務，以減輕同仁負擔。
#     * 有關社宅長期修繕費用之準備，中心說明已委託台科大及成大教授進行研究，預計明年開始提撥經費，以支應未來修繕需求。
#     * 有關社宅修繕費用分攤方式，中心說明將與市府研議建立長期修繕基金，並釐清相關權責。
#     * 有關社宅租金分級制度對租金收入之影響，中心說明已將此因素納入預算編列，未來將持續觀察實際狀況，作為預算調整依據。
#     * 有關建物改良費用之會計處理，中心說明將與會計師研議更合適的處理方式。
#     * 有關114年度預算案是否送議會審查，中心說明將於簡報中註明僅需送市府備查。
#     * 有關社宅物業管理費用佔住宅租金收入比例過高，中心說明將進一步分析物業管理費用結構，並研議降低費用之可行方案。
#     * 有關580專案申請案件數量，中心說明正確數字為20案。
#
# **案由三、本中心114年度預算案**
#
# **說明:**
#
# * 本案由行政部財務組組長吳妙芬報告，說明本中心114年度預算案。
#     * 本中心114年度預算書已依「新北市行政法人預算編制注意事項」規定完成編報，並已送請城鄉局會計師及主計處預審。
#     * 社會住宅當年度營業收入將依「新北市住宅及都市更新中心盈餘回繳城鄉發展基金辦法」計算營收繳回款及盈餘結繳基金。
#     * 預算編列原則為收支平衡。
#     * 114年度預算收支概況：
#         * 收入與支出總計為6億4,348萬1,000元，較上年度增加32.2%。
#         * 收入：
#             * 勞務收入：1億2,501萬1,160元，較上年度增加24.1%。
#             * 租金及權利金收入：5億1,105萬2,000元，較上年度增加33.22%。
#             * 其他業務收入：384萬3,000元，上年度未編列。
#             * 財務收入：300萬元，較上年度增加。
#         * 支出：
#             * 包含成本、費用及結繳數。
#             * 成本及費用合計約佔總支出60%。
#             * 結繳款：2億5,842萬8,000元，其中基本營收繳回款為2億5,608萬3,000元，較會議資料增加15萬5,000元；盈餘結繳數同步減少15萬5,000元。
#     * 近五年收入與支出執行概況：
#         * 114年度預期收入約為110年度的4.8倍。
#     * 固定資產改良擴充：
#         * 動產、廠房及設備：主要為配合農甲分租社宅試裝工程、冷氣及熱水器安裝、平板電腦採購等支出。
#         * 無形資產：200萬元，用於官網優化。
#
# **決議:**
#
# * 經全體出席董監事一致同意通過，後續如有涉及重大改變、顯著事實、明顯錯誤或新北市政府建議修正者，授權本中心予以修正，並依「新北市住宅及都市更新中心設置自治條例」規定報新北市政府備查。
# * 針對董監事提出的問題及建議，決議如下：
#     * 有關社宅租金收入及物業管理費用之會計處理，中心說明將與會計師確認後調整。
#     * 有關建物改良費用之會計處理，中心說明將與會計師討論後，選擇最適當的處理方式。
#     * 有關114年度預算案是否送議會審查，中心說明將於簡報中註明僅需送市府備查。
#
# **案由四、本中心擔任台北市文山區木柵段一小段912-1號等24筆土地公辦都市更新實施者案**
#
# **說明:**
#
# * 本案由綜合業務一部專案組組長葉陽報告，說明本中心擔任台北市文山區木柵段一小段912-1號等24筆土地公辦都市更新實施者案。
#     * 基地位置：台北市文山區九康街及秀明路一段交叉口旁。
#     * 土地面積：約1,816平方公尺。
#     * 土地所有權人：22人，共計24筆土地。
#     * 公有土地比例：89%。
#     * 私有土地比例：11%。
#     * 合法建築物：1戶。
#     * 土地使用分區：第三種住宅區。
#     * 基地現況：多為一層樓老舊建築物，約14戶。
#     * 容積獎勵：預計爭取48.23%。
#     * 預估銷售價格：
#         * 預售屋：每坪61-67萬元。
#         * 新成屋：每坪65-75萬元。
#         * 平均：每坪70萬元。
#     * 預估銷售面積：約2,840坪。
#     * 建築規劃：地上15層、地下3層。
#     * 更新後總價值：預估約21.36億元。
#     * 共同負擔：預估約9.96億元，比例為46.63%。
#     * 推動課題：
#         1. 需經台北市政府審查選定為公辦都更案。
#         2. 需進行鄰地居民意願調查。
#         3. 基地景鄰987地號(面積67平方公尺)為畸零地，需徵詢所有權人參與意願。
#         4. 基地景鄰988地號為遭佔用之計畫道路，需與佔用人協調。
#         5. 基地範圍內有14筆門牌與新北市政府財政局有租賃關係，需調查租戶參與意願。
#     * 實施架構：
#         * 中心地取得實施者資格後，將負責前期規劃整合、徵求出資人、專案管理等工作。
#     * 預計時程：
#         * 115年底前完成招商。
#
# **決議:**
#
# * 經全體出席董監事一致同意通過，依「新北市住宅及都市更新中心設置自治條例」第五條規定報請新北市政府核定。
# * 針對董監事提出的問題及建議，決議如下：
#     * 有關本案是否適用「都市更新條例」第十二條，中心說明將進一步研究確認。
#     * 有關本案之收入來源，中心說明將與財政局協商收取權利金及工程管理費。
#     * 有關本案之預估售價，中心說明將於招商前重新評估市場行情。
#     * 有關本案之推動期程，中心說明將盡力縮短。
#     * 有關私有土地所有權人、住戶及過期租地戶之協調事宜，中心說明將於後續業務報告中說明。
#
# **參、臨時動議**
#
# **(無)**
#
# **肆、散會**
#
# * 主席宣布會議結束，時間為下午4時0分。
#
# **[會議結束]**

# %%
def clean_meeting_minutes(meeting_minutes):
    # 查找 "[會議結束]" 标记的位置
    end_tag_index = meeting_minutes.find("[會議結束]")
    
    if end_tag_index != -1:
        # 如果找到标记，只保留标记之前的内容
        cleaned_minutes = meeting_minutes[:end_tag_index].strip()
    else:
        # 如果没有找到标记，保留原始内容
        cleaned_minutes = meeting_minutes
    
    return cleaned_minutes

cleaned_minutes = clean_meeting_minutes(meeting_minutes)
print(cleaned_minutes)
# Out:
# ## **新北市住宅及都市更新中心第二屆第四次董監事會 會議紀錄**
#
# **時間:** 中華民國113年7月4日(星期二)下午2時0分至4時0分
#
# **地點:** 新北市新店區公所住都中心辦公室
#
# **主席:** 陳董事長純敬                **紀錄:**  [待定]
#
# **出席:**
# * 董事: 9人
# * 監事: 2人
#
# **列席:** 各部門主管
#
# **壹、報告案**
#
# **案由三、本中心113年1-4月預算執行情形報告**
#
# **說明:**
#
# * 本報告案由行政部財務組組長吳妙芬報告，說明本中心113年1-4月預算執行情形。
#     * 1-4月收入執行率為99%，執行數為1億1,600萬1,000元。
#     * 成本及費用執行率為71%，執行數為4,460萬5,000元，剩餘數為7,139萬6,000元。
#     * 業務收入執行率為98%，主要為社宅租金及權利金收入。
#     * 其中，財政局委託管理的社宅及出租宅執行率為41%，因1-4月貸款社宅採用「收付實現制」列帳，故未認列社會住宅收入，產生預決算差異數。
#     * 經與會計師討論後，5月份起將依照預算編列原則，調整為「收付實現制」與「權責發生制」並列方式表達，未來報表將呈現收入與支出金額。
#     * 若將民權社宅收入計入，1-4月業務收入執行率可提高至103%。
#     * 公辦社宅住宅收入整體執行率為105%，既有社宅(相次1-7)執行率皆在95%以上，新接管社宅(相次8-12)預計8月份開始陸續點交招租，故1-4月尚無預算分配數。
#     * 榮獎社會住宅租金1-4月執行率為67%，落差原因說明如下：
#         * 三峽北大社宅(相次1)執行率為79%，因部分房舍漏水修繕，期間無租金收入。
#         * 永和國光社宅(相次2)於2月份點交予社會局管理，預算僅編列1-2月，執行率為53%。
#         * 五股城州1號社宅(相次9)執行率為0%，配合招租作業期程，預計8月份開始招租入住。
#         * 新接管社宅(相次10-14)因4月底前仍在業務點交及裝修作業中，執行率為0%，後續將配合招租期程開始招租入住。
#         * 若排除受建商延遲點交影響的社宅(相次10-14)，執行率可回升至99%。
#     * 成本及費用執行方面，1-4月執行率為71%，實際執行數為4,461萬元，較預算分配數6,256萬元減少約1,796萬元，主要落差原因有三：
#         * 整體用人費用執行率為76%，預算分配數1-4月減少約779萬元，因4月份禁用員額為55員，與預算編列的75員有所落差，影響執行率。目前正積極進行人員招募。
#         * 出入資產成本-服務費用執行率為74%，較預算分配數減少約620萬元，主要為社宅物管費用核銷延遲，目前正積極辦理核銷中。
#         * 業務費用-服務費用較預算分配數減少約257萬元，主要為都更委外案件支出及行銷宣傳費用與預期有所落差，預計下半年執行。
#     * 6月份起，中心將按月針對全年度執行率進行預估及檢視，並盤點各項目必要支出，以掌握全年度決算情形。
#
# **決議:**
#
# * 針對監事提出的意見，決議如下：
#     * 有關用人費用支出執行率僅60%-74%，顯示各單位人員進用未如期預期乙節，中心說明目前正積極招募人員中。
#     * 有關出資資產成本-服務費用-出資會執行數達600餘萬元，表示業務費用-服務費用-出資執行率僅17%乙節，除建議中心加速核銷作業外，並建議中心自行盤點服務費所對應之委外服務費服務契約是否有延期履約情形，加強履約管理。
# * 針對董監事提出的問題，決議如下：
#     * 有關114年度民權社宅租金收入認列方式，中心說明114年度預算將不再編列民權社宅租金收入，與會計室期待相符。
#     * 有關板橋民權社宅電梯電纜斷裂事件之額外支出，中心說明電梯修復費用由建商負擔，不會產生額外支出。
#     * 有關內部稽核業務報告中各項目的抽查比例，中心說明抽查比例係依據信賴區間95%及可容忍誤差比例計算，並考量風險程度及人力資源等因素彈性調整。
#     * 有關能力招募情形，中心說明薪資調整後，人員招募狀況雖有改善，但仍未達預期目標，目前員額僅56位，與編制員額仍有相當差距。多元招募管道中，以台北駐都轉任及大型博覽會成效較佳。
#     * 有關104人力銀行招募資訊露出時間，中心說明已調整為長期露出，讓求職者隨時都能看到職缺資訊。
#     * 有關重大採購廉政平台，中心說明已依市長指示成立採購廉政平台，網頁已正式運作，未來將視需要召開會議，落實市長政策。
#     * 有關新店中華段國有土地分回規劃案，中心說明目前國產署表示優先評估中央辦公廳舍使用，與中心推動方向不符，刻正與國產署溝通協調中，預計1-2個月內會有明確結果。
#     * 有關社宅修繕費用分攤方式，中心說明目前社宅登記於市府名下，由城鄉局管理，中心僅代為管理，故修繕費用應由市府負擔。未來將與市府研議建立長期修繕基金，以支應社宅長期維護需求。
#     * 有關社宅租金分級制度對租金收入之影響，中心說明已委託顧問公司進行評估，預估租金收入將減少7%，並已將此因素納入114年度預算編列。未來將持續觀察分級租金制度實施狀況，作為預算編列參考。
#     * 有關建物改良費用之會計處理，中心說明因建物非中心所有，但金額龐大，故採用「建物改良」科目入帳，並比照財產攤提折舊。未來將與會計師研議更合適的會計處理方式。
#     * 有關114年度預算案是否送議會審查，中心說明依據設置自治條例，114年度預算案僅需送市府備查，無需送議會審查。
#     * 有關社宅物業管理費用佔住宅租金收入比例過高，中心說明將進一步分析物業管理費用結構，並研議降低物業管理費用之可行方案。
#
# **決議：洽悉**
#
# **案由四、本中心內部稽核業務報告**
#
# **說明:**
#
# * 本報告案由稽核專員郭麗清報告，說明本中心內部稽核業務執行情形。
#     * 4-5月委託勤業眾信聯合會計師事務所查核租金及勞務收入循環，抽查結果均符合規定。
#     * 6-7月預計查核新增工程款項。
#
# **決議：洽悉**
#
# **(以下會議內容將於後續部分提供)**
# **貳、討論案**
#
# **案由一、本中心內部稽核人員聘任追認**
#
# **說明:**
#
# * 本案由代理執行長錢奕綱報告，說明本中心內部稽核人員郭麗清之聘任案，請其迴避。
#     * 郭麗清女士係由益鼎信實一號公司招聘，曾任職於生物科技公司12年，具備會計師資格及相關經驗，符合本中心內部稽核人員之資格條件。
#
# **決議:**
#
# * 本討論案於稽核人員郭麗清迴避後進行討論，經全體董監事一致同意通過追認。
#
# **案由二、本中心114年度業務及營運計畫**
#
# **說明:**
#
# * 本案由代理執行長錢奕綱報告，說明本中心114年度業務及營運計畫。
#     * **發展總目標:**
#         * 自立經營：透過行政法人企業化經營，提升市有財產經營效率。
#         * 落實政策：積極推動都市更新政策，建立公辦民營推動都市更新之模式，作為未來招商示範。
#         * 強化溝通：強化與民間業者及所有權人之間的互信基礎。
#     * **發展四大目標:**
#         * 實踐社會住宅政策：專責社宅招租、營運及履約管理，保障市民多元居住選擇，兼顧社宅品質與數量提升，維護居住品質，落實居住正義。
#         * 經營管理不動產：持續經營管理市府委託之社宅及榮獎回饋都市更新不動產，活化資產效益。預計114年度接管社宅達37處，總戶數超過5,000戶。
#         * 加速推動都市更新：加速辦理主導公辦及協助民辦推動都市更新，以公平、公開、公正方式推動，擴大都市更新能量。
#         * 推展不動產資訊研究及交流：提供政策建議，辦理社宅及都市更新資料收集、統計、分析及可行性評估作業，促進產官學交流，提供研究發展能量。
#     * **業務計畫:**
#         * **社會住宅租賃管理:**
#             * 考量市場行情，提供只租不售之社宅，明年度預計達37處，維持113年度30處以上，入住率達90%以上。
#             * 114年度將接管7處社宅，辦理入住及與地主簽約等事宜。
#         * **店鋪經營管理:**
#             * 健全社區生活機能，提供33處店鋪，入住率達80%以上。
#             * 辦理國光二期、泰山中山等16戶店鋪招租作業。
#         * **公益空間管理:**
#             * 提升社宅服務效能，達26間公益空間，配合市府各局處辦理公益空間租約，使用率達80%以上。
#             * 協助各局處、公益空間承租廠商及公益藝術團體辦理社區互動活動，增加社宅民眾凝聚力。
#         * **管理營運:**
#             * 提供高效能管理營運，針對5,500戶社宅，導入預計於7月底公布之SOP營運管理手冊，加強物管公司教育訓練及督導。
#             * 導入智慧化及電子化設備，降低社宅營運成本。
#             * 建立社宅民眾家戶訪視紀錄，針對特殊個案持續追蹤。
#         * **加速推動公辦都市更新:**
#             * 綜合業務一部執行案件：
#                 * 大城三：拆除完成後，進入實際施工階段，將結合PCM廠商嚴格管理施工品質及進度。
#                 * 大城一、四：辦理選配及都市更新計畫報核。
#                 * 樹林案：持續追蹤都市計畫變更審議進度，辦理後續公開招商。
#                 * 新店中華段：等待國產署完成需求評估後，再行處理。
#                 * 文山溪農案：於今年度辦理公告招商後，明年度辦理選配及都市更新事業計畫報核。
#                 * 永和鼎溪案：辦理公開評選實施者及簽約，進行履約管理。
#                 * 板橋福州案：辦理公告招商及履約管理。
#                 * 文山木柵案：辦理先期規劃作業、劃定更新地區及招商前置作業。
#             * 綜合業務二部執行案件：
#                 * 新莊公園一路案：擔任專案管理顧問，工程施工中，預計115年取得使用執照。
#                 * 蘆洲長安街193巷案：擔任全案管理顧問，協助事業計畫審議及報核。
#                 * 板橋油庫口案：擔任全案管理顧問，協助住戶協調整合及後續專業團隊遴選。
#                 * 新莊中港路中美社區案：擔任專業顧問，提供法律諮詢，協助實施者與未同意戶溝通協調。
#                 * 蘆洲長安街46巷案：擔任法律諮詢顧問，協助實施者與未同意戶溝通。
#                 * 新店區斯馨路案：擔任顧問，協助事業計畫及權變計畫審議。
#                 * 協助市府580專案：持續推動，加速案件辦理。
#                 * 新增受託民間推動都市更新案件1-3處。
#         * **行政管理:**
#             * 人員招募：依各部門需求，滾動式修正調整，辦理至少3場內部教育訓練及2次績效考核。
#             * 財務規劃：依業務範疇規劃營運資金，辦理預決算編列及執行控管，定期檢討租金收繳進度，降低呆帳風險，並定期檢討業務發展，進行四年期財務預測。
#             * 資訊管理：落實管理作業及應用系統流程、權限、備份等行政事務，辦理資通安全評鑑，並透過網路資訊提升作業效率。
#         * **組織建構:**
#             * 編制員額75人，維持不變。
#         * **住宅及都市更新知識研究發展:**
#             * 資產管理部：辦理物業管理教育訓練，提升同仁及外站物業管理專業職能，並與國內外社宅研究機構合作，提出分析研究報告。
#             * 綜合業務一部：辦理都市更新教育訓練，整合學界及業界實務經驗，加強社區協助及諮詢，並進行國內外都市更新作業研究規劃及資料收集，提出政策建議。
#             * 綜合業務二部：辦理都市更新法令說明會，普及都市更新知識，114年度目標辦理200場以上，並持續收集國內外都市更新研究規劃及政策資訊，提供都市更新處參考。
#             * 行政部：加強同仁都市更新專業知識教育，辦理1場都市更新相關教育系列活動，並至少提供1次國內外住宅及都市更新訊息，每週提供新北市政府相關法令修正及餘勤資訊。
#     * **經費收支:**
#         * 114年度收支總額為6億4,348萬1,000元，較今年度成長32%。
#         * 成本及費用總額為3億8,505萬元，較今年度成長24%。
#         * 結繳支出總額為2億5,842萬8,000元，較今年度成長46%。
#
# **決議:**
#
# * 經全體出席董監事一致同意通過，並授權住都中心依照會中建議文字修改，後續依「新北市住宅及都市更新中心設置自治條例」規定報新北市政府備查。
# * 針對董監事提出的問題及建議，決議如下：
#     * 有關中心是否應爭取興建社會住宅之權限，中心說明目前尚無此能量，將先著重於提升營運管理績效，未來再視情況評估。
#     * 有關青年社會住宅之定義，中心說明將修正為社會住宅，並針對不同族群提供多元居住選擇。
#     * 有關綜合業務一部及二部之業務推展，中心說明將持續深耕社區，協助社區進行自主更新，並積極開拓公辦都市更新案源，例如與國公營事業合作。
#     * 有關三重新據點之設置，中心說明已於6月27日正式營運，未來將提供都市更新法令諮詢、社宅收件及與都更聯盟合作辦理活動等服務。
#     * 有關AI應用於社宅及都市更新業務，中心說明已著手規劃，預計於今年底推出相關服務，以減輕同仁負擔。
#     * 有關社宅長期修繕費用之準備，中心說明已委託台科大及成大教授進行研究，預計明年開始提撥經費，以支應未來修繕需求。
#     * 有關社宅修繕費用分攤方式，中心說明將與市府研議建立長期修繕基金，並釐清相關權責。
#     * 有關社宅租金分級制度對租金收入之影響，中心說明已將此因素納入預算編列，未來將持續觀察實際狀況，作為預算調整依據。
#     * 有關建物改良費用之會計處理，中心說明將與會計師研議更合適的處理方式。
#     * 有關114年度預算案是否送議會審查，中心說明將於簡報中註明僅需送市府備查。
#     * 有關社宅物業管理費用佔住宅租金收入比例過高，中心說明將進一步分析物業管理費用結構，並研議降低費用之可行方案。
#     * 有關580專案申請案件數量，中心說明正確數字為20案。
#
# **案由三、本中心114年度預算案**
#
# **說明:**
#
# * 本案由行政部財務組組長吳妙芬報告，說明本中心114年度預算案。
#     * 本中心114年度預算書已依「新北市行政法人預算編制注意事項」規定完成編報，並已送請城鄉局會計師及主計處預審。
#     * 社會住宅當年度營業收入將依「新北市住宅及都市更新中心盈餘回繳城鄉發展基金辦法」計算營收繳回款及盈餘結繳基金。
#     * 預算編列原則為收支平衡。
#     * 114年度預算收支概況：
#         * 收入與支出總計為6億4,348萬1,000元，較上年度增加32.2%。
#         * 收入：
#             * 勞務收入：1億2,501萬1,160元，較上年度增加24.1%。
#             * 租金及權利金收入：5億1,105萬2,000元，較上年度增加33.22%。
#             * 其他業務收入：384萬3,000元，上年度未編列。
#             * 財務收入：300萬元，較上年度增加。
#         * 支出：
#             * 包含成本、費用及結繳數。
#             * 成本及費用合計約佔總支出60%。
#             * 結繳款：2億5,842萬8,000元，其中基本營收繳回款為2億5,608萬3,000元，較會議資料增加15萬5,000元；盈餘結繳數同步減少15萬5,000元。
#     * 近五年收入與支出執行概況：
#         * 114年度預期收入約為110年度的4.8倍。
#     * 固定資產改良擴充：
#         * 動產、廠房及設備：主要為配合農甲分租社宅試裝工程、冷氣及熱水器安裝、平板電腦採購等支出。
#         * 無形資產：200萬元，用於官網優化。
#
# **決議:**
#
# * 經全體出席董監事一致同意通過，後續如有涉及重大改變、顯著事實、明顯錯誤或新北市政府建議修正者，授權本中心予以修正，並依「新北市住宅及都市更新中心設置自治條例」規定報新北市政府備查。
# * 針對董監事提出的問題及建議，決議如下：
#     * 有關社宅租金收入及物業管理費用之會計處理，中心說明將與會計師確認後調整。
#     * 有關建物改良費用之會計處理，中心說明將與會計師討論後，選擇最適當的處理方式。
#     * 有關114年度預算案是否送議會審查，中心說明將於簡報中註明僅需送市府備查。
#
# **案由四、本中心擔任台北市文山區木柵段一小段912-1號等24筆土地公辦都市更新實施者案**
#
# **說明:**
#
# * 本案由綜合業務一部專案組組長葉陽報告，說明本中心擔任台北市文山區木柵段一小段912-1號等24筆土地公辦都市更新實施者案。
#     * 基地位置：台北市文山區九康街及秀明路一段交叉口旁。
#     * 土地面積：約1,816平方公尺。
#     * 土地所有權人：22人，共計24筆土地。
#     * 公有土地比例：89%。
#     * 私有土地比例：11%。
#     * 合法建築物：1戶。
#     * 土地使用分區：第三種住宅區。
#     * 基地現況：多為一層樓老舊建築物，約14戶。
#     * 容積獎勵：預計爭取48.23%。
#     * 預估銷售價格：
#         * 預售屋：每坪61-67萬元。
#         * 新成屋：每坪65-75萬元。
#         * 平均：每坪70萬元。
#     * 預估銷售面積：約2,840坪。
#     * 建築規劃：地上15層、地下3層。
#     * 更新後總價值：預估約21.36億元。
#     * 共同負擔：預估約9.96億元，比例為46.63%。
#     * 推動課題：
#         1. 需經台北市政府審查選定為公辦都更案。
#         2. 需進行鄰地居民意願調查。
#         3. 基地景鄰987地號(面積67平方公尺)為畸零地，需徵詢所有權人參與意願。
#         4. 基地景鄰988地號為遭佔用之計畫道路，需與佔用人協調。
#         5. 基地範圍內有14筆門牌與新北市政府財政局有租賃關係，需調查租戶參與意願。
#     * 實施架構：
#         * 中心地取得實施者資格後，將負責前期規劃整合、徵求出資人、專案管理等工作。
#     * 預計時程：
#         * 115年底前完成招商。
#
# **決議:**
#
# * 經全體出席董監事一致同意通過，依「新北市住宅及都市更新中心設置自治條例」第五條規定報請新北市政府核定。
# * 針對董監事提出的問題及建議，決議如下：
#     * 有關本案是否適用「都市更新條例」第十二條，中心說明將進一步研究確認。
#     * 有關本案之收入來源，中心說明將與財政局協商收取權利金及工程管理費。
#     * 有關本案之預估售價，中心說明將於招商前重新評估市場行情。
#     * 有關本案之推動期程，中心說明將盡力縮短。
#     * 有關私有土地所有權人、住戶及過期租地戶之協調事宜，中心說明將於後續業務報告中說明。
#
# **參、臨時動議**
#
# **(無)**
#
# **肆、散會**
#
# * 主席宣布會議結束，時間為下午4時0分。
#
# **

# %% [markdown]
# ### 測試程式碼輸出是否足夠穩定

# %%
from google.cloud import aiplatform
import vertexai
from vertexai.preview.generative_models import GenerativeModel, SafetySetting

def generate_meeting_minutes(transcribed_text, agenda, meeting_minutes_prompt):
    project_id = "nthurc-aisearch-202406"
    region = "asia-east1"
    vertexai.init(project=project_id, location=region)
    aiplatform.init(project=project_id, location=region)
    model = GenerativeModel("gemini-1.5-flash")
    
    generation_config = {
        "max_output_tokens": 8192,
        "temperature": 0.2,
        "top_p": 1,
        "top_k": 1,
    }
    generation_config_conditional = {
        "max_output_tokens": 1,
        "temperature": 0.0,
        "top_p": 1,
        "top_k": 1,
    }
    safety_settings = [
        SafetySetting(category=SafetySetting.HarmCategory.HARM_CATEGORY_HATE_SPEECH, threshold=SafetySetting.HarmBlockThreshold.BLOCK_NONE),
        SafetySetting(category=SafetySetting.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT, threshold=SafetySetting.HarmBlockThreshold.BLOCK_NONE),
        SafetySetting(category=SafetySetting.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT, threshold=SafetySetting.HarmBlockThreshold.BLOCK_NONE),
        SafetySetting(category=SafetySetting.HarmCategory.HARM_CATEGORY_HARASSMENT, threshold=SafetySetting.HarmBlockThreshold.BLOCK_NONE),
    ]

    meeting_minutes = ""
    count = 0
    while True:
        if not meeting_minutes:
            current_prompt = meeting_minutes_prompt
        else:
            current_prompt = f"""
            你是一位專業的會議記錄助理。你的任務是接續生成會議紀錄,請注意以下幾點:
            1. 仔細閱讀之前提供的會議逐字稿、Agenda和已生成的部分會議紀錄。
            2. 從上次中斷的地方繼續生成,不要重複已經輸出的內容。
            3. 遵循之前的結構和格式,保持一致性。特別注意:
            - 明確區分"報告案"和"討論案"部分
            - 保留原有的案由編號(如"案由一"、"案由二"等)
            - 使用適當的格式(標題、子標題、項目符號等)和排版(加粗、縮進等)
            
            架構參考 : 
            ####
                ex. 案由編號:[標題]
                董監事意見:
                - [董監事對於此案由意見列表]
                中心說明:
                - [中心對於此案由說明]。
                決議:[決議內容]
            ####
            
            4. 確保包含以下元素:
            a) 詳細記錄每個議題的討論內容
            b) 突出主要決策和結論
            c) 記錄董監事意見和中心的回應
            d) 使用"決議:"標記每個議題的最終決定
            e) 列出行動項目(如有),包括負責人和期限
            5. 只基於逐字稿中的事實,對不確定的資訊使用[待定]標記。
            6. 使用清晰、專業的繁體中文。
            7. 注意捕捉重要數據和統計資料。
            8. 如果尚未完成,請在會議紀錄最後提供簡潔的會議摘要。
            9. 當你完成所有議程項目，請加上"[會議結束]"標記。
            請直接從上次中斷的地方繼續生成,無需重複介紹或總結已完成的部分。你的任務是完成整個會議紀錄,直到涵蓋所有議程項目為止。
            ####
            逐字稿:
            {transcribed_text}
            ####
            Agenda:
            {agenda}
            ####
            已生成的會議紀錄:
            {meeting_minutes}
            ####
            請從上次中斷的地方繼續生成會議紀錄。
            """
        count += 1
        print(f"开始第 {count} 次生成")
        response = model.generate_content(
            contents=current_prompt,
            generation_config=generation_config,
            safety_settings=safety_settings,
        )
        meeting_minutes += response.text
        print(f"當前會議紀錄長度: {len(meeting_minutes)} 個字")
        
        needContinue_prompt = f'''
        你是一位專業的會議紀錄審核員。你的任務是根據提供的 Agenda 和會議紀錄內容，判斷會議紀錄是否完整完成。請仔細閱讀會議紀錄，並根據以下標準進行評估：
        1. 會議基本信息是否完整（日期、時間、地點、參與者等）
        2. 是否包含所有 Agenda 中列出的議題
        3. 每個議題是否有詳細的討論內容記錄
        4. 是否記錄了董監事的意見和中心的回應
        5. 每個議題是否有明確的決議
        6. 是否列出了行動項目（如有）
        7. 是否有一個總結性的會議摘要
        8. 會議紀錄是否以 "[會議結束]" 標記結束
        評估完成後，請根據以下規則輸出結果：
        - 如果會議紀錄滿足上述所有標準，並且以 "[會議結束]" 標記結束，請輸出 "Y"
        - 如果會議紀錄缺少任何一項上述內容，或者沒有 "[會議結束]" 標記，請輸出 "N"
        請只輸出 "Y" 或 "N"，不需要其他解釋或評論。
        ####
        會議 Agenda : {agenda}
        ####
        會議逐字稿 : {transcribed_text}
        ####
        目前會議紀錄 : {meeting_minutes}
        '''
        continue_response = model.generate_content(
            contents=needContinue_prompt,
            generation_config=generation_config_conditional,
            safety_settings=safety_settings,
        )
        print(f"第 {count} 次生成是否完成: {continue_response.text.strip().upper()}")
        if continue_response.text.strip().upper() == "Y":
            break
        if count >= 4:
            break
    
    return meeting_minutes, continue_response.text.strip().upper() == "Y"

import os

def clean_meeting_minutes(meeting_minutes):
    end_tag_index = meeting_minutes.find("[會議結束]")
    if end_tag_index != -1:
        cleaned_minutes = meeting_minutes[:end_tag_index].strip()
    else:
        cleaned_minutes = meeting_minutes
    return cleaned_minutes

def test_generate_meeting_minutes(transcribed_text, agenda, meeting_minutes_prompt, num_tests=10):
    successful_generations = 0
    generations_with_end_tag = 0

    # 創建一個資料夾來存儲輸出文件
    output_folder = "meeting_minutes_output"
    os.makedirs(output_folder, exist_ok=True)

    for i in range(num_tests):
        print(f"\n開始第 {i+1} 次測試")
        minutes, is_successful = generate_meeting_minutes(transcribed_text, agenda, meeting_minutes_prompt)
        
        # 清理會議紀錄
        cleaned_minutes = clean_meeting_minutes(minutes)
        
        # 保存清理後的會議紀錄到文件
        file_name = f"meeting_minutes_test_{i+1}.md"
        file_path = os.path.join(output_folder, file_name)
        with open(file_path, "w", encoding="utf-8") as f:
            f.write(cleaned_minutes)
        
        if is_successful:
            successful_generations += 1
        
        if "[會議結束]" in minutes:
            generations_with_end_tag += 1
        
        print(f"測試 {i+1} 完成：成功 = {is_successful}, 包含 [會議結束] 標記 = {'[會議結束]' in minutes}")
        print(f"清理後的會議紀錄已保存到: {file_path}")

    print(f"\n總結：")
    print(f"成功生成次數: {successful_generations} / {num_tests}")
    print(f"包含 [會議結束] 標記的次數: {generations_with_end_tag} / {num_tests}")
    print(f"所有清理後的會議紀錄已保存到 '{output_folder}' 資料夾")

test_generate_meeting_minutes(transcribed_text, agenda, meeting_minutes_prompt)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from sklearn.metrics.pairwise import cosine_similarity
#       4 from datasets import load_dataset
#       5 from tqdm import tqdm
#
# ModuleNotFoundError: No module named 'sklearn'
